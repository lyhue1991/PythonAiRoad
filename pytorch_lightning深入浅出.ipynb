# %% [markdown]
# # pytorch_lightning深入浅出

# %% [markdown]
# pytorch-lightning 是建立在pytorch之上的高层次模型接口。
#
# pytorch-lightning 之于 pytorch，就如同keras之于 tensorflow.
#
# pytorch-lightning 有以下一些引人注目的功能：
#
# * 可以不必编写自定义循环，只要指定loss计算方法即可。
#
# * 可以通过callbacks非常方便地添加CheckPoint参数保存、early_stopping 等功能。
#
# * 可以非常方便地在单CPU、多CPU、单GPU、多GPU乃至多TPU上训练模型。
#
# * 可以通过调用torchmetrics库，非常方便地添加Accuracy,AUC,Precision等各种常用评估指标。
#
# * 可以非常方便地实施多批次梯度累加、半精度混合精度训练、最大batch_size自动搜索等技巧，加快训练过程。
#
# * 可以非常方便地使用SWA(随机参数平均)、CyclicLR(学习率周期性调度策略)与auto_lr_find(最优学习率发现)等技巧 实现模型涨点。

# %% [markdown]
# 一般按照如下方式 安装和 引入 pytorch-lightning 库。
#
# ```bash
# #安装
# pip install pytorch-lightning
# ```
#
# ```python
# #引入
# import pytorch_lightning as pl
# ```
#
# 顾名思义，它可以帮助我们漂亮(pl)地进行深度学习研究。😋😋
# You do the research. Lightning will do everything else.⭐️⭐️
#
#
# 参考文档：
#
# * pl_docs: https://pytorch-lightning.readthedocs.io/en/latest/starter/introduction.html
# * pl_template:https://github.com/PyTorchLightning/deep-learning-project-template
# * torchmetrics: https://torchmetrics.readthedocs.io/en/latest/pages/lightning.html

# %% [markdown]
# ## 一，pytorch-lightning的设计哲学

# %% [markdown]
# pytorch-lightning 的核心设计哲学是将 深度学习项目中的 研究代码(定义模型) 和 工程代码 (训练模型) 相互分离。
#
# 用户只需专注于研究代码(pl.LightningModule)的实现，而工程代码借助训练工具类(pl.Trainer)统一实现。
#
# 更详细地说，深度学习项目代码可以分成如下4部分：
#
# * 研究代码 (Research code)，用户继承LightningModule实现。
# * 工程代码 (Engineering code)，用户无需关注通过调用Trainer实现。
# * 非必要代码 （Non-essential research code，logging, etc...），用户通过调用Callbacks实现。
# * 数据 (Data)，用户通过torch.utils.data.DataLoader实现，也可以封装成pl.LightningDataModule。

# %% [markdown]
# ## 二，pytorch-lightning使用范例

# %% [markdown]
# 下面我们使用minist图片分类问题为例，演示pytorch-lightning的最佳实践。

# %% [markdown]
# ### 1，准备数据

# %%
import torch 
from torch import nn 
from torchvision import transforms as T
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader,random_split
import pytorch_lightning as pl 
from torchmetrics import Accuracy

# %%
class MNISTDataModule(pl.LightningDataModule):
    def __init__(self, data_dir: str = "./minist/", 
                 batch_size: int = 32,
                 num_workers: int =4):
        super().__init__()
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.num_workers = num_workers

    def setup(self, stage = None):
        transform = T.Compose([T.ToTensor()])
        self.ds_test = MNIST(self.data_dir, train=False,transform=transform,download=True)
        self.ds_predict = MNIST(self.data_dir, train=False,transform=transform,download=True)
        ds_full = MNIST(self.data_dir, train=True,transform=transform,download=True)
        self.ds_train, self.ds_val = random_split(ds_full, [55000, 5000])

    def train_dataloader(self):
        return DataLoader(self.ds_train, batch_size=self.batch_size,
                          shuffle=True, num_workers=self.num_workers,
                          pin_memory=True)

    def val_dataloader(self):
        return DataLoader(self.ds_val, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=True)

    def test_dataloader(self):
        return DataLoader(self.ds_test, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=True)

    def predict_dataloader(self):
        return DataLoader(self.ds_predict, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=True)

# %%
data_mnist = MNISTDataModule()
data_mnist.setup()
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./minist/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./minist/MNIST/raw/train-images-idx3-ubyte.gz to ./minist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./minist/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./minist/MNIST/raw/train-labels-idx1-ubyte.gz to ./minist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./minist/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./minist/MNIST/raw/t10k-images-idx3-ubyte.gz to ./minist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./minist/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./minist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./minist/MNIST/raw

# %%
for features,labels in data_mnist.train_dataloader():
    print(features.shape)
    print(labels.shape)
    break
# Out:
# torch.Size([32, 1, 28, 28])
# torch.Size([32])

# %% [markdown]
# ```
# torch.Size([32, 1, 28, 28])
# torch.Size([32])
# ```

# %% [markdown]
# ### 2，定义模型

# %%
net = nn.Sequential(
    nn.Conv2d(in_channels=1,out_channels=32,kernel_size = 3),
    nn.MaxPool2d(kernel_size = 2,stride = 2),
    nn.Conv2d(in_channels=32,out_channels=64,kernel_size = 5),
    nn.MaxPool2d(kernel_size = 2,stride = 2),
    nn.Dropout2d(p = 0.1),
    nn.AdaptiveMaxPool2d((1,1)),
    nn.Flatten(),
    nn.Linear(64,32),
    nn.ReLU(),
    nn.Linear(32,10)
)

class Model(pl.LightningModule):
    
    def __init__(self,net,learning_rate=1e-3):
        super().__init__()
        self.save_hyperparameters()
        self.net = net
        self.train_acc = Accuracy()
        self.val_acc = Accuracy()
        self.test_acc = Accuracy() 
        
        
    def forward(self,x):
        x = self.net(x)
        return x
    
    
    #定义loss
    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}
    
    #定义各种metrics
    def training_step_end(self,outputs):
        train_acc = self.train_acc(outputs['preds'], outputs['y']).item()    
        self.log("train_acc",train_acc,prog_bar=True)
        return {"loss":outputs["loss"].mean()}
    
    #定义optimizer,以及可选的lr_scheduler
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.hparams.learning_rate)
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}

    def validation_step_end(self,outputs):
        val_acc = self.val_acc(outputs['preds'], outputs['y']).item()    
        self.log("val_loss",outputs["loss"].mean(),on_epoch=True,on_step=False)
        self.log("val_acc",val_acc,prog_bar=True,on_epoch=True,on_step=False)
    
    def test_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}
    
    def test_step_end(self,outputs):
        test_acc = self.test_acc(outputs['preds'], outputs['y']).item()    
        self.log("test_acc",test_acc,on_epoch=True,on_step=False)
        self.log("test_loss",outputs["loss"].mean(),on_epoch=True,on_step=False)
    
model = Model(net)

#查看模型大小
model_size = pl.utilities.memory.get_model_size_mb(model)
print("model_size = {} M \n".format(model_size))
model.example_input_array = [features]
summary = pl.utilities.model_summary.ModelSummary(model,max_depth=-1)
print(summary)
# Out:
# model_size = 0.218447 M
#
#    | Name      | Type              | Params | In sizes         | Out sizes
# ---------------------------------------------------------------------------------------
# 0  | net       | Sequential        | 54.0 K | [32, 1, 28, 28]  | [32, 10]
# 1  | net.0     | Conv2d            | 320    | [32, 1, 28, 28]  | [32, 32, 26, 26]
# 2  | net.1     | MaxPool2d         | 0      | [32, 32, 26, 26] | [32, 32, 13, 13]
# 3  | net.2     | Conv2d            | 51.3 K | [32, 32, 13, 13] | [32, 64, 9, 9]
# 4  | net.3     | MaxPool2d         | 0      | [32, 64, 9, 9]   | [32, 64, 4, 4]
# 5  | net.4     | Dropout2d         | 0      | [32, 64, 4, 4]   | [32, 64, 4, 4]
# 6  | net.5     | AdaptiveMaxPool2d | 0      | [32, 64, 4, 4]   | [32, 64, 1, 1]
# 7  | net.6     | Flatten           | 0      | [32, 64, 1, 1]   | [32, 64]
# 8  | net.7     | Linear            | 2.1 K  | [32, 64]         | [32, 32]
# 9  | net.8     | ReLU              | 0      | [32, 32]         | [32, 32]
# 10 | net.9     | Linear            | 330    | [32, 32]         | [32, 10]
# 11 | train_acc | Accuracy          | 0      | ?                | ?
# 12 | val_acc   | Accuracy          | 0      | ?                | ?
# 13 | test_acc  | Accuracy          | 0      | ?                | ?
# ---------------------------------------------------------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# /Users/liangyun/ProgramFiles/anaconda3/lib/python3.8/site-packages/pytorch_lightning/utilities/parsing.py:261: UserWarning: Attribute 'net' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['net'])`.
#   rank_zero_warn(

# %% [markdown]
# ```
# model_size = 0.218447 M
#
#    | Name      | Type              | Params | In sizes         | Out sizes
# ---------------------------------------------------------------------------------------
# 0  | net       | Sequential        | 54.0 K | [32, 1, 28, 28]  | [32, 10]
# 1  | net.0     | Conv2d            | 320    | [32, 1, 28, 28]  | [32, 32, 26, 26]
# 2  | net.1     | MaxPool2d         | 0      | [32, 32, 26, 26] | [32, 32, 13, 13]
# 3  | net.2     | Conv2d            | 51.3 K | [32, 32, 13, 13] | [32, 64, 9, 9]
# 4  | net.3     | MaxPool2d         | 0      | [32, 64, 9, 9]   | [32, 64, 4, 4]
# 5  | net.4     | Dropout2d         | 0      | [32, 64, 4, 4]   | [32, 64, 4, 4]
# 6  | net.5     | AdaptiveMaxPool2d | 0      | [32, 64, 4, 4]   | [32, 64, 1, 1]
# 7  | net.6     | Flatten           | 0      | [32, 64, 1, 1]   | [32, 64]
# 8  | net.7     | Linear            | 2.1 K  | [32, 64]         | [32, 32]
# 9  | net.8     | ReLU              | 0      | [32, 32]         | [32, 32]
# 10 | net.9     | Linear            | 330    | [32, 32]         | [32, 10]
# 11 | train_acc | Accuracy          | 0      | ?                | ?
# 12 | val_acc   | Accuracy          | 0      | ?                | ?
# 13 | test_acc  | Accuracy          | 0      | ?                | ?
# ---------------------------------------------------------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# ```

# %% [markdown]
# ### 3，训练模型

# %%
pl.seed_everything(1234)

ckpt_callback = pl.callbacks.ModelCheckpoint(
    monitor='val_loss',
    save_top_k=1,
    mode='min'
)
early_stopping = pl.callbacks.EarlyStopping(monitor = 'val_loss',
               patience=3,
               mode = 'min')

# gpus=0 则使用cpu训练，gpus=1则使用1个gpu训练，gpus=2则使用2个gpu训练，gpus=-1则使用所有gpu训练，
# gpus=[0,1]则指定使用0号和1号gpu训练， gpus="0,1,2,3"则使用0,1,2,3号gpu训练
# tpus=1 则使用1个tpu训练

trainer = pl.Trainer(max_epochs=20,   
     #gpus=0, #单CPU模式
     gpus=0, #单GPU模式
     #num_processes=4,strategy="ddp_find_unused_parameters_false", #多CPU(进程)模式
     #gpus=[0,1,2,3],strategy="dp", #多GPU的DataParallel(速度提升效果一般)
     #gpus=[0,1,2,3],strategy=“ddp_find_unused_parameters_false" #多GPU的DistributedDataParallel(速度提升效果好)
     callbacks = [ckpt_callback,early_stopping],
     profiler="simple") 

#断点续训
#trainer = pl.Trainer(resume_from_checkpoint='./lightning_logs/version_31/checkpoints/epoch=02-val_loss=0.05.ckpt')

#训练模型
trainer.fit(model,data_mnist)
# Out:
# Global seed set to 1234
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /Users/liangyun/CodeFiles/machine_learning_AK47/2_Base_Models/lightning_logs
#
#   | Name      | Type       | Params | In sizes        | Out sizes
# -----------------------------------------------------------------------
# 0 | net       | Sequential | 54.0 K | [32, 1, 28, 28] | [32, 10]
# 1 | train_acc | Accuracy   | 0      | ?               | ?
# 2 | val_acc   | Accuracy   | 0      | ?               | ?
# 3 | test_acc  | Accuracy   | 0      | ?               | ?
# -----------------------------------------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# FIT Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                                                          	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                                                           	|  -              	|  750524         	|  1035.3         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                                                              	|  114.28         	|  9              	|  1028.5         	|  99.346         	|
# |  run_training_batch                                                                                                                                                                                              	|  0.046199       	|  15471          	|  714.75         	|  69.04          	|
# |  [LightningModule]Model.optimizer_step                                                                                                                                                                           	|  0.045555       	|  15471          	|  704.78         	|  68.077         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                                                                         	|  0.02216        	|  15471          	|  342.84         	|  33.116         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                                                                    	|  0.018079       	|  15471          	|  279.7          	|  27.017         	|
# |  on_train_batch_end                                                                                                                                                                                              	|  0.0045703      	|  15471          	|  70.707         	|  6.8299         	|
# |  [LightningModule]Model.training_step_end                                                                                                                                                                        	|  0.0020879      	|  15471          	|  32.301         	|  3.1201         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                                                                  	|  0.022605       	|  1415           	|  31.986         	|  3.0897         	|
# |  on_train_batch_start                                                                                                                                                                                            	|  0.00065768     	|  15471          	|  10.175         	|  0.98284        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                                                               	|  0.0047436      	|  1415           	|  6.7123         	|  0.64836        	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                                                                  	|  0.0003106      	|  16886          	|  5.2448         	|  0.50662        	|
# |  [LightningModule]Model.optimizer_zero_grad                                                                                                                                                                      	|  0.00024071     	|  15471          	|  3.724          	|  0.35972        	|
# |  [LightningModule]Model.validation_step_end                                                                                                                                                                      	|  0.002431       	|  1415           	|  3.4399         	|  0.33228        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                                                                   	|  0.043175       	|  10             	|  0.43175        	|  0.041705       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_batch_start                                                                                                                                    	|  1.7939e-05     	|  15471          	|  0.27754        	|  0.026809       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                                                                 	|  1.4938e-05     	|  15471          	|  0.23111        	|  0.022324       	|
# |  [Callback]TQDMProgressBar.on_batch_start                                                                                                                                                                        	|  1.3093e-05     	|  15471          	|  0.20256        	|  0.019566       	|
# |  [Callback]ModelSummary.on_batch_start                                                                                                                                                                           	|  1.2013e-05     	|  15471          	|  0.18585        	|  0.017952       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_batch_end                                                                                                                                      	|  1.0508e-05     	|  15471          	|  0.16256        	|  0.015703       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_start                     	|  1.0212e-05     	|  15471          	|  0.158          	|  0.015262       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                                                                               	|  9.7898e-06     	|  15471          	|  0.15146        	|  0.01463        	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                                                                     	|  9.4311e-06     	|  15471          	|  0.14591        	|  0.014094       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_start                                                                                                                                                          	|  9.3942e-06     	|  15471          	|  0.14534        	|  0.014039       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                                                             	|  8.792e-05      	|  1415           	|  0.12441        	|  0.012017       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                                                                                	|  7.7306e-06     	|  15471          	|  0.1196         	|  0.011553       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_end                       	|  7.4362e-06     	|  15471          	|  0.11504        	|  0.011113       	|
# |  [Callback]TQDMProgressBar.on_batch_end                                                                                                                                                                          	|  7.3346e-06     	|  15471          	|  0.11347        	|  0.010961       	|
# |  [LightningModule]Model.on_train_batch_start                                                                                                                                                                     	|  7.2084e-06     	|  15471          	|  0.11152        	|  0.010772       	|
# |  [Callback]ModelSummary.on_batch_end                                                                                                                                                                             	|  6.8693e-06     	|  15471          	|  0.10627        	|  0.010265       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                                                                        	|  6.8604e-06     	|  15471          	|  0.10614        	|  0.010252       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                                                                   	|  6.6147e-06     	|  15471          	|  0.10234        	|  0.0098851      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                                                                          	|  6.5559e-06     	|  15471          	|  0.10143        	|  0.0097971      	|
# |  [Callback]GradientAccumulationScheduler.on_after_backward                                                                                                                                                       	|  6.4805e-06     	|  15471          	|  0.10026        	|  0.0096846      	|
# |  [Callback]GradientAccumulationScheduler.on_batch_end                                                                                                                                                            	|  6.2774e-06     	|  15471          	|  0.097118       	|  0.009381       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_after_backward                  	|  6.2459e-06     	|  15471          	|  0.096631       	|  0.0093339      	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                                                                        	|  0.094863       	|  1              	|  0.094863       	|  0.0091632      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_zero_grad                	|  6.0117e-06     	|  15471          	|  0.093007       	|  0.0089839      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_backward                 	|  5.9367e-06     	|  15471          	|  0.091846       	|  0.0088718      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_end                 	|  0.010071       	|  9              	|  0.090637       	|  0.008755       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                                                                    	|  5.7881e-06     	|  15471          	|  0.089548       	|  0.0086498      	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                                                                       	|  5.7598e-06     	|  15471          	|  0.089111       	|  0.0086076      	|
# |  [Callback]GradientAccumulationScheduler.on_before_zero_grad                                                                                                                                                     	|  5.7241e-06     	|  15471          	|  0.088557       	|  0.0085541      	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                                                                      	|  5.6813e-06     	|  15471          	|  0.087896       	|  0.0084902      	|
# |  [Callback]GradientAccumulationScheduler.on_before_backward                                                                                                                                                      	|  5.3884e-06     	|  15471          	|  0.083364       	|  0.0080525      	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                                                              	|  5.2815e-06     	|  15471          	|  0.08171        	|  0.0078927      	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                                                                 	|  0.080444       	|  1              	|  0.080444       	|  0.0077704      	|
# |  [Callback]GradientAccumulationScheduler.on_before_optimizer_step                                                                                                                                                	|  5.1356e-06     	|  15471          	|  0.079453       	|  0.0076747      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_optimizer_step           	|  5.1284e-06     	|  15471          	|  0.079342       	|  0.007664       	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                                                                 	|  5.0537e-06     	|  15471          	|  0.078186       	|  0.0075523      	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                                                             	|  4.6168e-06     	|  15471          	|  0.071427       	|  0.0068994      	|
# |  [LightningModule]Model.on_train_batch_end                                                                                                                                                                       	|  4.4916e-06     	|  15471          	|  0.069489       	|  0.0067123      	|
# |  [Strategy]SingleDeviceStrategy.training_step_end                                                                                                                                                                	|  3.7312e-06     	|  15471          	|  0.057726       	|  0.005576       	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                                                                  	|  0.0060883      	|  9              	|  0.054795       	|  0.0052928      	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                                                                     	|  0.0044036      	|  10             	|  0.044036       	|  0.0042536      	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                                                                  	|  3.0484e-05     	|  1415           	|  0.043135       	|  0.0041666      	|
# |  [LightningModule]Model.on_after_backward                                                                                                                                                                        	|  2.7791e-06     	|  15471          	|  0.042995       	|  0.0041531      	|
# |  [LightningModule]Model.on_before_backward                                                                                                                                                                       	|  2.3516e-06     	|  15471          	|  0.036382       	|  0.0035143      	|
# |  [LightningModule]Model.on_before_zero_grad                                                                                                                                                                      	|  2.2216e-06     	|  15471          	|  0.034371       	|  0.00332        	|
# |  [LightningModule]Model.on_before_optimizer_step                                                                                                                                                                 	|  2.1045e-06     	|  15471          	|  0.032558       	|  0.003145       	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_start                                                                                                                                               	|  2.2432e-05     	|  1415           	|  0.031742       	|  0.0030661      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                                                                         	|  2.066e-05      	|  1415           	|  0.029234       	|  0.0028238      	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                                                             	|  0.026042       	|  1              	|  0.026042       	|  0.0025155      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                                                                                	|  0.0025392      	|  9              	|  0.022853       	|  0.0022074      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_end            	|  1.4988e-05     	|  1415           	|  0.021207       	|  0.0020485      	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                                                                	|  1.2564e-05     	|  1415           	|  0.017777       	|  0.0017172      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                                                                    	|  0.001752       	|  9              	|  0.015768       	|  0.0015231      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_end                                                                                                                                                 	|  1.0898e-05     	|  1415           	|  0.01542        	|  0.0014895      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_start          	|  1.0686e-05     	|  1415           	|  0.01512        	|  0.0014605      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                                                                           	|  8.9751e-06     	|  1415           	|  0.0127         	|  0.0012267      	|
# |  [LightningModule]Model.on_validation_batch_start                                                                                                                                                                	|  4.1048e-06     	|  1415           	|  0.0058083      	|  0.00056105     	|
# |  [Strategy]SingleDeviceStrategy.validation_step_end                                                                                                                                                              	|  3.6303e-06     	|  1415           	|  0.0051369      	|  0.00049619     	|
# |  [LightningModule]Model.on_validation_batch_end                                                                                                                                                                  	|  3.3238e-06     	|  1415           	|  0.0047031      	|  0.0004543      	|
# |  [LightningModule]Model.on_validation_model_train                                                                                                                                                                	|  0.00038458     	|  10             	|  0.0038458      	|  0.00037148     	|
# |  [LightningModule]Model.on_validation_model_eval                                                                                                                                                                 	|  0.000218       	|  10             	|  0.00218        	|  0.00021057     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_end                  	|  0.00014091     	|  10             	|  0.0014091      	|  0.00013611     	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                                                                          	|  0.0011128      	|  1              	|  0.0011128      	|  0.00010749     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                                                                      	|  6.479e-05      	|  10             	|  0.0006479      	|  6.2583e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_start                                                                                                                                                   	|  0.00044772     	|  1              	|  0.00044772     	|  4.3247e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_epoch_end                                                                                                                                      	|  1.7578e-05     	|  19             	|  0.00033398     	|  3.2261e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                                                                       	|  3.562e-05      	|  9              	|  0.00032058     	|  3.0966e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                                                                        	|  3.1521e-05     	|  10             	|  0.00031521     	|  3.0447e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.setup                              	|  0.00025678     	|  1              	|  0.00025678     	|  2.4804e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_end                                                                                                                                                            	|  1.1977e-05     	|  19             	|  0.00022756     	|  2.1981e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                                                                               	|  2.1693e-05     	|  10             	|  0.00021693     	|  2.0954e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                                                                     	|  2.2876e-05     	|  9              	|  0.00020589     	|  1.9887e-05     	|
# |  [LightningModule]Model.configure_optimizers                                                                                                                                                                     	|  0.0001787      	|  1              	|  0.0001787      	|  1.7261e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_epoch_start                                                                                                                                    	|  9.1784e-06     	|  19             	|  0.00017439     	|  1.6845e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_end                                                                                                                                 	|  1.7215e-05     	|  10             	|  0.00017215     	|  1.6628e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_start                                                                                                                                                    	|  1.8298e-05     	|  9              	|  0.00016468     	|  1.5907e-05     	|
# |  [Callback]TQDMProgressBar.on_epoch_end                                                                                                                                                                          	|  7.6978e-06     	|  19             	|  0.00014626     	|  1.4128e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                                                               	|  1.4491e-05     	|  10             	|  0.00014491     	|  1.3998e-05     	|
# |  [LightningModule]Model.on_epoch_start                                                                                                                                                                           	|  7.5777e-06     	|  19             	|  0.00014398     	|  1.3907e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_start                                                                                                                                                          	|  6.8797e-06     	|  19             	|  0.00013071     	|  1.2626e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_start                                                                                                                                                     	|  1.3034e-05     	|  10             	|  0.00013034     	|  1.259e-05      	|
# |  [Callback]TQDMProgressBar.on_epoch_start                                                                                                                                                                        	|  6.7241e-06     	|  19             	|  0.00012776     	|  1.2341e-05     	|
# |  [Callback]ModelSummary.on_epoch_end                                                                                                                                                                             	|  6.6082e-06     	|  19             	|  0.00012556     	|  1.2128e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_end                       	|  6.5673e-06     	|  19             	|  0.00012478     	|  1.2053e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_start                     	|  6.2478e-06     	|  19             	|  0.00011871     	|  1.1467e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_end                                                                                                                           	|  1.1434e-05     	|  10             	|  0.00011434     	|  1.1045e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_start                	|  1.121e-05      	|  10             	|  0.0001121      	|  1.0828e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_end                                                                                                                                                       	|  1.1132e-05     	|  10             	|  0.00011132     	|  1.0753e-05     	|
# |  [Callback]ModelSummary.on_epoch_start                                                                                                                                                                           	|  5.4825e-06     	|  19             	|  0.00010417     	|  1.0062e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_end                                                                                                                                                      	|  1.0704e-05     	|  9              	|  9.6338e-05     	|  9.3057e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_end            	|  9.4385e-06     	|  10             	|  9.4385e-05     	|  9.117e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_start               	|  9.0062e-06     	|  9              	|  8.1056e-05     	|  7.8295e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                                                                  	|  7.654e-06      	|  10             	|  7.654e-05      	|  7.3933e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_end                                                                                                                                                 	|  6.7581e-06     	|  10             	|  6.7581e-05     	|  6.5279e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_start                                                                                                                         	|  6.6193e-06     	|  10             	|  6.6193e-05     	|  6.3939e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                                                             	|  6.5567e-06     	|  10             	|  6.5567e-05     	|  6.3334e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_start              	|  6.5134e-05     	|  1              	|  6.5134e-05     	|  6.2916e-06     	|
# |  [LightningModule]Model.on_validation_epoch_end                                                                                                                                                                  	|  6.3101e-06     	|  10             	|  6.3101e-05     	|  6.0952e-06     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                                                                       	|  1.0263e-05     	|  6              	|  6.158e-05      	|  5.9483e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                                                                                	|  1.0004e-05     	|  6              	|  6.0027e-05     	|  5.7983e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_start          	|  5.5679e-06     	|  10             	|  5.5679e-05     	|  5.3783e-06     	|
# |  [LightningModule]Model.on_train_epoch_start                                                                                                                                                                     	|  6.1488e-06     	|  9              	|  5.5339e-05     	|  5.3454e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                                                                    	|  5.53e-05       	|  1              	|  5.53e-05       	|  5.3417e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                                                                	|  5.282e-06      	|  10             	|  5.282e-05      	|  5.1021e-06     	|
# |  [LightningModule]Model.on_train_epoch_end                                                                                                                                                                       	|  5.807e-06      	|  9              	|  5.2263e-05     	|  5.0483e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_save_checkpoint                                                                                                                                                      	|  8.704e-06      	|  6              	|  5.2224e-05     	|  5.0445e-06     	|
# |  [LightningModule]Model.validation_epoch_end                                                                                                                                                                     	|  5.0435e-06     	|  10             	|  5.0435e-05     	|  4.8717e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_start                                                                                                                                               	|  4.9998e-06     	|  10             	|  4.9998e-05     	|  4.8295e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                                                                              	|  5.2429e-06     	|  9              	|  4.7186e-05     	|  4.5579e-06     	|
# |  [LightningModule]Model.on_epoch_end                                                                                                                                                                             	|  2.4024e-06     	|  19             	|  4.5646e-05     	|  4.4091e-06     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                                                           	|  4.533e-05      	|  1              	|  4.533e-05      	|  4.3786e-06     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                                                                    	|  5.8962e-06     	|  6              	|  3.5377e-05     	|  3.4172e-06     	|
# |  [LightningModule]Model.on_validation_end                                                                                                                                                                        	|  3.4332e-06     	|  10             	|  3.4332e-05     	|  3.3163e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                                                                	|  2.9985e-06     	|  10             	|  2.9985e-05     	|  2.8964e-06     	|
# |  [LightningModule]Model.on_save_checkpoint                                                                                                                                                                       	|  4.9433e-06     	|  6              	|  2.966e-05      	|  2.865e-06      	|
# |  [LightningModule]Model.on_validation_start                                                                                                                                                                      	|  2.8826e-06     	|  10             	|  2.8826e-05     	|  2.7844e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                                                                      	|  2.8456e-05     	|  1              	|  2.8456e-05     	|  2.7487e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_save_checkpoint                 	|  4.693e-06      	|  6              	|  2.8158e-05     	|  2.7199e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                                                              	|  2.759e-06      	|  10             	|  2.759e-05      	|  2.665e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_start                     	|  2.5755e-05     	|  1              	|  2.5755e-05     	|  2.4878e-06     	|
# |  [LightningModule]Model.on_validation_epoch_start                                                                                                                                                                	|  2.3547e-06     	|  10             	|  2.3547e-05     	|  2.2745e-06     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                                                                   	|  2.2204e-05     	|  1              	|  2.2204e-05     	|  2.1448e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                                                                             	|  2.1144e-05     	|  1              	|  2.1144e-05     	|  2.0424e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                                                             	|  2.02e-05       	|  1              	|  2.02e-05       	|  1.9512e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_start                                                                                                                                                            	|  1.9313e-05     	|  1              	|  1.9313e-05     	|  1.8655e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_train_start                                                                                                                                                          	|  1.8056e-05     	|  1              	|  1.8056e-05     	|  1.7441e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                                                                          	|  1.6018e-05     	|  1              	|  1.6018e-05     	|  1.5472e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                                                                        	|  1.2208e-05     	|  1              	|  1.2208e-05     	|  1.1792e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                                                                               	|  1.1828e-05     	|  1              	|  1.1828e-05     	|  1.1425e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                                                                 	|  1.1639e-05     	|  1              	|  1.1639e-05     	|  1.1243e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_start                                                                                                                                    	|  1.0905e-05     	|  1              	|  1.0905e-05     	|  1.0534e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                                                                             	|  9.687e-06      	|  1              	|  9.687e-06      	|  9.3571e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_accelerator_backend_setup                                                                                                               	|  8.982e-06      	|  1              	|  8.982e-06      	|  8.6761e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_pretrain_routine_start                                                                                                                         	|  8.735e-06      	|  1              	|  8.735e-06      	|  8.4375e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_train_end                                                                                                                                                            	|  7.96e-06       	|  1              	|  7.96e-06       	|  7.6889e-07     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                                                                      	|  7.892e-06      	|  1              	|  7.892e-06      	|  7.6232e-07     	|
# |  [LightningModule]Model.configure_callbacks                                                                                                                                                                      	|  7.678e-06      	|  1              	|  7.678e-06      	|  7.4165e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_end                	|  7.623e-06      	|  1              	|  7.623e-06      	|  7.3634e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_end                                                                                                                                                     	|  7.397e-06      	|  1              	|  7.397e-06      	|  7.1451e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_end                       	|  7.375e-06      	|  1              	|  7.375e-06      	|  7.1238e-07     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                                                            	|  6.705e-06      	|  1              	|  6.705e-06      	|  6.4766e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_start                       	|  6.439e-06      	|  1              	|  6.439e-06      	|  6.2197e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                                                                      	|  6.282e-06      	|  1              	|  6.282e-06      	|  6.068e-07      	|
# |  [Callback]GradientAccumulationScheduler.on_fit_end                                                                                                                                                              	|  6.145e-06      	|  1              	|  6.145e-06      	|  5.9357e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_configure_sharded_model                                                                                                                        	|  6.03e-06       	|  1              	|  6.03e-06       	|  5.8246e-07     	|
# |  [Callback]ModelSummary.setup                                                                                                                                                                                    	|  5.683e-06      	|  1              	|  5.683e-06      	|  5.4894e-07     	|
# |  [LightningModule]Model.on_train_start                                                                                                                                                                           	|  5.618e-06      	|  1              	|  5.618e-06      	|  5.4267e-07     	|
# |  [Callback]TQDMProgressBar.on_configure_sharded_model                                                                                                                                                            	|  4.771e-06      	|  1              	|  4.771e-06      	|  4.6085e-07     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                                                               	|  4.759e-06      	|  1              	|  4.759e-06      	|  4.5969e-07     	|
# |  [Callback]GradientAccumulationScheduler.setup                                                                                                                                                                   	|  4.71e-06       	|  1              	|  4.71e-06       	|  4.5496e-07     	|
# |  [Callback]TQDMProgressBar.on_before_accelerator_backend_setup                                                                                                                                                   	|  4.692e-06      	|  1              	|  4.692e-06      	|  4.5322e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                                                                   	|  4.68e-06       	|  1              	|  4.68e-06       	|  4.5206e-07     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_start                                                                                                                                                             	|  4.495e-06      	|  1              	|  4.495e-06      	|  4.3419e-07     	|
# |  [LightningModule]Model.on_train_dataloader                                                                                                                                                                      	|  4.478e-06      	|  1              	|  4.478e-06      	|  4.3255e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_end                         	|  4.376e-06      	|  1              	|  4.376e-06      	|  4.227e-07      	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                                                                          	|  4.219e-06      	|  1              	|  4.219e-06      	|  4.0753e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_start          	|  4.192e-06      	|  1              	|  4.192e-06      	|  4.0492e-07     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_pretrain_routine_end                                                                                                                           	|  4.17e-06       	|  1              	|  4.17e-06       	|  4.028e-07      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.on_before_accelerator_backend_setup	|  4.052e-06      	|  1              	|  4.052e-06      	|  3.914e-07      	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                                                              	|  4.023e-06      	|  1              	|  4.023e-06      	|  3.886e-07      	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_end                                                                                                                                                 	|  3.912e-06      	|  1              	|  3.912e-06      	|  3.7788e-07     	|
# |  [Callback]ModelSummary.on_before_accelerator_backend_setup                                                                                                                                                      	|  3.831e-06      	|  1              	|  3.831e-06      	|  3.7005e-07     	|
# |  [LightningModule]Model.on_val_dataloader                                                                                                                                                                        	|  3.815e-06      	|  1              	|  3.815e-06      	|  3.6851e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_before_accelerator_backend_setup                                                                                                                                     	|  3.79e-06       	|  1              	|  3.79e-06       	|  3.6609e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_end            	|  3.764e-06      	|  1              	|  3.764e-06      	|  3.6358e-07     	|
# |  [Callback]ModelSummary.on_pretrain_routine_start                                                                                                                                                                	|  3.763e-06      	|  1              	|  3.763e-06      	|  3.6348e-07     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                                                                 	|  3.74e-06       	|  1              	|  3.74e-06       	|  3.6126e-07     	|
# |  [Callback]ModelSummary.on_configure_sharded_model                                                                                                                                                               	|  3.707e-06      	|  1              	|  3.707e-06      	|  3.5807e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_configure_sharded_model         	|  3.7e-06        	|  1              	|  3.7e-06        	|  3.574e-07      	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_start                                                                                                                                               	|  3.674e-06      	|  1              	|  3.674e-06      	|  3.5489e-07     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_end                                                                                                                                                               	|  3.515e-06      	|  1              	|  3.515e-06      	|  3.3953e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.teardown                           	|  3.444e-06      	|  1              	|  3.444e-06      	|  3.3267e-07     	|
# |  [LightningModule]Model.prepare_data                                                                                                                                                                             	|  3.397e-06      	|  1              	|  3.397e-06      	|  3.2813e-07     	|
# |  [Callback]ModelSummary.on_pretrain_routine_end                                                                                                                                                                  	|  3.361e-06      	|  1              	|  3.361e-06      	|  3.2465e-07     	|
# |  [Callback]GradientAccumulationScheduler.on_configure_sharded_model                                                                                                                                              	|  3.315e-06      	|  1              	|  3.315e-06      	|  3.2021e-07     	|
# |  [Callback]GradientAccumulationScheduler.teardown                                                                                                                                                                	|  3.142e-06      	|  1              	|  3.142e-06      	|  3.035e-07      	|
# |  [LightningModule]Model.on_fit_end                                                                                                                                                                               	|  3.09e-06       	|  1              	|  3.09e-06       	|  2.9848e-07     	|
# |  [LightningModule]Model.on_train_end                                                                                                                                                                             	|  3.075e-06      	|  1              	|  3.075e-06      	|  2.9703e-07     	|
# |  [LightningModule]Model.configure_sharded_model                                                                                                                                                                  	|  2.912e-06      	|  1              	|  2.912e-06      	|  2.8128e-07     	|
# |  [LightningModule]Model.setup                                                                                                                                                                                    	|  2.681e-06      	|  1              	|  2.681e-06      	|  2.5897e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                                                                     	|  2.507e-06      	|  1              	|  2.507e-06      	|  2.4216e-07     	|
# |  [LightningModule]Model.on_fit_start                                                                                                                                                                             	|  2.148e-06      	|  1              	|  2.148e-06      	|  2.0748e-07     	|
# |  [LightningModule]Model.on_pretrain_routine_end                                                                                                                                                                  	|  2.145e-06      	|  1              	|  2.145e-06      	|  2.0719e-07     	|
# |  [LightningModule]Model.on_pretrain_routine_start                                                                                                                                                                	|  1.893e-06      	|  1              	|  1.893e-06      	|  1.8285e-07     	|
# |  [LightningModule]Model.teardown                                                                                                                                                                                 	|  1.312e-06      	|  1              	|  1.312e-06      	|  1.2673e-07     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ```
# Epoch 8: 100%
# 1876/1876 [01:44<00:00, 17.93it/s, loss=0.0603, v_num=0, train_acc=1.000, val_acc=0.985]
# ```

# %% [markdown]
# ### 4，评估模型

# %%
result = trainer.test(model,data_mnist.train_dataloader(),ckpt_path='best')
# Out:
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=11-step=20627.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=11-step=20627.ckpt
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:662: UserWarning:
#
# Your `test_dataloader` has `shuffle=True`, it is strongly recommended that you turn this off for val/test/predict dataloaders.
# Testing: 0it [00:00, ?it/s]
# TEST Profiler Report
#
# Action                             	|  Mean duration (s)	|Num calls      	|  Total time (s) 	|  Percentage %   	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# Total                              	|  -              	|_              	|  404.7          	|  100 %          	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# run_training_epoch                 	|  21.814         	|15             	|  327.21         	|  80.853         	|
# run_training_batch                 	|  0.0076827      	|25785          	|  198.1          	|  48.949         	|
# optimizer_step_with_closure_0      	|  0.0072715      	|25785          	|  187.5          	|  46.329         	|
# training_step_and_backward         	|  0.0061708      	|25785          	|  159.11         	|  39.316         	|
# model_forward                      	|  0.0041915      	|25785          	|  108.08         	|  26.705         	|
# training_step_end                  	|  0.0028167      	|25785          	|  72.629         	|  17.946         	|
# on_train_batch_end                 	|  0.002178       	|25785          	|  56.159         	|  13.877         	|
# backward                           	|  0.0016287      	|25785          	|  41.995         	|  10.377         	|
# training_step                      	|  0.0011591      	|25785          	|  29.888         	|  7.3851         	|
# evaluation_step_and_end            	|  0.0044375      	|4546           	|  20.173         	|  4.9846         	|
# run_test_evaluation                	|  4.4232         	|3              	|  13.27          	|  3.2788         	|
# zero_grad                          	|  0.00031003     	|25785          	|  7.9942         	|  1.9753         	|
# get_train_batch                    	|  0.00030696     	|25800          	|  7.9194         	|  1.9568         	|
# on_train_batch_start               	|  0.0003015      	|25785          	|  7.7742         	|  1.921          	|
# training_batch_to_device           	|  0.00029603     	|25785          	|  7.633          	|  1.8861         	|
# validation_step_end                	|  0.0031315      	|2357           	|  7.3808         	|  1.8238         	|
# fetch_next_train_batch             	|  0.00028266     	|25800          	|  7.2927         	|  1.802          	|
# test_step_end                      	|  0.0029989      	|2189           	|  6.5646         	|  1.6221         	|
# validation_step                    	|  0.001317       	|2357           	|  3.1043         	|  0.76705        	|
# test_step                          	|  0.001246       	|2189           	|  2.7275         	|  0.67395        	|
# get_validate_batch                 	|  0.00083031     	|2370           	|  1.9678         	|  0.48624        	|
# fetch_next_validate_batch          	|  0.00080573     	|2370           	|  1.9096         	|  0.47184        	|
# evaluation_batch_to_device         	|  0.0003088      	|4546           	|  1.4038         	|  0.34687        	|
# on_batch_start                     	|  4.1352e-05     	|25785          	|  1.0663         	|  0.26346        	|
# on_batch_end                       	|  3.8432e-05     	|25785          	|  0.99096        	|  0.24486        	|
# on_before_zero_grad                	|  3.8268e-05     	|25785          	|  0.98675        	|  0.24382        	|
# on_after_backward                  	|  3.6081e-05     	|25785          	|  0.93036        	|  0.22989        	|
# on_before_backward                 	|  3.2031e-05     	|25785          	|  0.82592        	|  0.20408        	|
# on_before_optimizer_step           	|  3.0111e-05     	|25785          	|  0.77642        	|  0.19185        	|
# get_test_batch                     	|  0.00034506     	|2192           	|  0.75637        	|  0.18689        	|
# on_validation_batch_end            	|  0.00030486     	|2357           	|  0.71855        	|  0.17755        	|
# fetch_next_test_batch              	|  0.00032118     	|2192           	|  0.70402        	|  0.17396        	|
# on_validation_start                	|  0.034396       	|16             	|  0.55034        	|  0.13598        	|
# on_test_batch_end                  	|  0.00015042     	|2189           	|  0.32926        	|  0.081358       	|
# on_test_start                      	|  0.032437       	|3              	|  0.097312       	|  0.024045       	|
# on_validation_batch_start          	|  3.8675e-05     	|2357           	|  0.091158       	|  0.022525       	|
# on_train_epoch_end                 	|  0.0055654      	|15             	|  0.083482       	|  0.020628       	|
# on_test_batch_start                	|  3.6226e-05     	|2189           	|  0.079299       	|  0.019594       	|
# on_validation_end                  	|  0.0030449      	|16             	|  0.048719       	|  0.012038       	|
# on_train_epoch_start               	|  0.0026013      	|15             	|  0.03902        	|  0.0096415      	|
# on_train_start                     	|  0.036383       	|1              	|  0.036383       	|  0.0089901      	|
# on_sanity_check_start              	|  0.034045       	|1              	|  0.034045       	|  0.0084122      	|
# get_sanity_check_batch             	|  0.0064563      	|3              	|  0.019369       	|  0.0047859      	|
# fetch_next_sanity_check_batch      	|  0.0064196      	|3              	|  0.019259       	|  0.0047587      	|
# on_pretrain_routine_start          	|  0.0055585      	|1              	|  0.0055585      	|  0.0013735      	|
# on_test_end                        	|  0.0017212      	|3              	|  0.0051637      	|  0.0012759      	|
# on_validation_model_eval           	|  0.00027574     	|16             	|  0.0044118      	|  0.0010901      	|
# on_train_end                       	|  0.0012372      	|1              	|  0.0012372      	|  0.00030571     	|
# on_epoch_start                     	|  3.4914e-05     	|34             	|  0.0011871      	|  0.00029332     	|
# on_epoch_end                       	|  3.2898e-05     	|34             	|  0.0011185      	|  0.00027638     	|
# on_validation_epoch_end            	|  4.788e-05      	|16             	|  0.00076608     	|  0.00018929     	|
# on_test_model_eval                 	|  0.0002197      	|3              	|  0.00065911     	|  0.00016286     	|
# on_validation_epoch_start          	|  3.1486e-05     	|16             	|  0.00050377     	|  0.00012448     	|
# configure_optimizers               	|  0.00027334     	|1              	|  0.00027334     	|  6.7542e-05     	|
# on_configure_sharded_model         	|  4.7993e-05     	|4              	|  0.00019197     	|  4.7435e-05     	|
# teardown                           	|  4.1536e-05     	|4              	|  0.00016614     	|  4.1053e-05     	|
# on_before_accelerator_backend_setup	|  3.8753e-05     	|4              	|  0.00015501     	|  3.8303e-05     	|
# on_test_epoch_end                  	|  4.8818e-05     	|3              	|  0.00014645     	|  3.6188e-05     	|
# setup                              	|  3.5844e-05     	|4              	|  0.00014338     	|  3.5427e-05     	|
# on_test_epoch_start                	|  3.1454e-05     	|3              	|  9.4362e-05     	|  2.3316e-05     	|
# on_sanity_check_end                	|  6.0066e-05     	|1              	|  6.0066e-05     	|  1.4842e-05     	|
# configure_callbacks                	|  1.4934e-05     	|4              	|  5.9735e-05     	|  1.476e-05      	|
# configure_sharded_model            	|  1.4916e-05     	|4              	|  5.9664e-05     	|  1.4743e-05     	|
# on_fit_end                         	|  5.3426e-05     	|1              	|  5.3426e-05     	|  1.3201e-05     	|
# on_test_dataloader                 	|  1.5845e-05     	|3              	|  4.7536e-05     	|  1.1746e-05     	|
# on_fit_start                       	|  4.3138e-05     	|1              	|  4.3138e-05     	|  1.0659e-05     	|
# on_pretrain_routine_end            	|  3.9236e-05     	|1              	|  3.9236e-05     	|  9.6949e-06     	|
# prepare_data                       	|  8.8867e-06     	|4              	|  3.5547e-05     	|  8.7834e-06     	|
# on_train_dataloader                	|  1.6958e-05     	|1              	|  1.6958e-05     	|  4.1901e-06     	|
# on_val_dataloader                  	|  9.2648e-06     	|1              	|  9.2648e-06     	|  2.2893e-06     	|
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9966545701026917, 'test_loss': 0.010617421939969063}
# --------------------------------------------------------------------------------

# %% [markdown]
# ```
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9966545701026917, 'test_loss': 0.010617421939969063}
# --------------------------------------------------------------------------------
# ```

# %%
result = trainer.test(model,data_mnist.val_dataloader(),ckpt_path='best')
# Out:
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning:
#
# DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=11-step=20627.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=11-step=20627.ckpt
# Testing: 0it [00:00, ?it/s]
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning:
#
# DataModule.teardown has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.teardown.
#
# TEST Profiler Report
#
# Action                             	|  Mean duration (s)	|Num calls      	|  Total time (s) 	|  Percentage %   	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# Total                              	|  -              	|_              	|  371.98         	|  100 %          	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# run_training_epoch                 	|  21.814         	|15             	|  327.21         	|  87.966         	|
# run_training_batch                 	|  0.0076827      	|25785          	|  198.1          	|  53.255         	|
# optimizer_step_with_closure_0      	|  0.0072715      	|25785          	|  187.5          	|  50.405         	|
# training_step_and_backward         	|  0.0061708      	|25785          	|  159.11         	|  42.775         	|
# model_forward                      	|  0.0041915      	|25785          	|  108.08         	|  29.055         	|
# training_step_end                  	|  0.0028167      	|25785          	|  72.629         	|  19.525         	|
# on_train_batch_end                 	|  0.002178       	|25785          	|  56.159         	|  15.097         	|
# backward                           	|  0.0016287      	|25785          	|  41.995         	|  11.29          	|
# training_step                      	|  0.0011591      	|25785          	|  29.888         	|  8.0349         	|
# evaluation_step_and_end            	|  0.004534       	|2827           	|  12.818         	|  3.4458         	|
# zero_grad                          	|  0.00031003     	|25785          	|  7.9942         	|  2.1491         	|
# get_train_batch                    	|  0.00030696     	|25800          	|  7.9194         	|  2.129          	|
# on_train_batch_start               	|  0.0003015      	|25785          	|  7.7742         	|  2.09           	|
# training_batch_to_device           	|  0.00029603     	|25785          	|  7.633          	|  2.052          	|
# validation_step_end                	|  0.0031315      	|2357           	|  7.3808         	|  1.9842         	|
# fetch_next_train_batch             	|  0.00028266     	|25800          	|  7.2927         	|  1.9605         	|
# run_test_evaluation                	|  1.7593         	|2              	|  3.5187         	|  0.94594        	|
# validation_step                    	|  0.001317       	|2357           	|  3.1043         	|  0.83454        	|
# get_validate_batch                 	|  0.00083031     	|2370           	|  1.9678         	|  0.52902        	|
# fetch_next_validate_batch          	|  0.00080573     	|2370           	|  1.9096         	|  0.51336        	|
# test_step_end                      	|  0.0030928      	|470            	|  1.4536         	|  0.39079        	|
# on_batch_start                     	|  4.1352e-05     	|25785          	|  1.0663         	|  0.28664        	|
# on_batch_end                       	|  3.8432e-05     	|25785          	|  0.99096        	|  0.2664         	|
# on_before_zero_grad                	|  3.8268e-05     	|25785          	|  0.98675        	|  0.26527        	|
# on_after_backward                  	|  3.6081e-05     	|25785          	|  0.93036        	|  0.25011        	|
# evaluation_batch_to_device         	|  0.00031589     	|2827           	|  0.89301        	|  0.24007        	|
# on_before_backward                 	|  3.2031e-05     	|25785          	|  0.82592        	|  0.22203        	|
# on_before_optimizer_step           	|  3.0111e-05     	|25785          	|  0.77642        	|  0.20873        	|
# on_validation_batch_end            	|  0.00030486     	|2357           	|  0.71855        	|  0.19317        	|
# test_step                          	|  0.0013339      	|470            	|  0.62694        	|  0.16854        	|
# on_validation_start                	|  0.034396       	|16             	|  0.55034        	|  0.14795        	|
# get_test_batch                     	|  0.00067238     	|472            	|  0.31736        	|  0.085318       	|
# fetch_next_test_batch              	|  0.0006473      	|472            	|  0.30552        	|  0.082135       	|
# on_validation_batch_start          	|  3.8675e-05     	|2357           	|  0.091158       	|  0.024506       	|
# on_train_epoch_end                 	|  0.0055654      	|15             	|  0.083482       	|  0.022443       	|
# on_test_batch_end                  	|  0.00016392     	|470            	|  0.077042       	|  0.020711       	|
# on_test_start                      	|  0.032143       	|2              	|  0.064287       	|  0.017282       	|
# on_validation_end                  	|  0.0030449      	|16             	|  0.048719       	|  0.013097       	|
# on_train_epoch_start               	|  0.0026013      	|15             	|  0.03902        	|  0.01049        	|
# on_train_start                     	|  0.036383       	|1              	|  0.036383       	|  0.009781       	|
# on_sanity_check_start              	|  0.034045       	|1              	|  0.034045       	|  0.0091523      	|
# get_sanity_check_batch             	|  0.0064563      	|3              	|  0.019369       	|  0.005207       	|
# fetch_next_sanity_check_batch      	|  0.0064196      	|3              	|  0.019259       	|  0.0051774      	|
# on_test_batch_start                	|  3.7254e-05     	|470            	|  0.01751        	|  0.0047072      	|
# on_pretrain_routine_start          	|  0.0055585      	|1              	|  0.0055585      	|  0.0014943      	|
# on_validation_model_eval           	|  0.00027574     	|16             	|  0.0044118      	|  0.001186       	|
# on_test_end                        	|  0.0020979      	|2              	|  0.0041958      	|  0.001128       	|
# on_train_end                       	|  0.0012372      	|1              	|  0.0012372      	|  0.00033261     	|
# on_epoch_start                     	|  3.4934e-05     	|33             	|  0.0011528      	|  0.00030992     	|
# on_epoch_end                       	|  3.3019e-05     	|33             	|  0.0010896      	|  0.00029293     	|
# on_validation_epoch_end            	|  4.788e-05      	|16             	|  0.00076608     	|  0.00020595     	|
# on_validation_epoch_start          	|  3.1486e-05     	|16             	|  0.00050377     	|  0.00013543     	|
# on_test_model_eval                 	|  0.00021777     	|2              	|  0.00043555     	|  0.00011709     	|
# configure_optimizers               	|  0.00027334     	|1              	|  0.00027334     	|  7.3484e-05     	|
# on_configure_sharded_model         	|  4.8459e-05     	|3              	|  0.00014538     	|  3.9082e-05     	|
# teardown                           	|  4.0405e-05     	|3              	|  0.00012122     	|  3.2587e-05     	|
# on_before_accelerator_backend_setup	|  3.8253e-05     	|3              	|  0.00011476     	|  3.0851e-05     	|
# setup                              	|  3.7334e-05     	|3              	|  0.000112       	|  3.011e-05      	|
# on_test_epoch_end                  	|  4.7239e-05     	|2              	|  9.4477e-05     	|  2.5399e-05     	|
# on_test_epoch_start                	|  3.185e-05      	|2              	|  6.37e-05       	|  1.7125e-05     	|
# on_sanity_check_end                	|  6.0066e-05     	|1              	|  6.0066e-05     	|  1.6148e-05     	|
# on_fit_end                         	|  5.3426e-05     	|1              	|  5.3426e-05     	|  1.4363e-05     	|
# configure_callbacks                	|  1.5653e-05     	|3              	|  4.696e-05      	|  1.2624e-05     	|
# configure_sharded_model            	|  1.4702e-05     	|3              	|  4.4105e-05     	|  1.1857e-05     	|
# on_fit_start                       	|  4.3138e-05     	|1              	|  4.3138e-05     	|  1.1597e-05     	|
# on_pretrain_routine_end            	|  3.9236e-05     	|1              	|  3.9236e-05     	|  1.0548e-05     	|
# on_test_dataloader                 	|  1.6155e-05     	|2              	|  3.2309e-05     	|  8.6859e-06     	|
# prepare_data                       	|  8.8324e-06     	|3              	|  2.6497e-05     	|  7.1233e-06     	|
# on_train_dataloader                	|  1.6958e-05     	|1              	|  1.6958e-05     	|  4.5587e-06     	|
# on_val_dataloader                  	|  9.2648e-06     	|1              	|  9.2648e-06     	|  2.4907e-06     	|
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9865999817848206, 'test_loss': 0.042671505361795425}
# --------------------------------------------------------------------------------

# %% [markdown]
# ```
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9865999817848206, 'test_loss': 0.042671505361795425}
# --------------------------------------------------------------------------------
# ```

# %%
result = trainer.test(model,data_mnist.test_dataloader(),ckpt_path='best')
# Out:
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=11-step=20627.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=11-step=20627.ckpt
# Testing: 0it [00:00, ?it/s]
# TEST Profiler Report
#
# Action                             	|  Mean duration (s)	|Num calls      	|  Total time (s) 	|  Percentage %   	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# Total                              	|  -              	|_              	|  421.76         	|  100 %          	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# run_training_epoch                 	|  21.814         	|15             	|  327.21         	|  77.583         	|
# run_training_batch                 	|  0.0076827      	|25785          	|  198.1          	|  46.97          	|
# optimizer_step_with_closure_0      	|  0.0072715      	|25785          	|  187.5          	|  44.456         	|
# training_step_and_backward         	|  0.0061708      	|25785          	|  159.11         	|  37.726         	|
# model_forward                      	|  0.0041915      	|25785          	|  108.08         	|  25.625         	|
# training_step_end                  	|  0.0028167      	|25785          	|  72.629         	|  17.221         	|
# on_train_batch_end                 	|  0.002178       	|25785          	|  56.159         	|  13.316         	|
# backward                           	|  0.0016287      	|25785          	|  41.995         	|  9.9573         	|
# training_step                      	|  0.0011591      	|25785          	|  29.888         	|  7.0865         	|
# evaluation_step_and_end            	|  0.0044129      	|4859           	|  21.442         	|  5.084          	|
# run_test_evaluation                	|  3.8129         	|4              	|  15.252         	|  3.6162         	|
# zero_grad                          	|  0.00031003     	|25785          	|  7.9942         	|  1.8955         	|
# get_train_batch                    	|  0.00030696     	|25800          	|  7.9194         	|  1.8777         	|
# on_train_batch_start               	|  0.0003015      	|25785          	|  7.7742         	|  1.8433         	|
# training_batch_to_device           	|  0.00029603     	|25785          	|  7.633          	|  1.8098         	|
# test_step_end                      	|  0.0029875      	|2502           	|  7.4748         	|  1.7723         	|
# validation_step_end                	|  0.0031315      	|2357           	|  7.3808         	|  1.75           	|
# fetch_next_train_batch             	|  0.00028266     	|25800          	|  7.2927         	|  1.7291         	|
# validation_step                    	|  0.001317       	|2357           	|  3.1043         	|  0.73604        	|
# test_step                          	|  0.0012236      	|2502           	|  3.0615         	|  0.72589        	|
# get_validate_batch                 	|  0.00083031     	|2370           	|  1.9678         	|  0.46658        	|
# fetch_next_validate_batch          	|  0.00080573     	|2370           	|  1.9096         	|  0.45277        	|
# evaluation_batch_to_device         	|  0.00030573     	|4859           	|  1.4855         	|  0.35222        	|
# on_batch_start                     	|  4.1352e-05     	|25785          	|  1.0663         	|  0.25281        	|
# on_batch_end                       	|  3.8432e-05     	|25785          	|  0.99096        	|  0.23496        	|
# on_before_zero_grad                	|  3.8268e-05     	|25785          	|  0.98675        	|  0.23396        	|
# on_after_backward                  	|  3.6081e-05     	|25785          	|  0.93036        	|  0.22059        	|
# get_test_batch                     	|  0.00035842     	|2506           	|  0.89821        	|  0.21297        	|
# fetch_next_test_batch              	|  0.00033491     	|2506           	|  0.83928        	|  0.199          	|
# on_before_backward                 	|  3.2031e-05     	|25785          	|  0.82592        	|  0.19583        	|
# on_before_optimizer_step           	|  3.0111e-05     	|25785          	|  0.77642        	|  0.18409        	|
# on_validation_batch_end            	|  0.00030486     	|2357           	|  0.71855        	|  0.17037        	|
# on_validation_start                	|  0.034396       	|16             	|  0.55034        	|  0.13049        	|
# on_test_batch_end                  	|  0.00014831     	|2502           	|  0.37107        	|  0.087982       	|
# on_test_start                      	|  0.031928       	|4              	|  0.12771        	|  0.030281       	|
# on_validation_batch_start          	|  3.8675e-05     	|2357           	|  0.091158       	|  0.021614       	|
# on_test_batch_start                	|  3.5954e-05     	|2502           	|  0.089957       	|  0.021329       	|
# on_train_epoch_end                 	|  0.0055654      	|15             	|  0.083482       	|  0.019794       	|
# on_validation_end                  	|  0.0030449      	|16             	|  0.048719       	|  0.011551       	|
# on_train_epoch_start               	|  0.0026013      	|15             	|  0.03902        	|  0.0092517      	|
# on_train_start                     	|  0.036383       	|1              	|  0.036383       	|  0.0086266      	|
# on_sanity_check_start              	|  0.034045       	|1              	|  0.034045       	|  0.0080721      	|
# get_sanity_check_batch             	|  0.0064563      	|3              	|  0.019369       	|  0.0045924      	|
# fetch_next_sanity_check_batch      	|  0.0064196      	|3              	|  0.019259       	|  0.0045663      	|
# on_test_end                        	|  0.0017795      	|4              	|  0.0071179      	|  0.0016877      	|
# on_pretrain_routine_start          	|  0.0055585      	|1              	|  0.0055585      	|  0.0013179      	|
# on_validation_model_eval           	|  0.00027574     	|16             	|  0.0044118      	|  0.0010461      	|
# on_train_end                       	|  0.0012372      	|1              	|  0.0012372      	|  0.00029335     	|
# on_epoch_start                     	|  3.4778e-05     	|35             	|  0.0012172      	|  0.00028861     	|
# on_epoch_end                       	|  3.2773e-05     	|35             	|  0.0011471      	|  0.00027197     	|
# on_test_model_eval                 	|  0.00021448     	|4              	|  0.00085791     	|  0.00020341     	|
# on_validation_epoch_end            	|  4.788e-05      	|16             	|  0.00076608     	|  0.00018164     	|
# on_validation_epoch_start          	|  3.1486e-05     	|16             	|  0.00050377     	|  0.00011945     	|
# configure_optimizers               	|  0.00027334     	|1              	|  0.00027334     	|  6.4811e-05     	|
# on_configure_sharded_model         	|  4.8502e-05     	|5              	|  0.00024251     	|  5.75e-05       	|
# teardown                           	|  4.0765e-05     	|5              	|  0.00020383     	|  4.8328e-05     	|
# on_test_epoch_end                  	|  4.7728e-05     	|4              	|  0.00019091     	|  4.5266e-05     	|
# on_before_accelerator_backend_setup	|  3.8085e-05     	|5              	|  0.00019042     	|  4.515e-05      	|
# setup                              	|  3.4354e-05     	|5              	|  0.00017177     	|  4.0728e-05     	|
# on_test_epoch_start                	|  3.0808e-05     	|4              	|  0.00012323     	|  2.9219e-05     	|
# configure_sharded_model            	|  1.4956e-05     	|5              	|  7.4778e-05     	|  1.773e-05      	|
# configure_callbacks                	|  1.4231e-05     	|5              	|  7.1157e-05     	|  1.6872e-05     	|
# on_test_dataloader                 	|  1.6113e-05     	|4              	|  6.4451e-05     	|  1.5282e-05     	|
# on_sanity_check_end                	|  6.0066e-05     	|1              	|  6.0066e-05     	|  1.4242e-05     	|
# on_fit_end                         	|  5.3426e-05     	|1              	|  5.3426e-05     	|  1.2668e-05     	|
# prepare_data                       	|  8.9305e-06     	|5              	|  4.4652e-05     	|  1.0587e-05     	|
# on_fit_start                       	|  4.3138e-05     	|1              	|  4.3138e-05     	|  1.0228e-05     	|
# on_pretrain_routine_end            	|  3.9236e-05     	|1              	|  3.9236e-05     	|  9.3029e-06     	|
# on_train_dataloader                	|  1.6958e-05     	|1              	|  1.6958e-05     	|  4.0207e-06     	|
# on_val_dataloader                  	|  9.2648e-06     	|1              	|  9.2648e-06     	|  2.1967e-06     	|
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.987500011920929, 'test_loss': 0.047178059816360474}
# --------------------------------------------------------------------------------

# %% [markdown]
# ```
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.987500011920929, 'test_loss': 0.047178059816360474}
# --------------------------------------------------------------------------------
# ```

# %% [markdown]
# ### 5，使用模型

# %%
data,label = next(iter(data_module.test_dataloader()))
model.eval()
prediction = model(data)
print(prediction)
# Out:
# tensor([[-13.0112,  -2.8257,  -1.8588,  -3.6137,  -0.3307,  -5.4953, -19.7282,
#           15.9651,  -8.0379,  -2.2925],
#         [ -6.0261,  -2.5480,  13.4140,  -5.5701, -10.2049,  -6.4469,  -3.7119,
#           -6.0732,  -6.0826,  -7.7339],
#         [ -5.1793,   8.9197,  -7.2543, -13.2983,  -5.0533,  -6.4719,  -3.7550,
#           -6.6116,  -6.1681, -11.3888],
#         [ 14.4084,  -9.3049,  -0.2826,  -5.9594, -10.0195,  -1.9158,   3.8159,
#          -10.0758,  -1.9282,  -5.2118],
#         [ -9.4577,  -4.3220, -10.3566, -15.9498,  11.8866,  -7.0987,  -7.1806,
#           -1.5529,  -6.9066,   2.5904],
#         [ -8.8615,  11.8241,  -8.4843, -16.3067,  -5.3663,  -7.3302,  -6.5410,
#           -3.8980,  -8.0192, -10.7459],
#         [ -7.5349,  -2.6864,  -8.1347, -11.1265,   8.3502,  -2.3806,  -5.2649,
#           -3.3453,  -2.2118,  -2.6089],
#         [ -7.0058,  -9.8076,  -1.7974,  -4.9063,  -0.0970,  -2.0131,  -4.3724,
#           -6.8718,   1.4275,   8.6853],
#         [ -3.9027,  -9.7034,   0.1843,  -0.4189,  -6.5177,   5.7285,  -0.9670,
#           -8.5215,  -1.2326,  -4.2621],
#         [ -5.9817, -12.8820,  -2.9370, -11.9836,  -1.7086,  -1.5813, -14.7753,
#            0.4480,   1.3776,  11.3914],
#         [ 16.8340,  -8.0244,  -0.7741,  -5.0373, -11.2885,  -3.0471,   1.0007,
#           -7.0407,  -1.2350,  -6.8061],
#         [  6.8250, -12.7335,   0.1518,  -7.4281, -12.0778,   0.2939,  20.9634,
#          -20.7821,   3.9082,  -9.5157],
#         [ -8.0805, -13.0810,  -4.6054, -10.2063,  -0.9193,  -4.6293, -11.5931,
#           -4.6349,   2.1769,  15.3276],
#         [ 13.7328,  -3.8627,  -4.0112,  -7.9956,  -9.7883,  -6.5610,  -2.8990,
#           -4.4617,  -3.1956,  -2.7883],
#         [ -3.1513,  11.1374,  -5.1134,  -5.2249,  -6.0831,  -3.9673,  -7.4346,
#           -4.5471,  -4.4011,  -8.6621],
#         [ -9.6877, -15.3236,  -1.2526,   4.5638,  -7.1031,  15.3295,  -7.1941,
#           -2.5545,  -3.3236,  -7.0454],
#         [ -1.3276, -12.8454,  -3.9938, -10.3719,  -2.7715,  -5.6029,  -6.2417,
#           -3.1272,   2.6297,  10.1432],
#         [ -5.7811,  -8.4391,  -0.4687,  -3.7991,  -3.6599,  -1.2870, -19.4970,
#           16.7608,  -9.3972,  -4.0588],
#         [ -5.3566,  -7.7389,   5.9662,  12.1440,  -8.3407,   1.1119,  -6.9031,
#           -6.4835,   4.3029,  -1.3591],
#         [ -9.5364,  -4.2172, -10.2173, -13.0270,  15.0092,  -2.6132,  -5.0676,
#           -2.7529,  -4.0657,  -4.2093],
#         [-15.8513,  -3.5621,  -6.6063,  -6.6193,   0.8588,  -3.8259, -14.1176,
#            0.7407,  -4.0745,  11.5699],
#         [ -0.8086, -11.0222,  -1.0758,  -8.4852, -12.8985,   7.2650,  19.9413,
#          -17.6839,   2.1309, -10.0899],
#         [  0.2642, -14.5380,  -6.8190, -11.9187,  -5.3507,   1.6481,  14.2073,
#          -18.0123,   4.7929,  -5.3580],
#         [ -9.0779, -15.1762,  -9.6641,   1.0906, -12.2709,  20.9257,  -4.5509,
#          -10.3599,  -1.9897,  -4.2746],
#         [ -6.6996,  -4.9878,  -7.9854, -11.2790,  10.4383,  -5.9630,  -4.8909,
#           -3.5206,  -3.8640,   0.2913],
#         [ 17.2738, -11.7963,  -1.6868,  -9.3057,  -9.3189,  -5.6459,   0.5775,
#           -8.4094,  -0.2450,  -3.6427],
#         [ -4.8818,  -8.1715,   2.8342,   1.0672,  -4.5164,  -1.5684, -11.8290,
#            9.5152,  -4.6545,  -3.0746],
#         [ -6.3762,  -4.2479,  -9.9438, -16.4484,  16.2417,  -4.5141,  -7.3567,
#           -3.2876,  -5.0833,  -2.4909],
#         [ 16.5702,  -4.3689,  -0.7699,  -5.4350, -10.6765,  -6.3137,  -1.3944,
#           -7.6100,  -1.2885,  -4.8424],
#         [ -2.9474,  10.0741,  -4.6694,  -6.3517,  -3.6757,  -3.3109,  -8.0018,
#           -3.7477,  -3.9049,  -7.0626],
#         [-16.7028,  -4.9060,   0.4400,  24.4337, -12.8793,   1.5085, -17.9232,
#           -3.0839,   0.5491,   1.9846],
#         [ -5.0909,  10.1805,  -8.2528,  -9.2240,  -1.8044,  -4.0296,  -8.2297,
#           -3.1828,  -5.9361,  -4.8410]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ```
# tensor([[-13.0112,  -2.8257,  -1.8588,  -3.6137,  -0.3307,  -5.4953, -19.7282,
#           15.9651,  -8.0379,  -2.2925],
#         [ -6.0261,  -2.5480,  13.4140,  -5.5701, -10.2049,  -6.4469,  -3.7119,
#           -6.0732,  -6.0826,  -7.7339],
#           ...
#         [-16.7028,  -4.9060,   0.4400,  24.4337, -12.8793,   1.5085, -17.9232,
#           -3.0839,   0.5491,   1.9846],
#         [ -5.0909,  10.1805,  -8.2528,  -9.2240,  -1.8044,  -4.0296,  -8.2297,
#           -3.1828,  -5.9361,  -4.8410]], grad_fn=<AddmmBackward0>)
# ```

# %% [markdown]
# ### 6，保存模型

# %% [markdown]
# 最优模型默认保存在 trainer.checkpoint_callback.best_model_path 的目录下，可以直接加载。

# %%
print(trainer.checkpoint_callback.best_model_path)
print(trainer.checkpoint_callback.best_model_score)
# Out:
# /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_10/checkpoints/epoch=8-step=15470.ckpt
# tensor(0.0376, device='cuda:0')

# %% [markdown]
# ```
# lightning_logs/version_10/checkpoints/epoch=8-step=15470.ckpt
# tensor(0.0376, device='cuda:0')
# ```

# %%
model_clone = Model.load_from_checkpoint(trainer.checkpoint_callback.best_model_path)
trainer_clone = pl.Trainer(max_epochs=3,gpus=1) 
result = trainer_clone.test(model_clone,data_module.test_dataloader())
print(result)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Testing: 0it [00:00, ?it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9887999892234802, 'test_loss': 0.03627564385533333}
# --------------------------------------------------------------------------------
# [{'test_acc': 0.9887999892234802, 'test_loss': 0.03627564385533333}]

# %% [markdown]
# ```
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9887999892234802, 'test_loss': 0.03627564385533333}
# --------------------------------------------------------------------------------
# [{'test_acc': 0.9887999892234802, 'test_loss': 0.03627564385533333}]
# ```

# %% [markdown]
# ## 三，训练加速技巧

# %% [markdown]
# 下面重点介绍pytorch_lightning 模型训练加速的一些技巧。
#
# * 1，使用多进程读取数据(num_workers=4)
#
# * 2，使用锁业内存(pin_memory=True)
#
# * 3，使用加速器(gpus=4,strategy="ddp_find_unused_parameters_false")
#
# * 4，使用梯度累加(accumulate_grad_batches=6)
#
# * 5，使用半精度(precision=16,batch_size=`2*batch_size`)
#
# * 6，自动搜索最大batch_size(auto_scale_batch_size='binsearch')
#
# （注：过大的batch_size对模型学习是有害的。）
#
# 详细原理，可以参考：
#
# https://pytorch-lightning.readthedocs.io/en/latest/common/trainer.html
#
# 我们将训练代码封装成如下脚本形式，方便后面测试使用。

# %%
# %%writefile mnist_cnn.py
import torch 
from torch import nn 
from argparse import ArgumentParser

import torchvision 
from torchvision import transforms as T
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader,random_split
import pytorch_lightning as pl
from torchmetrics import Accuracy

#================================================================================
# 一，准备数据
#================================================================================

class MNISTDataModule(pl.LightningDataModule):
    def __init__(self, data_dir: str = "./minist/", 
                 batch_size: int = 32,
                 num_workers: int =4,
                 pin_memory:bool =True):
        super().__init__()
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.pin_memory = pin_memory

    def setup(self, stage = None):
        transform = T.Compose([T.ToTensor()])
        self.ds_test = MNIST(self.data_dir, download=True,train=False,transform=transform)
        self.ds_predict = MNIST(self.data_dir, download=True, train=False,transform=transform)
        ds_full = MNIST(self.data_dir, download=True, train=True,transform=transform)
        self.ds_train, self.ds_val = random_split(ds_full, [55000, 5000])

    def train_dataloader(self):
        return DataLoader(self.ds_train, batch_size=self.batch_size,
                          shuffle=True, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)

    def val_dataloader(self):
        return DataLoader(self.ds_val, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)

    def test_dataloader(self):
        return DataLoader(self.ds_test, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)

    def predict_dataloader(self):
        return DataLoader(self.ds_predict, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)
    
    @staticmethod
    def add_dataset_args(parent_parser):
        parser = ArgumentParser(parents=[parent_parser], add_help=False)
        parser.add_argument('--batch_size', type=int, default=32)
        parser.add_argument('--num_workers', type=int, default=4)
        parser.add_argument('--pin_memory', type=bool, default=True)
        return parser

#================================================================================
# 二，定义模型
#================================================================================

net = nn.Sequential(
    nn.Conv2d(in_channels=1,out_channels=32,kernel_size = 3),
    nn.MaxPool2d(kernel_size = 2,stride = 2),
    nn.Conv2d(in_channels=32,out_channels=64,kernel_size = 5),
    nn.MaxPool2d(kernel_size = 2,stride = 2),
    nn.Dropout2d(p = 0.1),
    nn.AdaptiveMaxPool2d((1,1)),
    nn.Flatten(),
    nn.Linear(64,32),
    nn.ReLU(),
    nn.Linear(32,10)
)

class Model(pl.LightningModule):
    
    def __init__(self,net,learning_rate=1e-3):
        super().__init__()
        self.save_hyperparameters()
        self.net = net
        self.train_acc = Accuracy()
        self.val_acc = Accuracy()
        self.test_acc = Accuracy() 
        
        
    def forward(self,x):
        x = self.net(x)
        return x
    
    
    #定义loss
    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}
    
    #定义各种metrics
    def training_step_end(self,outputs):
        train_acc = self.train_acc(outputs['preds'], outputs['y']).item()    
        self.log("train_acc",train_acc,prog_bar=True)
        return {"loss":outputs["loss"].mean()}
    
    #定义optimizer,以及可选的lr_scheduler
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.hparams.learning_rate)
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}

    def validation_step_end(self,outputs):
        val_acc = self.val_acc(outputs['preds'], outputs['y']).item()    
        self.log("val_loss",outputs["loss"].mean(),on_epoch=True,on_step=False)
        self.log("val_acc",val_acc,prog_bar=True,on_epoch=True,on_step=False)
    
    def test_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}
    
    def test_step_end(self,outputs):
        test_acc = self.test_acc(outputs['preds'], outputs['y']).item()    
        self.log("test_acc",test_acc,on_epoch=True,on_step=False)
        self.log("test_loss",outputs["loss"].mean(),on_epoch=True,on_step=False)
    
    @staticmethod
    def add_model_args(parent_parser):
        parser = ArgumentParser(parents=[parent_parser], add_help=False)
        parser.add_argument('--learning_rate', type=float, default=1e-3)
        return parser
    

#================================================================================
# 三，训练模型
#================================================================================
    
def main(hparams):
    pl.seed_everything(1234)
    
    data_mnist = MNISTDataModule(batch_size=hparams.batch_size,
                                 num_workers=hparams.num_workers)
    
    model = Model(net,learning_rate=hparams.learning_rate)
    
    ckpt_callback = pl.callbacks.ModelCheckpoint(
        monitor='val_loss',
        save_top_k=1,
        mode='min'
    )
    early_stopping = pl.callbacks.EarlyStopping(monitor = 'val_loss',
                   patience=3,
                   mode = 'min')
    
    trainer = pl.Trainer.from_argparse_args( 
        hparams,
        max_epochs=10,
        
        callbacks = [ckpt_callback,early_stopping]
    ) 

    
    
    if hparams.auto_scale_batch_size is not None:
        #搜索不发生OOM的最大batch_size
        max_batch_size = trainer.tuner.scale_batch_size(model,data_mnist,
                        mode=hparams.auto_scale_batch_size)
        data_mnist.batch_size = max_batch_size
        
        #等价于
        #trainer.tune(model,data_mnist)
        
    
    #gpus=0, #单CPU模式
    #gpus=1, #单GPU模式
    #num_processes=4,strategy="ddp_find_unused_parameters_false", #多CPU(进程)模式
    #gpus=4,strategy="dp", #多GPU(dp速度提升效果一般)
    #gpus=4,strategy=“ddp_find_unused_parameters_false" #多GPU(ddp速度提升效果好)

    trainer.fit(model,data_mnist)
    result = trainer.test(model,data_mnist,ckpt_path='best')

if __name__ == "__main__":
    parser = ArgumentParser()
    parser = MNISTDataModule.add_dataset_args(parser)
    parser = Model.add_model_args(parser)
    parser = pl.Trainer.add_argparse_args(parser)
    hparams = parser.parse_args()
    main(hparams)
# Out:
# Overwriting mnist_cnn.py

# %% [markdown]
# ### 1，使用多进程读取数据(num_workers=4)
#
# 使用多进程读取数据，可以避免数据加载过程成为性能瓶颈。

# %% [markdown]
# * 单进程读取数据(num_workers=0, gpus=1): 1min 18s
#
# * 多进程读取数据(num_workers=4, gpus=1): 59.7s

# %%
# %%time
#单进程读取数据(num_workers=0)
# !python3 mnist_cnn.py --num_workers=0 --gpus=1
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]/usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Global seed set to 1234
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Epoch 0:  92%|▉| 1719/1876 [00:21<00:01, 80.92it/s, loss=0.131, v_num=7, train_a
# Validating: 0it [00:00, ?it/s]
# Epoch 0:  92%|▉| 1724/1876 [00:21<00:01, 81.00it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  93%|▉| 1736/1876 [00:21<00:01, 81.18it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  93%|▉| 1749/1876 [00:21<00:01, 81.38it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  94%|▉| 1762/1876 [00:21<00:01, 81.56it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  95%|▉| 1775/1876 [00:21<00:01, 81.75it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  95%|▉| 1788/1876 [00:21<00:01, 81.93it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  96%|▉| 1801/1876 [00:21<00:00, 82.09it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  97%|▉| 1814/1876 [00:22<00:00, 82.26it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  97%|▉| 1827/1876 [00:22<00:00, 82.42it/s, loss=0.131, v_num=7, train_a
# Epoch 0:  98%|▉| 1840/1876 [00:22<00:00, 82.60it/s, loss=0.131, v_num=7, train_a
# Validating:  77%|█████████████████████▌      | 121/157 [00:01<00:00, 116.50it/s]
# Epoch 0:  99%|▉| 1853/1876 [00:22<00:00, 82.78it/s, loss=0.131, v_num=7, train_a
# Epoch 0: 100%|█| 1876/1876 [00:22<00:00, 83.07it/s, loss=0.131, v_num=7, train_a
# Epoch 1:  92%|▉| 1719/1876 [00:22<00:02, 78.06it/s, loss=0.0759, v_num=7, train_
# Validating: 0it [00:00, ?it/s]
# Epoch 1:  92%|▉| 1729/1876 [00:22<00:01, 78.22it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  93%|▉| 1742/1876 [00:22<00:01, 78.44it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  94%|▉| 1755/1876 [00:22<00:01, 78.66it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  94%|▉| 1768/1876 [00:22<00:01, 78.88it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  95%|▉| 1781/1876 [00:22<00:01, 79.10it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  96%|▉| 1795/1876 [00:22<00:01, 79.36it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  96%|▉| 1809/1876 [00:22<00:00, 79.60it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  97%|▉| 1823/1876 [00:22<00:00, 79.82it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  98%|▉| 1837/1876 [00:22<00:00, 80.03it/s, loss=0.0759, v_num=7, train_
# Validating:  75%|█████████████████████       | 118/157 [00:00<00:00, 126.17it/s]
# Epoch 1:  99%|▉| 1851/1876 [00:23<00:00, 80.22it/s, loss=0.0759, v_num=7, train_
# Epoch 1:  99%|▉| 1865/1876 [00:23<00:00, 80.41it/s, loss=0.0759, v_num=7, train_
# Epoch 1: 100%|█| 1876/1876 [00:23<00:00, 80.54it/s, loss=0.0759, v_num=7, train_
# Epoch 2:  92%|▉| 1719/1876 [00:21<00:01, 79.40it/s, loss=0.0629, v_num=7, train_
# Validating: 0it [00:00, ?it/s]
# Epoch 2:  92%|▉| 1722/1876 [00:21<00:01, 79.44it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  93%|▉| 1736/1876 [00:21<00:01, 79.65it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  93%|▉| 1750/1876 [00:21<00:01, 79.86it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  94%|▉| 1764/1876 [00:22<00:01, 80.08it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  95%|▉| 1778/1876 [00:22<00:01, 80.30it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  96%|▉| 1792/1876 [00:22<00:01, 80.50it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  96%|▉| 1806/1876 [00:22<00:00, 80.71it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  97%|▉| 1820/1876 [00:22<00:00, 80.92it/s, loss=0.0629, v_num=7, train_
# Validating:  64%|██████████████████          | 101/157 [00:00<00:00, 120.94it/s]
# Epoch 2:  98%|▉| 1834/1876 [00:22<00:00, 81.14it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  99%|▉| 1848/1876 [00:22<00:00, 81.35it/s, loss=0.0629, v_num=7, train_
# Epoch 2:  99%|▉| 1862/1876 [00:22<00:00, 81.57it/s, loss=0.0629, v_num=7, train_
# Epoch 2: 100%|█| 1876/1876 [00:22<00:00, 81.76it/s, loss=0.0629, v_num=7, train_
# Epoch 3:  92%|▉| 1719/1876 [00:21<00:01, 80.51it/s, loss=0.0536, v_num=7, train_
# Validating: 0it [00:00, ?it/s]
# Epoch 3:  92%|▉| 1722/1876 [00:21<00:01, 80.55it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  93%|▉| 1736/1876 [00:21<00:01, 80.76it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  93%|▉| 1750/1876 [00:21<00:01, 80.98it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  94%|▉| 1764/1876 [00:21<00:01, 81.19it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  95%|▉| 1778/1876 [00:21<00:01, 81.41it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  96%|▉| 1792/1876 [00:21<00:01, 81.61it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  96%|▉| 1806/1876 [00:22<00:00, 81.81it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  97%|▉| 1820/1876 [00:22<00:00, 82.01it/s, loss=0.0536, v_num=7, train_
# Validating:  64%|██████████████████          | 101/157 [00:00<00:00, 120.40it/s]
# Epoch 3:  98%|▉| 1834/1876 [00:22<00:00, 82.22it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  99%|▉| 1848/1876 [00:22<00:00, 82.43it/s, loss=0.0536, v_num=7, train_
# Epoch 3:  99%|▉| 1862/1876 [00:22<00:00, 82.65it/s, loss=0.0536, v_num=7, train_
# Epoch 3: 100%|█| 1876/1876 [00:22<00:00, 82.85it/s, loss=0.0536, v_num=7, train_
# Epoch 4:  92%|▉| 1719/1876 [00:21<00:01, 79.62it/s, loss=0.0731, v_num=7, train_
# Validating: 0it [00:00, ?it/s]
# Epoch 4:  92%|▉| 1722/1876 [00:21<00:01, 79.67it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  93%|▉| 1736/1876 [00:21<00:01, 79.89it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  93%|▉| 1750/1876 [00:21<00:01, 80.10it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  94%|▉| 1764/1876 [00:21<00:01, 80.31it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  95%|▉| 1778/1876 [00:22<00:01, 80.53it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  96%|▉| 1792/1876 [00:22<00:01, 80.74it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  96%|▉| 1806/1876 [00:22<00:00, 80.93it/s, loss=0.0731, v_num=7, train_
# Validating:  55%|████████████████             | 87/157 [00:00<00:00, 118.58it/s]
# Epoch 4:  97%|▉| 1820/1876 [00:22<00:00, 81.12it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  98%|▉| 1834/1876 [00:22<00:00, 81.31it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  99%|▉| 1848/1876 [00:22<00:00, 81.51it/s, loss=0.0731, v_num=7, train_
# Epoch 4:  99%|▉| 1862/1876 [00:22<00:00, 81.72it/s, loss=0.0731, v_num=7, train_
# Epoch 4: 100%|█| 1876/1876 [00:22<00:00, 81.91it/s, loss=0.0731, v_num=7, train_
# Epoch 5:  92%|▉| 1719/1876 [00:21<00:01, 79.49it/s, loss=0.0458, v_num=7, train_
# Validating: 0it [00:00, ?it/s]
# Epoch 5:  92%|▉| 1722/1876 [00:21<00:01, 79.55it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  93%|▉| 1736/1876 [00:21<00:01, 79.79it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  93%|▉| 1750/1876 [00:21<00:01, 80.02it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  94%|▉| 1764/1876 [00:21<00:01, 80.26it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  95%|▉| 1778/1876 [00:22<00:01, 80.48it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  96%|▉| 1792/1876 [00:22<00:01, 80.70it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  96%|▉| 1806/1876 [00:22<00:00, 80.91it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  97%|▉| 1820/1876 [00:22<00:00, 81.12it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  98%|▉| 1834/1876 [00:22<00:00, 81.32it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  99%|▉| 1848/1876 [00:22<00:00, 81.53it/s, loss=0.0458, v_num=7, train_
# Epoch 5:  99%|▉| 1862/1876 [00:22<00:00, 81.71it/s, loss=0.0458, v_num=7, train_
# Validating:  91%|█████████████████████████▌  | 143/157 [00:01<00:00, 120.06it/s]
# Epoch 5: 100%|█| 1876/1876 [00:22<00:00, 81.90it/s, loss=0.0458, v_num=7, train_
# Epoch 6:  92%|▉| 1719/1876 [00:21<00:01, 79.39it/s, loss=0.0726, v_num=7, train_
# Validating: 0it [00:00, ?it/s]
# Epoch 6:  92%|▉| 1722/1876 [00:21<00:01, 79.44it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  93%|▉| 1736/1876 [00:21<00:01, 79.72it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  93%|▉| 1750/1876 [00:21<00:01, 79.97it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  94%|▉| 1764/1876 [00:21<00:01, 80.23it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  95%|▉| 1778/1876 [00:22<00:01, 80.48it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  96%|▉| 1792/1876 [00:22<00:01, 80.71it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  96%|▉| 1806/1876 [00:22<00:00, 80.95it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  97%|▉| 1820/1876 [00:22<00:00, 81.18it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  98%|▉| 1834/1876 [00:22<00:00, 81.43it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  99%|▉| 1849/1876 [00:22<00:00, 81.72it/s, loss=0.0726, v_num=7, train_
# Epoch 6:  99%|▉| 1864/1876 [00:22<00:00, 81.98it/s, loss=0.0726, v_num=7, train_
# Epoch 6: 100%|█| 1876/1876 [00:22<00:00, 82.15it/s, loss=0.0726, v_num=7, train_
# Epoch 6: 100%|█| 1876/1876 [00:22<00:00, 82.14it/s, loss=0.0726, v_num=7, train_
# FIT Profiler Report
#
# Action                             	|  Mean duration (s)	|Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------
# Total                              	|  -              	|_              	|  164.47         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------
# run_training_epoch                 	|  22.878         	|7              	|  160.15         	|  97.368         	|
# run_training_batch                 	|  0.0063689      	|12033          	|  76.637         	|  46.595         	|
# optimizer_step_with_closure_0      	|  0.0060027      	|12033          	|  72.23          	|  43.916         	|
# training_step_and_backward         	|  0.005106       	|12033          	|  61.44          	|  37.355         	|
# get_train_batch                    	|  0.0040925      	|12040          	|  49.274         	|  29.958         	|
# fetch_next_train_batch             	|  0.0040657      	|12040          	|  48.951         	|  29.762         	|
# model_forward                      	|  0.0037554      	|12033          	|  45.189         	|  27.475         	|
# training_step_end                  	|  0.0025311      	|12033          	|  30.457         	|  18.518         	|
# backward                           	|  0.0011116      	|12033          	|  13.375         	|  8.1321         	|
# training_step                      	|  0.0010423      	|12033          	|  12.543         	|  7.6258         	|
# on_train_batch_end                 	|  0.0008786      	|12033          	|  10.572         	|  6.4279         	|
# evaluation_step_and_end            	|  0.0048366      	|1101           	|  5.3251         	|  3.2376         	|
# get_validate_batch                 	|  0.0038521      	|1106           	|  4.2605         	|  2.5903         	|
# fetch_next_validate_batch          	|  0.0038265      	|1106           	|  4.2321         	|  2.5731         	|
# on_train_batch_start               	|  0.00027346     	|12033          	|  3.2906         	|  2.0007         	|
# validation_step_end                	|  0.0026181      	|1101           	|  2.8825         	|  1.7525         	|
# zero_grad                          	|  0.00020552     	|12033          	|  2.473          	|  1.5036         	|
# validation_step                    	|  0.0021413      	|1101           	|  2.3576         	|  1.4334         	|
# training_batch_to_device           	|  0.00019259     	|12033          	|  2.3174         	|  1.409          	|
# on_batch_start                     	|  3.9314e-05     	|12033          	|  0.47306        	|  0.28762        	|
# on_batch_end                       	|  3.4313e-05     	|12033          	|  0.41289        	|  0.25104        	|
# on_before_zero_grad                	|  3.3974e-05     	|12033          	|  0.40881        	|  0.24856        	|
# on_after_backward                  	|  3.2071e-05     	|12033          	|  0.38591        	|  0.23463        	|
# on_before_backward                 	|  2.9808e-05     	|12033          	|  0.35868        	|  0.21808        	|
# on_before_optimizer_step           	|  2.8173e-05     	|12033          	|  0.339          	|  0.20611        	|
# evaluation_batch_to_device         	|  0.0002006      	|1101           	|  0.22086        	|  0.13428        	|
# on_validation_batch_end            	|  0.00011326     	|1101           	|  0.12469        	|  0.075814       	|
# on_validation_batch_start          	|  3.4017e-05     	|1101           	|  0.037453       	|  0.022771       	|
# on_train_epoch_end                 	|  0.0039483      	|7              	|  0.027638       	|  0.016804       	|
# get_sanity_check_batch             	|  0.0047596      	|3              	|  0.014279       	|  0.0086815      	|
# fetch_next_sanity_check_batch      	|  0.0047342      	|3              	|  0.014203       	|  0.0086352      	|
# on_validation_end                  	|  0.00073308     	|8              	|  0.0058647      	|  0.0035657      	|
# on_validation_start                	|  0.00046837     	|8              	|  0.003747       	|  0.0022781      	|
# on_train_epoch_start               	|  0.00041611     	|7              	|  0.0029128      	|  0.001771       	|
# on_validation_model_eval           	|  0.00018604     	|8              	|  0.0014883      	|  0.00090488     	|
# on_sanity_check_start              	|  0.0014785      	|1              	|  0.0014785      	|  0.00089891     	|
# on_pretrain_routine_start          	|  0.0013295      	|1              	|  0.0013295      	|  0.00080836     	|
# on_train_start                     	|  0.00058921     	|1              	|  0.00058921     	|  0.00035824     	|
# on_epoch_start                     	|  3.1013e-05     	|15             	|  0.00046519     	|  0.00028284     	|
# on_epoch_end                       	|  2.9344e-05     	|15             	|  0.00044016     	|  0.00026762     	|
# on_train_end                       	|  0.00038472     	|1              	|  0.00038472     	|  0.00023391     	|
# on_validation_epoch_end            	|  3.6193e-05     	|8              	|  0.00028955     	|  0.00017604     	|
# configure_optimizers               	|  0.00027934     	|1              	|  0.00027934     	|  0.00016984     	|
# on_validation_epoch_start          	|  2.7588e-05     	|8              	|  0.0002207      	|  0.00013419     	|
# setup                              	|  5.6159e-05     	|1              	|  5.6159e-05     	|  3.4144e-05     	|
# on_configure_sharded_model         	|  4.634e-05      	|1              	|  4.634e-05      	|  2.8174e-05     	|
# on_sanity_check_end                	|  4.2111e-05     	|1              	|  4.2111e-05     	|  2.5603e-05     	|
# on_fit_end                         	|  4.1825e-05     	|1              	|  4.1825e-05     	|  2.5429e-05     	|
# on_fit_start                       	|  3.6279e-05     	|1              	|  3.6279e-05     	|  2.2057e-05     	|
# on_before_accelerator_backend_setup	|  3.3909e-05     	|1              	|  3.3909e-05     	|  2.0617e-05     	|
# teardown                           	|  3.31e-05       	|1              	|  3.31e-05       	|  2.0125e-05     	|
# on_pretrain_routine_end            	|  3.1208e-05     	|1              	|  3.1208e-05     	|  1.8974e-05     	|
# prepare_data                       	|  1.2093e-05     	|1              	|  1.2093e-05     	|  7.3526e-06     	|
# configure_sharded_model            	|  1.0941e-05     	|1              	|  1.0941e-05     	|  6.6522e-06     	|
# configure_callbacks                	|  1.0638e-05     	|1              	|  1.0638e-05     	|  6.4682e-06     	|
# on_train_dataloader                	|  8.137e-06      	|1              	|  8.137e-06      	|  4.9472e-06     	|
# on_val_dataloader                  	|  6.9747e-06     	|1              	|  6.9747e-06     	|  4.2406e-06     	|
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:133: UserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 64 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   f"The dataloader, {name}, does not have many workers which may be a bottleneck."
# Testing: 100%|██████████████████████████████▉| 312/313 [00:02<00:00, 124.68it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9857000112533569, 'test_loss': 0.04885349050164223}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:02<00:00, 123.46it/s]
# TEST Profiler Report
#
# Action                             	|  Mean duration (s)	|Num calls      	|  Total time (s) 	|  Percentage %   	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# Total                              	|  -              	|_              	|  167.18         	|  100 %          	|
# ---------------------------------------------------------------------------------------------------------------------------------------
# run_training_epoch                 	|  22.878         	|7              	|  160.15         	|  95.792         	|
# run_training_batch                 	|  0.0063689      	|12033          	|  76.637         	|  45.841         	|
# optimizer_step_with_closure_0      	|  0.0060027      	|12033          	|  72.23          	|  43.205         	|
# training_step_and_backward         	|  0.005106       	|12033          	|  61.44          	|  36.751         	|
# get_train_batch                    	|  0.0040925      	|12040          	|  49.274         	|  29.473         	|
# fetch_next_train_batch             	|  0.0040657      	|12040          	|  48.951         	|  29.28          	|
# model_forward                      	|  0.0037554      	|12033          	|  45.189         	|  27.03          	|
# training_step_end                  	|  0.0025311      	|12033          	|  30.457         	|  18.218         	|
# backward                           	|  0.0011116      	|12033          	|  13.375         	|  8.0005         	|
# training_step                      	|  0.0010423      	|12033          	|  12.543         	|  7.5024         	|
# on_train_batch_end                 	|  0.0008786      	|12033          	|  10.572         	|  6.3238         	|
# evaluation_step_and_end            	|  0.0045467      	|1414           	|  6.4291         	|  3.8456         	|
# get_validate_batch                 	|  0.0038521      	|1106           	|  4.2605         	|  2.5484         	|
# fetch_next_validate_batch          	|  0.0038265      	|1106           	|  4.2321         	|  2.5315         	|
# on_train_batch_start               	|  0.00027346     	|12033          	|  3.2906         	|  1.9683         	|
# validation_step_end                	|  0.0026181      	|1101           	|  2.8825         	|  1.7242         	|
# run_test_evaluation                	|  2.5374         	|1              	|  2.5374         	|  1.5178         	|
# zero_grad                          	|  0.00020552     	|12033          	|  2.473          	|  1.4792         	|
# validation_step                    	|  0.0021413      	|1101           	|  2.3576         	|  1.4102         	|
# training_batch_to_device           	|  0.00019259     	|12033          	|  2.3174         	|  1.3862         	|
# get_test_batch                     	|  0.0038072      	|314            	|  1.1955         	|  0.71507        	|
# fetch_next_test_batch              	|  0.0037828      	|314            	|  1.1878         	|  0.71049        	|
# test_step_end                      	|  0.002581       	|313            	|  0.80784        	|  0.48322        	|
# on_batch_start                     	|  3.9314e-05     	|12033          	|  0.47306        	|  0.28296        	|
# on_batch_end                       	|  3.4313e-05     	|12033          	|  0.41289        	|  0.24697        	|
# on_before_zero_grad                	|  3.3974e-05     	|12033          	|  0.40881        	|  0.24453        	|
# on_after_backward                  	|  3.2071e-05     	|12033          	|  0.38591        	|  0.23083        	|
# on_before_backward                 	|  2.9808e-05     	|12033          	|  0.35868        	|  0.21455        	|
# on_before_optimizer_step           	|  2.8173e-05     	|12033          	|  0.339          	|  0.20278        	|
# evaluation_batch_to_device         	|  0.00019911     	|1414           	|  0.28153        	|  0.1684         	|
# test_step                          	|  0.00087096     	|313            	|  0.27261        	|  0.16306        	|
# on_validation_batch_end            	|  0.00011326     	|1101           	|  0.12469        	|  0.074587       	|
# on_validation_batch_start          	|  3.4017e-05     	|1101           	|  0.037453       	|  0.022403       	|
# on_train_epoch_end                 	|  0.0039483      	|7              	|  0.027638       	|  0.016532       	|
# on_test_batch_end                  	|  7.6605e-05     	|313            	|  0.023977       	|  0.014342       	|
# get_sanity_check_batch             	|  0.0047596      	|3              	|  0.014279       	|  0.008541       	|
# fetch_next_sanity_check_batch      	|  0.0047342      	|3              	|  0.014203       	|  0.0084954      	|
# on_test_batch_start                	|  3.3206e-05     	|313            	|  0.010393       	|  0.0062169      	|
# on_validation_end                  	|  0.00073308     	|8              	|  0.0058647      	|  0.003508       	|
# on_validation_start                	|  0.00046837     	|8              	|  0.003747       	|  0.0022413      	|
# on_train_epoch_start               	|  0.00041611     	|7              	|  0.0029128      	|  0.0017423      	|
# on_validation_model_eval           	|  0.00018604     	|8              	|  0.0014883      	|  0.00089024     	|
# on_sanity_check_start              	|  0.0014785      	|1              	|  0.0014785      	|  0.00088436     	|
# on_pretrain_routine_start          	|  0.0013295      	|1              	|  0.0013295      	|  0.00079527     	|
# on_train_start                     	|  0.00058921     	|1              	|  0.00058921     	|  0.00035244     	|
# on_epoch_start                     	|  3.1191e-05     	|16             	|  0.00049905     	|  0.00029851     	|
# on_epoch_end                       	|  2.9256e-05     	|16             	|  0.00046809     	|  0.00027999     	|
# on_test_start                      	|  0.00044506     	|1              	|  0.00044506     	|  0.00026621     	|
# on_train_end                       	|  0.00038472     	|1              	|  0.00038472     	|  0.00023012     	|
# on_test_end                        	|  0.00035959     	|1              	|  0.00035959     	|  0.00021509     	|
# on_validation_epoch_end            	|  3.6193e-05     	|8              	|  0.00028955     	|  0.00017319     	|
# configure_optimizers               	|  0.00027934     	|1              	|  0.00027934     	|  0.00016709     	|
# on_validation_epoch_start          	|  2.7588e-05     	|8              	|  0.0002207      	|  0.00013202     	|
# on_test_model_eval                 	|  0.00018527     	|1              	|  0.00018527     	|  0.00011082     	|
# setup                              	|  5.4737e-05     	|2              	|  0.00010947     	|  6.5483e-05     	|
# on_configure_sharded_model         	|  4.7909e-05     	|2              	|  9.5818e-05     	|  5.7314e-05     	|
# teardown                           	|  3.4635e-05     	|2              	|  6.9271e-05     	|  4.1435e-05     	|
# on_before_accelerator_backend_setup	|  3.3455e-05     	|2              	|  6.6911e-05     	|  4.0023e-05     	|
# on_sanity_check_end                	|  4.2111e-05     	|1              	|  4.2111e-05     	|  2.5189e-05     	|
# on_fit_end                         	|  4.1825e-05     	|1              	|  4.1825e-05     	|  2.5018e-05     	|
# on_fit_start                       	|  3.6279e-05     	|1              	|  3.6279e-05     	|  2.17e-05       	|
# on_test_epoch_end                  	|  3.3344e-05     	|1              	|  3.3344e-05     	|  1.9945e-05     	|
# on_pretrain_routine_end            	|  3.1208e-05     	|1              	|  3.1208e-05     	|  1.8667e-05     	|
# on_test_epoch_start                	|  3.0434e-05     	|1              	|  3.0434e-05     	|  1.8204e-05     	|
# configure_sharded_model            	|  1.2611e-05     	|2              	|  2.5222e-05     	|  1.5087e-05     	|
# configure_callbacks                	|  1.08e-05       	|2              	|  2.1599e-05     	|  1.292e-05      	|
# prepare_data                       	|  9.8348e-06     	|2              	|  1.967e-05      	|  1.1765e-05     	|
# on_test_dataloader                 	|  1.2081e-05     	|1              	|  1.2081e-05     	|  7.2264e-06     	|
# on_train_dataloader                	|  8.137e-06      	|1              	|  8.137e-06      	|  4.8672e-06     	|
# on_val_dataloader                  	|  6.9747e-06     	|1              	|  6.9747e-06     	|  4.1719e-06     	|
#
# CPU times: user 4.67 s, sys: 2.14 s, total: 6.81 s
# Wall time: 2min 50s

# %% [markdown]
# ```
# ------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9857000112533569, 'test_loss': 0.04885349050164223}
# --------------------------------------------------------------------------------
#
# CPU times: user 4.67 s, sys: 2.14 s, total: 6.81 s
# Wall time: 2min 50s
# ```

# %%
# %%time
#多进程读取数据(num_workers=4)
# !python3 mnist_cnn.py --num_workers=4 --gpus=1
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  92%|▉| 1720/1876 [00:14<00:01, 115.08it/s, loss=0.125, v_num=63, train
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 0:  92%|▉| 1734/1876 [00:15<00:01, 113.45it/s, loss=0.125, v_num=63, train
# Epoch 0:  93%|▉| 1754/1876 [00:15<00:01, 114.01it/s, loss=0.125, v_num=63, train
# Epoch 0:  95%|▉| 1776/1876 [00:15<00:00, 114.67it/s, loss=0.125, v_num=63, train
# Epoch 0:  96%|▉| 1798/1876 [00:15<00:00, 115.34it/s, loss=0.125, v_num=63, train
# Epoch 0:  97%|▉| 1820/1876 [00:15<00:00, 116.01it/s, loss=0.125, v_num=63, train
# Epoch 0:  98%|▉| 1842/1876 [00:15<00:00, 116.65it/s, loss=0.125, v_num=63, train
# Epoch 0:  99%|▉| 1865/1876 [00:15<00:00, 117.34it/s, loss=0.125, v_num=63, train
# Epoch 0: 100%|█| 1876/1876 [00:16<00:00, 117.00it/s, loss=0.125, v_num=63, train
# Epoch 1:  92%|▉| 1719/1876 [00:14<00:01, 115.00it/s, loss=0.0657, v_num=63, trai
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 1:  92%|▉| 1725/1876 [00:15<00:01, 112.94it/s, loss=0.0657, v_num=63, trai
# Epoch 1:  93%|▉| 1748/1876 [00:15<00:01, 113.64it/s, loss=0.0657, v_num=63, trai
# Epoch 1:  94%|▉| 1771/1876 [00:15<00:00, 114.33it/s, loss=0.0657, v_num=63, trai
# Epoch 1:  96%|▉| 1794/1876 [00:15<00:00, 114.99it/s, loss=0.0657, v_num=63, trai
# Epoch 1:  97%|▉| 1817/1876 [00:15<00:00, 115.62it/s, loss=0.0657, v_num=63, trai
# Epoch 1:  98%|▉| 1840/1876 [00:15<00:00, 116.24it/s, loss=0.0657, v_num=63, trai
# Epoch 1:  99%|▉| 1863/1876 [00:15<00:00, 116.88it/s, loss=0.0657, v_num=63, trai
# Epoch 1: 100%|█| 1876/1876 [00:16<00:00, 116.61it/s, loss=0.0657, v_num=63, trai
# Epoch 2:  92%|▉| 1719/1876 [00:14<00:01, 116.38it/s, loss=0.0752, v_num=63, trai
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 2:  92%|▉| 1725/1876 [00:15<00:01, 114.39it/s, loss=0.0752, v_num=63, trai
# Epoch 2:  93%|▉| 1748/1876 [00:15<00:01, 115.11it/s, loss=0.0752, v_num=63, trai
# Epoch 2:  94%|▉| 1771/1876 [00:15<00:00, 115.83it/s, loss=0.0752, v_num=63, trai
# Epoch 2:  96%|▉| 1794/1876 [00:15<00:00, 116.53it/s, loss=0.0752, v_num=63, trai
# Epoch 2:  97%|▉| 1817/1876 [00:15<00:00, 117.21it/s, loss=0.0752, v_num=63, trai
# Epoch 2:  98%|▉| 1840/1876 [00:15<00:00, 117.88it/s, loss=0.0752, v_num=63, trai
# Epoch 2:  99%|▉| 1863/1876 [00:15<00:00, 118.53it/s, loss=0.0752, v_num=63, trai
# Epoch 2: 100%|█| 1876/1876 [00:15<00:00, 118.23it/s, loss=0.0752, v_num=63, trai
# Epoch 2: 100%|█| 1876/1876 [00:15<00:00, 118.20it/s, loss=0.0752, v_num=63, trai
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing:  96%|█████████████████████████████▋ | 300/313 [00:01<00:00, 200.61it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9764000177383423, 'test_loss': 0.0820135846734047}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 163.40it/s]
# CPU times: user 1.56 s, sys: 647 ms, total: 2.21 s
# Wall time: 59.7 s

# %% [markdown]
# ```
# ---------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9764000177383423, 'test_loss': 0.0820135846734047}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 163.40it/s]
# CPU times: user 1.56 s, sys: 647 ms, total: 2.21 s
# Wall time: 59.7 s
# ```

# %% [markdown]
# ### 2，使用锁业内存(pin_memory=True)

# %% [markdown]
# 锁页内存存放的内容在任何情况下都不会与主机的虚拟内存进行交换（注：虚拟内存就是硬盘）
#
# 因此锁业内存比非锁业内存读写效率更高，copy到GPU上也更快速。
#
# 当计算机的内存充足的时候，可以设置pin_memory=True。当系统卡住，或者交换内存使用过多的时候，设置pin_memory=False。
#
# 因为pin_memory与电脑硬件性能有关，pytorch开发者不能确保每一个炼丹玩家都有高端设备，因此pin_memory默认为False。

# %% [markdown]
# * 非锁业内存存储数据(pin_memory=False, gpus=1): 1min
#
# * 锁业内存存储数据(pin_memory=True, gpus=1): 59.5s

# %%
# %%time
#非锁业内存存储数据(pin_memory=False)
# !python3 mnist_cnn.py --pin_memory=False --gpus=1
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  92%|▉| 1719/1876 [00:15<00:01, 110.93it/s, loss=0.141, v_num=64, train
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 0:  92%|▉| 1727/1876 [00:15<00:01, 109.33it/s, loss=0.141, v_num=64, train
# Epoch 0:  93%|▉| 1750/1876 [00:15<00:01, 110.07it/s, loss=0.141, v_num=64, train
# Epoch 0:  95%|▉| 1773/1876 [00:16<00:00, 110.78it/s, loss=0.141, v_num=64, train
# Epoch 0:  96%|▉| 1796/1876 [00:16<00:00, 111.45it/s, loss=0.141, v_num=64, train
# Epoch 0:  97%|▉| 1819/1876 [00:16<00:00, 112.08it/s, loss=0.141, v_num=64, train
# Epoch 0:  98%|▉| 1842/1876 [00:16<00:00, 112.67it/s, loss=0.141, v_num=64, train
# Epoch 0:  99%|▉| 1865/1876 [00:16<00:00, 113.29it/s, loss=0.141, v_num=64, train
# Epoch 0: 100%|█| 1876/1876 [00:16<00:00, 112.80it/s, loss=0.141, v_num=64, train
# Epoch 1:  92%|▉| 1719/1876 [00:14<00:01, 114.87it/s, loss=0.0764, v_num=64, trai
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 1:  92%|▉| 1725/1876 [00:15<00:01, 113.05it/s, loss=0.0764, v_num=64, trai
# Epoch 1:  93%|▉| 1748/1876 [00:15<00:01, 113.77it/s, loss=0.0764, v_num=64, trai
# Epoch 1:  94%|▉| 1771/1876 [00:15<00:00, 114.46it/s, loss=0.0764, v_num=64, trai
# Epoch 1:  96%|▉| 1794/1876 [00:15<00:00, 115.15it/s, loss=0.0764, v_num=64, trai
# Epoch 1:  97%|▉| 1817/1876 [00:15<00:00, 115.81it/s, loss=0.0764, v_num=64, trai
# Epoch 1:  98%|▉| 1840/1876 [00:15<00:00, 116.47it/s, loss=0.0764, v_num=64, trai
# Epoch 1:  99%|▉| 1863/1876 [00:15<00:00, 117.11it/s, loss=0.0764, v_num=64, trai
# Epoch 1: 100%|█| 1876/1876 [00:16<00:00, 116.92it/s, loss=0.0764, v_num=64, trai
# Epoch 2:  92%|▉| 1719/1876 [00:15<00:01, 112.30it/s, loss=0.0576, v_num=64, trai
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 2:  92%|▉| 1725/1876 [00:15<00:01, 110.63it/s, loss=0.0576, v_num=64, trai
# Epoch 2:  93%|▉| 1748/1876 [00:15<00:01, 111.33it/s, loss=0.0576, v_num=64, trai
# Epoch 2:  94%|▉| 1771/1876 [00:15<00:00, 112.00it/s, loss=0.0576, v_num=64, trai
# Epoch 2:  96%|▉| 1794/1876 [00:15<00:00, 112.69it/s, loss=0.0576, v_num=64, trai
# Epoch 2:  97%|▉| 1817/1876 [00:16<00:00, 113.39it/s, loss=0.0576, v_num=64, trai
# Epoch 2:  98%|▉| 1840/1876 [00:16<00:00, 114.07it/s, loss=0.0576, v_num=64, trai
# Epoch 2:  99%|▉| 1863/1876 [00:16<00:00, 114.76it/s, loss=0.0576, v_num=64, trai
# Epoch 2: 100%|█| 1876/1876 [00:16<00:00, 114.54it/s, loss=0.0576, v_num=64, trai
# Epoch 2: 100%|█| 1876/1876 [00:16<00:00, 114.47it/s, loss=0.0576, v_num=64, trai
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing:  99%|██████████████████████████████▊| 311/313 [00:01<00:00, 210.55it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9812999963760376, 'test_loss': 0.06231774762272835}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 171.69it/s]
# CPU times: user 1.59 s, sys: 619 ms, total: 2.21 s
# Wall time: 1min

# %% [markdown]
# ```
# ----------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9812999963760376, 'test_loss': 0.06231774762272835}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 171.69it/s]
# CPU times: user 1.59 s, sys: 619 ms, total: 2.21 s
# Wall time: 1min
# ```

# %%
# %%time
#锁业内存存储数据(pin_memory=True)
# !python3 mnist_cnn.py --pin_memory=True --gpus=1
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  92%|▉| 1719/1876 [00:14<00:01, 116.58it/s, loss=0.13, v_num=66, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 0:  92%|▉| 1724/1876 [00:15<00:01, 114.70it/s, loss=0.13, v_num=66, train_
# Epoch 0:  93%|▉| 1746/1876 [00:15<00:01, 115.39it/s, loss=0.13, v_num=66, train_
# Epoch 0:  94%|▉| 1768/1876 [00:15<00:00, 115.98it/s, loss=0.13, v_num=66, train_
# Epoch 0:  95%|▉| 1790/1876 [00:15<00:00, 116.63it/s, loss=0.13, v_num=66, train_
# Epoch 0:  97%|▉| 1812/1876 [00:15<00:00, 117.26it/s, loss=0.13, v_num=66, train_
# Epoch 0:  98%|▉| 1834/1876 [00:15<00:00, 117.86it/s, loss=0.13, v_num=66, train_
# Epoch 0:  99%|▉| 1856/1876 [00:15<00:00, 118.46it/s, loss=0.13, v_num=66, train_
# Epoch 0: 100%|█| 1876/1876 [00:15<00:00, 118.31it/s, loss=0.13, v_num=66, train_
# Epoch 1:  92%|▉| 1719/1876 [00:14<00:01, 116.58it/s, loss=0.0697, v_num=66, trai
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 1:  93%|▉| 1738/1876 [00:15<00:01, 115.16it/s, loss=0.0697, v_num=66, trai
# Epoch 1:  94%|▉| 1761/1876 [00:15<00:00, 115.90it/s, loss=0.0697, v_num=66, trai
# Epoch 1:  95%|▉| 1784/1876 [00:15<00:00, 116.64it/s, loss=0.0697, v_num=66, trai
# Epoch 1:  96%|▉| 1807/1876 [00:15<00:00, 117.37it/s, loss=0.0697, v_num=66, trai
# Epoch 1:  98%|▉| 1830/1876 [00:15<00:00, 118.04it/s, loss=0.0697, v_num=66, trai
# Epoch 1:  99%|▉| 1853/1876 [00:15<00:00, 118.75it/s, loss=0.0697, v_num=66, trai
# Epoch 1: 100%|█| 1876/1876 [00:15<00:00, 118.68it/s, loss=0.0697, v_num=66, trai
# Epoch 2:  92%|▉| 1719/1876 [00:15<00:01, 114.55it/s, loss=0.0864, v_num=66, trai
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 2:  92%|▉| 1725/1876 [00:15<00:01, 112.75it/s, loss=0.0864, v_num=66, trai
# Epoch 2:  93%|▉| 1748/1876 [00:15<00:01, 113.46it/s, loss=0.0864, v_num=66, trai
# Epoch 2:  94%|▉| 1771/1876 [00:15<00:00, 114.14it/s, loss=0.0864, v_num=66, trai
# Epoch 2:  96%|▉| 1794/1876 [00:15<00:00, 114.83it/s, loss=0.0864, v_num=66, trai
# Epoch 2:  97%|▉| 1817/1876 [00:15<00:00, 115.55it/s, loss=0.0864, v_num=66, trai
# Epoch 2:  98%|▉| 1840/1876 [00:15<00:00, 116.26it/s, loss=0.0864, v_num=66, trai
# Epoch 2:  99%|▉| 1863/1876 [00:15<00:00, 116.95it/s, loss=0.0864, v_num=66, trai
# Epoch 2: 100%|█| 1876/1876 [00:16<00:00, 116.66it/s, loss=0.0864, v_num=66, trai
# Epoch 2: 100%|█| 1876/1876 [00:16<00:00, 116.64it/s, loss=0.0864, v_num=66, trai
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing:  94%|█████████████████████████████  | 294/313 [00:01<00:00, 224.25it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9757999777793884, 'test_loss': 0.08017424494028091}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 174.58it/s]
# CPU times: user 1.54 s, sys: 677 ms, total: 2.22 s
# Wall time: 59.5 s

# %% [markdown]
# ```
# ---------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9757999777793884, 'test_loss': 0.08017424494028091}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 174.58it/s]
# CPU times: user 1.54 s, sys: 677 ms, total: 2.22 s
# Wall time: 59.5 s
# ```

# %% [markdown]
# ### 3，使用加速器(gpus=4,strategy="ddp_find_unused_parameters_false")
#
# pl 可以很方便地应用单CPU、多CPU、单GPU、多GPU乃至多TPU上训练模型。
#
# 以下几种情况训练耗时统计如下：
#
# * 单CPU: 2min 17s
#
# * 单GPU:  59.4 s
#
# * 4个GPU(dp模式): 1min
#
# * 4个GPU(ddp模式): 38.9 s
#
# 一般情况下，如果是单机多卡，建议使用 ddp模式，因为dp模式需要非常多的data和model传输，非常耗时。

# %%
# %%time
#单CPU
# !python3 mnist_cnn.py --gpus=0
# Out:
# Global seed set to 1234
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py:1585: UserWarning: GPU available but not used. Set the gpus flag in your trainer `Trainer(gpus=1)` or script `--gpus=1`.
#   "GPU available but not used. Set the gpus flag in your trainer `Trainer(gpus=1)` or script `--gpus=1`."
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  92%|▉| 1719/1876 [00:39<00:03, 43.06it/s, loss=0.137, v_num=43, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 0:  92%|▉| 1726/1876 [00:40<00:03, 42.89it/s, loss=0.137, v_num=43, train_
# Epoch 0:  92%|▉| 1734/1876 [00:40<00:03, 42.98it/s, loss=0.137, v_num=43, train_
# Epoch 0:  93%|▉| 1745/1876 [00:40<00:03, 43.14it/s, loss=0.137, v_num=43, train_
# Epoch 0:  94%|▉| 1756/1876 [00:40<00:02, 43.28it/s, loss=0.137, v_num=43, train_
# Epoch 0:  94%|▉| 1767/1876 [00:40<00:02, 43.40it/s, loss=0.137, v_num=43, train_
# Epoch 0:  95%|▉| 1778/1876 [00:40<00:02, 43.53it/s, loss=0.137, v_num=43, train_
# Epoch 0:  95%|▉| 1789/1876 [00:40<00:01, 43.68it/s, loss=0.137, v_num=43, train_
# Validating:  45%|█████████████▍                | 70/157 [00:01<00:01, 83.88it/s]
# Epoch 0:  96%|▉| 1800/1876 [00:41<00:01, 43.81it/s, loss=0.137, v_num=43, train_
# Epoch 0:  97%|▉| 1812/1876 [00:41<00:01, 43.98it/s, loss=0.137, v_num=43, train_
# Epoch 0:  97%|▉| 1824/1876 [00:41<00:01, 43.74it/s, loss=0.137, v_num=43, train_
# Epoch 0:  98%|▉| 1836/1876 [00:41<00:00, 43.92it/s, loss=0.137, v_num=43, train_
# Epoch 0:  99%|▉| 1848/1876 [00:41<00:00, 44.03it/s, loss=0.137, v_num=43, train_
# Epoch 0:  99%|▉| 1860/1876 [00:42<00:00, 44.21it/s, loss=0.137, v_num=43, train_
# Epoch 0: 100%|▉| 1872/1876 [00:42<00:00, 44.32it/s, loss=0.137, v_num=43, train_
# Epoch 0: 100%|█| 1876/1876 [00:42<00:00, 44.26it/s, loss=0.137, v_num=43, train_
# Epoch 1:  92%|▉| 1719/1876 [00:39<00:03, 43.56it/s, loss=0.103, v_num=43, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 1:  92%|▉| 1728/1876 [00:39<00:03, 43.41it/s, loss=0.103, v_num=43, train_
# Epoch 1:  93%|▉| 1740/1876 [00:39<00:03, 43.57it/s, loss=0.103, v_num=43, train_
# Validating:  13%|████                          | 21/157 [00:00<00:02, 56.25it/s]
# Epoch 1:  93%|▉| 1752/1876 [00:40<00:02, 43.70it/s, loss=0.103, v_num=43, train_
# Epoch 1:  94%|▉| 1764/1876 [00:40<00:02, 43.83it/s, loss=0.103, v_num=43, train_
# Validating:  30%|████████▉                     | 47/157 [00:00<00:01, 72.21it/s]
# Epoch 1:  95%|▉| 1776/1876 [00:40<00:02, 43.97it/s, loss=0.103, v_num=43, train_
# Epoch 1:  95%|▉| 1788/1876 [00:40<00:01, 44.13it/s, loss=0.103, v_num=43, train_
# Epoch 1:  96%|▉| 1800/1876 [00:40<00:01, 44.28it/s, loss=0.103, v_num=43, train_
# Epoch 1:  97%|▉| 1812/1876 [00:40<00:01, 44.44it/s, loss=0.103, v_num=43, train_
# Epoch 1:  97%|▉| 1824/1876 [00:40<00:01, 44.61it/s, loss=0.103, v_num=43, train_
# Epoch 1:  98%|▉| 1836/1876 [00:41<00:00, 44.73it/s, loss=0.103, v_num=43, train_
# Epoch 1:  99%|▉| 1848/1876 [00:41<00:00, 44.87it/s, loss=0.103, v_num=43, train_
# Epoch 1:  99%|▉| 1860/1876 [00:41<00:00, 45.03it/s, loss=0.103, v_num=43, train_
# Epoch 1: 100%|▉| 1872/1876 [00:41<00:00, 45.19it/s, loss=0.103, v_num=43, train_
# Epoch 1: 100%|█| 1876/1876 [00:41<00:00, 45.16it/s, loss=0.103, v_num=43, train_
# Epoch 2:  92%|▉| 1719/1876 [00:38<00:03, 44.87it/s, loss=0.0701, v_num=43, train
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 2:  92%|▉| 1728/1876 [00:38<00:03, 44.69it/s, loss=0.0701, v_num=43, train
# Epoch 2:  93%|▉| 1740/1876 [00:38<00:03, 44.85it/s, loss=0.0701, v_num=43, train
# Validating:  13%|████                          | 21/157 [00:00<00:02, 54.69it/s]
# Epoch 2:  93%|▉| 1752/1876 [00:38<00:02, 45.02it/s, loss=0.0701, v_num=43, train
# Epoch 2:  94%|▉| 1764/1876 [00:39<00:02, 44.96it/s, loss=0.0701, v_num=43, train
# Epoch 2:  95%|▉| 1776/1876 [00:39<00:02, 45.04it/s, loss=0.0701, v_num=43, train
# Epoch 2:  95%|▉| 1788/1876 [00:39<00:01, 45.19it/s, loss=0.0701, v_num=43, train
# Validating:  44%|█████████████▏                | 69/157 [00:01<00:01, 64.20it/s]
# Epoch 2:  96%|▉| 1800/1876 [00:39<00:01, 45.33it/s, loss=0.0701, v_num=43, train
# Epoch 2:  97%|▉| 1812/1876 [00:39<00:01, 45.43it/s, loss=0.0701, v_num=43, train
# Epoch 2:  97%|▉| 1824/1876 [00:40<00:01, 45.56it/s, loss=0.0701, v_num=43, train
# Epoch 2:  98%|▉| 1836/1876 [00:40<00:00, 45.70it/s, loss=0.0701, v_num=43, train
# Validating:  75%|█████████████████████▌       | 117/157 [00:01<00:00, 76.39it/s]
# Epoch 2:  99%|▉| 1848/1876 [00:40<00:00, 45.75it/s, loss=0.0701, v_num=43, train
# Epoch 2:  99%|▉| 1860/1876 [00:40<00:00, 45.89it/s, loss=0.0701, v_num=43, train
# Validating:  91%|██████████████████████████▍  | 143/157 [00:02<00:00, 66.14it/s]
# Epoch 2: 100%|█| 1876/1876 [00:40<00:00, 45.92it/s, loss=0.0701, v_num=43, train
# Epoch 2: 100%|█| 1876/1876 [00:40<00:00, 45.91it/s, loss=0.0701, v_num=43, train
# Testing: 100%|████████████████████████████████| 313/313 [00:05<00:00, 61.75it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9790999889373779, 'test_loss': 0.07223792374134064}
# --------------------------------------------------------------------------------
# Testing: 100%|████████████████████████████████| 313/313 [00:05<00:00, 55.95it/s]
# CPU times: user 2.67 s, sys: 740 ms, total: 3.41 s
# Wall time: 2min 17s

# %% [markdown]
# ```
# -----------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9790999889373779, 'test_loss': 0.07223792374134064}
# --------------------------------------------------------------------------------
# Testing: 100%|████████████████████████████████| 313/313 [00:05<00:00, 55.95it/s]
# CPU times: user 2.67 s, sys: 740 ms, total: 3.41 s
# Wall time: 2min 17s
# ```

# %%
# %%time
#单GPU
# !python3 mnist_cnn.py --gpus=1
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  92%|▉| 1719/1876 [00:16<00:01, 103.63it/s, loss=0.136, v_num=3, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 0:  92%|▉| 1726/1876 [00:16<00:01, 102.26it/s, loss=0.136, v_num=3, train_
# Epoch 0:  93%|▉| 1744/1876 [00:16<00:01, 102.70it/s, loss=0.136, v_num=3, train_
# Epoch 0:  94%|▉| 1763/1876 [00:17<00:01, 103.21it/s, loss=0.136, v_num=3, train_
# Epoch 0:  95%|▉| 1782/1876 [00:17<00:00, 103.72it/s, loss=0.136, v_num=3, train_
# Epoch 0:  96%|▉| 1801/1876 [00:17<00:00, 104.21it/s, loss=0.136, v_num=3, train_
# Epoch 0:  97%|▉| 1820/1876 [00:17<00:00, 104.69it/s, loss=0.136, v_num=3, train_
# Epoch 0:  98%|▉| 1839/1876 [00:17<00:00, 105.16it/s, loss=0.136, v_num=3, train_
# Epoch 0:  99%|▉| 1858/1876 [00:17<00:00, 105.62it/s, loss=0.136, v_num=3, train_
# Epoch 0: 100%|█| 1876/1876 [00:17<00:00, 105.67it/s, loss=0.136, v_num=3, train_
# Epoch 1:  92%|▉| 1719/1876 [00:16<00:01, 102.50it/s, loss=0.0813, v_num=3, train
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 1:  92%|▉| 1729/1876 [00:17<00:01, 101.29it/s, loss=0.0813, v_num=3, train
# Epoch 1:  93%|▉| 1750/1876 [00:17<00:01, 101.90it/s, loss=0.0813, v_num=3, train
# Epoch 1:  94%|▉| 1771/1876 [00:17<00:01, 102.51it/s, loss=0.0813, v_num=3, train
# Epoch 1:  96%|▉| 1792/1876 [00:17<00:00, 103.08it/s, loss=0.0813, v_num=3, train
# Epoch 1:  97%|▉| 1813/1876 [00:17<00:00, 103.65it/s, loss=0.0813, v_num=3, train
# Epoch 1:  98%|▉| 1834/1876 [00:17<00:00, 104.24it/s, loss=0.0813, v_num=3, train
# Epoch 1:  99%|▉| 1855/1876 [00:17<00:00, 104.83it/s, loss=0.0813, v_num=3, train
# Epoch 1: 100%|█| 1876/1876 [00:17<00:00, 105.02it/s, loss=0.0813, v_num=3, train
# Epoch 2:  92%|▉| 1719/1876 [00:15<00:01, 108.71it/s, loss=0.0521, v_num=3, train
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                       | 0/157 [00:00<?, ?it/s]
# Epoch 2:  92%|▉| 1722/1876 [00:16<00:01, 107.15it/s, loss=0.0521, v_num=3, train
# Epoch 2:  93%|▉| 1743/1876 [00:16<00:01, 107.76it/s, loss=0.0521, v_num=3, train
# Epoch 2:  94%|▉| 1764/1876 [00:16<00:01, 108.29it/s, loss=0.0521, v_num=3, train
# Epoch 2:  95%|▉| 1785/1876 [00:16<00:00, 108.79it/s, loss=0.0521, v_num=3, train
# Epoch 2:  96%|▉| 1806/1876 [00:16<00:00, 109.37it/s, loss=0.0521, v_num=3, train
# Epoch 2:  97%|▉| 1827/1876 [00:16<00:00, 109.91it/s, loss=0.0521, v_num=3, train
# Epoch 2:  99%|▉| 1848/1876 [00:16<00:00, 110.49it/s, loss=0.0521, v_num=3, train
# Epoch 2: 100%|█| 1876/1876 [00:16<00:00, 110.80it/s, loss=0.0521, v_num=3, train
# Epoch 2: 100%|█| 1876/1876 [00:16<00:00, 110.73it/s, loss=0.0521, v_num=3, train
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Testing:  96%|█████████████████████████████▌ | 299/313 [00:01<00:00, 213.15it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9778000116348267, 'test_loss': 0.06929327547550201}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 171.04it/s]
# CPU times: user 1.83 s, sys: 488 ms, total: 2.32 s
# Wall time: 1min 3s

# %% [markdown]
# ```
# ---------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9778000116348267, 'test_loss': 0.06929327547550201}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:01<00:00, 171.04it/s]
# CPU times: user 1.83 s, sys: 488 ms, total: 2.32 s
# Wall time: 1min 3s
# ```

# %%
# %%time
#多GPU，dp模式（为公平比较，batch_size=32*4）
# !python3 mnist_cnn.py --gpus=4 --strategy="dp" --batch_size=128
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  91%|▉| 430/470 [00:11<00:01, 37.23it/s, loss=0.16, v_num=48, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 0:  93%|▉| 435/470 [00:12<00:00, 36.00it/s, loss=0.16, v_num=48, train_acc
# Epoch 0:  94%|▉| 441/470 [00:12<00:00, 36.18it/s, loss=0.16, v_num=48, train_acc
# Epoch 0:  95%|▉| 447/470 [00:12<00:00, 36.35it/s, loss=0.16, v_num=48, train_acc
# Epoch 0:  96%|▉| 453/470 [00:12<00:00, 36.51it/s, loss=0.16, v_num=48, train_acc
# Epoch 0:  98%|▉| 459/470 [00:12<00:00, 36.68it/s, loss=0.16, v_num=48, train_acc
# Epoch 0:  99%|▉| 465/470 [00:12<00:00, 36.86it/s, loss=0.16, v_num=48, train_acc
# Epoch 0: 100%|█| 470/470 [00:12<00:00, 36.57it/s, loss=0.16, v_num=48, train_acc
# Epoch 1:  91%|▉| 430/470 [00:10<00:01, 39.66it/s, loss=0.11, v_num=48, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 1:  92%|▉| 432/470 [00:11<00:00, 38.05it/s, loss=0.11, v_num=48, train_acc
# Epoch 1:  93%|▉| 438/470 [00:11<00:00, 38.22it/s, loss=0.11, v_num=48, train_acc
# Epoch 1:  94%|▉| 444/470 [00:11<00:00, 38.37it/s, loss=0.11, v_num=48, train_acc
# Epoch 1:  96%|▉| 450/470 [00:11<00:00, 38.54it/s, loss=0.11, v_num=48, train_acc
# Epoch 1:  97%|▉| 456/470 [00:11<00:00, 38.71it/s, loss=0.11, v_num=48, train_acc
# Epoch 1:  98%|▉| 462/470 [00:11<00:00, 38.88it/s, loss=0.11, v_num=48, train_acc
# Epoch 1: 100%|█| 470/470 [00:12<00:00, 38.65it/s, loss=0.11, v_num=48, train_acc
# Epoch 2:  91%|▉| 430/470 [00:10<00:01, 39.47it/s, loss=0.0776, v_num=48, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 2:  92%|▉| 434/470 [00:11<00:00, 38.05it/s, loss=0.0776, v_num=48, train_a
# Epoch 2:  94%|▉| 441/470 [00:11<00:00, 38.24it/s, loss=0.0776, v_num=48, train_a
# Epoch 2:  95%|▉| 448/470 [00:11<00:00, 38.43it/s, loss=0.0776, v_num=48, train_a
# Epoch 2:  97%|▉| 455/470 [00:11<00:00, 38.62it/s, loss=0.0776, v_num=48, train_a
# Validating:  62%|███████████████████▍           | 25/40 [00:00<00:00, 40.04it/s]
# Epoch 2:  98%|▉| 462/470 [00:11<00:00, 38.79it/s, loss=0.0776, v_num=48, train_a
# Epoch 2: 100%|█| 470/470 [00:12<00:00, 38.58it/s, loss=0.0776, v_num=48, train_a
# Epoch 2: 100%|█| 470/470 [00:12<00:00, 38.54it/s, loss=0.0776, v_num=48, train_a
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing: 100%|██████████████████████████████████| 79/79 [00:02<00:00, 38.62it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9790999889373779, 'test_loss': 0.06855566054582596}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 79/79 [00:02<00:00, 38.55it/s]
# CPU times: user 1.2 s, sys: 553 ms, total: 1.75 s
# Wall time: 1min

# %% [markdown]
# ```
# ------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9790999889373779, 'test_loss': 0.06855566054582596}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 79/79 [00:02<00:00, 38.55it/s]
# CPU times: user 1.2 s, sys: 553 ms, total: 1.75 s
# Wall time: 1min
# ```

# %%
# %%time
#多GPU，ddp模式
# !python3 mnist_cnn.py --gpus=4 --strategy="ddp_find_unused_parameters_false"
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# Epoch 0:  91%|▉| 430/470 [00:05<00:00, 83.09it/s, loss=0.201, v_num=47, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 0:  93%|▉| 437/470 [00:05<00:00, 79.88it/s, loss=0.201, v_num=47, train_ac
# Epoch 0:  97%|▉| 456/470 [00:05<00:00, 81.84it/s, loss=0.201, v_num=47, train_ac
# Epoch 0: 100%|█| 470/470 [00:05<00:00, 80.88it/s, loss=0.201, v_num=47, train_ac
# Epoch 1:  91%|▉| 430/470 [00:05<00:00, 84.31it/s, loss=0.0979, v_num=47, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 1:  93%|▉| 437/470 [00:05<00:00, 80.97it/s, loss=0.0979, v_num=47, train_a
# Epoch 1:  97%|▉| 456/470 [00:05<00:00, 82.95it/s, loss=0.0979, v_num=47, train_a
# Epoch 1: 100%|█| 470/470 [00:05<00:00, 82.27it/s, loss=0.0979, v_num=47, train_a
# Epoch 2:  91%|▉| 430/470 [00:05<00:00, 84.67it/s, loss=0.0889, v_num=47, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 2:  93%|▉| 437/470 [00:05<00:00, 81.37it/s, loss=0.0889, v_num=47, train_a
# Epoch 2:  97%|▉| 456/470 [00:05<00:00, 83.34it/s, loss=0.0889, v_num=47, train_a
# Epoch 2: 100%|█| 470/470 [00:05<00:00, 82.87it/s, loss=0.0889, v_num=47, train_a
# Epoch 2: 100%|█| 470/470 [00:05<00:00, 82.72it/s, loss=0.0889, v_num=47, train_a
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing:  91%|██████████████████████████████   | 72/79 [00:00<00:00, 137.66it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9732000231742859, 'test_loss': 0.08606339246034622}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 79/79 [00:00<00:00, 85.79it/s]
# CPU times: user 784 ms, sys: 387 ms, total: 1.17 s
# Wall time: 38.9 s

# %% [markdown]
# ```
# ---------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9732000231742859, 'test_loss': 0.08606339246034622}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 79/79 [00:00<00:00, 85.79it/s]
# CPU times: user 784 ms, sys: 387 ms, total: 1.17 s
# Wall time: 38.9 s
# ```

# %% [markdown]
# ### 4，使用梯度累加(accumulate_grad_batches=6)

# %% [markdown]
# 梯度累加就是累加多个batch的梯度，然后用累加的梯度更新一次参数，使用梯度累加相当于增大batch_size.
#
# 由于更新参数的计算量略大于简单梯度求和的计算量（对于大部分优化器而言），使用梯度累加会让速度略有提升。
#
# * 4个GPU(ddp模式): 38.9 s
#
# * 4个GPU(ddp模式)+梯度累加: 36.9 s

# %%
# %%time
#多GPU，ddp模式, 考虑梯度累加
# !python3 mnist_cnn.py --accumulate_grad_batches=6 --gpus=4 --strategy="ddp_find_unused_parameters_false"
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/4
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 2, MEMBER: 3/4
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 3, MEMBER: 4/4
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/4
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 4 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# Epoch 0:  91%|▉| 430/470 [00:04<00:00, 95.76it/s, loss=0.639, v_num=54, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 0:  92%|▉| 432/470 [00:04<00:00, 90.82it/s, loss=0.639, v_num=54, train_ac
# Epoch 0:  96%|▉| 449/470 [00:04<00:00, 92.43it/s, loss=0.639, v_num=54, train_ac
# Epoch 0: 100%|█| 470/470 [00:05<00:00, 92.13it/s, loss=0.639, v_num=54, train_ac
# Epoch 1:  91%|▉| 430/470 [00:04<00:00, 95.65it/s, loss=0.205, v_num=54, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 1:  94%|▉| 442/470 [00:04<00:00, 91.50it/s, loss=0.205, v_num=54, train_ac
# Epoch 1:  98%|▉| 460/470 [00:04<00:00, 93.21it/s, loss=0.205, v_num=54, train_ac
# Epoch 1: 100%|█| 470/470 [00:05<00:00, 92.20it/s, loss=0.205, v_num=54, train_ac
# Epoch 2:  91%|▉| 430/470 [00:04<00:00, 94.67it/s, loss=0.155, v_num=54, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/40 [00:00<?, ?it/s]
# Epoch 2:  92%|▉| 432/470 [00:04<00:00, 89.72it/s, loss=0.155, v_num=54, train_ac
# Epoch 2:  96%|▉| 450/470 [00:04<00:00, 91.25it/s, loss=0.155, v_num=54, train_ac
# Epoch 2: 100%|█| 470/470 [00:05<00:00, 90.41it/s, loss=0.155, v_num=54, train_ac
# Epoch 2: 100%|█| 470/470 [00:05<00:00, 90.23it/s, loss=0.155, v_num=54, train_ac
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# Global seed set to 1234
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 2 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# LOCAL_RANK: 3 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing:  94%|██████████████████████████████▉  | 74/79 [00:00<00:00, 141.05it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9603000283241272, 'test_loss': 0.1400066614151001}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 79/79 [00:00<00:00, 89.10it/s]
# CPU times: user 749 ms, sys: 402 ms, total: 1.15 s
# Wall time: 36.9 s

# %% [markdown]
# ```
# ----------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9603000283241272, 'test_loss': 0.1400066614151001}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 79/79 [00:00<00:00, 89.10it/s]
# CPU times: user 749 ms, sys: 402 ms, total: 1.15 s
# Wall time: 36.9 s
# ```

# %% [markdown]
# ### 5，使用半精度(precision=16)

# %% [markdown]
# 通过precision可以设置 double (64), float (32), bfloat16 ("bf16"), half (16) 精度的训练。
#
# 默认是float(32) 标准精度，bfloat16 ("bf16")是混合精度。
#
# 如果选择 half(16) 半精度，并同时增大batch_size为原来2倍, 通常训练速度会提升3倍左右。

# %%
# %%time 
#半精度
# !python3 mnist_cnn.py --precision=16 --batch_size=64 --gpus=1
# Out:
# Global seed set to 1234
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.108     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  92%|▉| 860/939 [00:08<00:00, 99.68it/s, loss=0.142, v_num=73, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/79 [00:00<?, ?it/s]
# Epoch 0:  92%|▉| 868/939 [00:08<00:00, 96.98it/s, loss=0.142, v_num=73, train_ac
# Epoch 0:  95%|▉| 888/939 [00:09<00:00, 98.11it/s, loss=0.142, v_num=73, train_ac
# Epoch 0:  97%|▉| 908/939 [00:09<00:00, 99.16it/s, loss=0.142, v_num=73, train_ac
# Epoch 0:  99%|▉| 928/939 [00:09<00:00, 100.10it/s, loss=0.142, v_num=73, train_a
# Epoch 0: 100%|█| 939/939 [00:09<00:00, 99.59it/s, loss=0.142, v_num=73, train_ac
# Epoch 1:  92%|▉| 860/939 [00:08<00:00, 99.95it/s, loss=0.0815, v_num=73, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/79 [00:00<?, ?it/s]
# Epoch 1:  94%|▉| 880/939 [00:08<00:00, 97.85it/s, loss=0.0815, v_num=73, train_a
# Epoch 1:  96%|▉| 900/939 [00:09<00:00, 98.96it/s, loss=0.0815, v_num=73, train_a
# Epoch 1:  98%|▉| 920/939 [00:09<00:00, 100.02it/s, loss=0.0815, v_num=73, train_
# Validating:  77%|███████████████████████▏      | 61/79 [00:00<00:00, 135.13it/s]
# Epoch 1: 100%|█| 939/939 [00:09<00:00, 99.97it/s, loss=0.0815, v_num=73, train_a
# Epoch 2:  92%|▉| 860/939 [00:08<00:00, 100.47it/s, loss=0.0806, v_num=73, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/79 [00:00<?, ?it/s]
# Epoch 2:  94%|▉| 880/939 [00:08<00:00, 98.30it/s, loss=0.0806, v_num=73, train_a
# Validating:  25%|███████▊                       | 20/79 [00:00<00:00, 64.09it/s]
# Epoch 2:  96%|▉| 900/939 [00:09<00:00, 99.23it/s, loss=0.0806, v_num=73, train_a
# Epoch 2:  98%|▉| 920/939 [00:09<00:00, 100.13it/s, loss=0.0806, v_num=73, train_
# Epoch 2: 100%|█| 939/939 [00:09<00:00, 100.10it/s, loss=0.0806, v_num=73, train_
# Epoch 2: 100%|█| 939/939 [00:09<00:00, 99.99it/s, loss=0.0806, v_num=73, train_a
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing: 100%|███████████████████████████████| 157/157 [00:01<00:00, 145.74it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9769999980926514, 'test_loss': 0.07660940289497375}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 157/157 [00:01<00:00, 130.02it/s]
# CPU times: user 943 ms, sys: 429 ms, total: 1.37 s
# Wall time: 39.6 s

# %% [markdown]
# ### 6，自动搜索最大batch_size(auto_scale_batch_size="power")

# %%
# !python3 mnist_cnn.py --auto_scale_batch_size="power"  --gpus=1
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py:2165: LightningDeprecationWarning: `Trainer.weights_summary` is deprecated in v1.5 and will be removed in v1.7.
#   rank_zero_deprecation("`Trainer.weights_summary` is deprecated in v1.5 and will be removed in v1.7.")
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/trainer.py:2170: LightningDeprecationWarning: Setting `Trainer.weights_summary` is deprecated in v1.5 and will be removed in v1.7.
#   rank_zero_deprecation("Setting `Trainer.weights_summary` is deprecated in v1.5 and will be removed in v1.7.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 2 succeeded, trying batch size 4
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.teardown has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.teardown.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# Batch size 4 succeeded, trying batch size 8
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 8 succeeded, trying batch size 16
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 16 succeeded, trying batch size 32
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 32 succeeded, trying batch size 64
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 64 succeeded, trying batch size 128
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 128 succeeded, trying batch size 256
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 256 succeeded, trying batch size 512
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 512 succeeded, trying batch size 1024
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 1024 succeeded, trying batch size 2048
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (27) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 2048 succeeded, trying batch size 4096
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (14) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 4096 succeeded, trying batch size 8192
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (7) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 8192 succeeded, trying batch size 16384
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (4) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 16384 succeeded, trying batch size 32768
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (2) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 32768 succeeded, trying batch size 65536
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Global seed set to 1234
# Batch size 55000 succeeded, trying batch size 110000
# Finished batch size finder, will continue with full run using batch size 55000
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/scale_batch_size_temp_model_46adaf1c-f209-4c7f-910c-6fcecfcc985b.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  50%|▌| 1/2 [00:07<00:07,  7.74s/it, loss=1.91, v_num=12, train_acc=0.0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|█| 2/2 [00:08<00:00,  4.29s/it, loss=1.91, v_num=12, train_acc=0.0
# Epoch 1:  50%|▌| 1/2 [00:07<00:07,  7.83s/it, loss=1.92, v_num=12, train_acc=0.1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 2/2 [00:08<00:00,  4.34s/it, loss=1.92, v_num=12, train_acc=0.1
# Epoch 2:  50%|▌| 1/2 [00:07<00:07,  7.88s/it, loss=1.93, v_num=12, train_acc=0.1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 2/2 [00:08<00:00,  4.36s/it, loss=1.93, v_num=12, train_acc=0.1
# Epoch 3:  50%|▌| 1/2 [00:07<00:07,  7.93s/it, loss=1.94, v_num=12, train_acc=0.1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 2/2 [00:08<00:00,  4.38s/it, loss=1.94, v_num=12, train_acc=0.1
# Epoch 4:  50%|▌| 1/2 [00:07<00:07,  7.71s/it, loss=1.95, v_num=12, train_acc=0.2
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 2/2 [00:08<00:00,  4.29s/it, loss=1.95, v_num=12, train_acc=0.2
# Epoch 5:  50%|▌| 1/2 [00:07<00:07,  7.89s/it, loss=1.96, v_num=12, train_acc=0.2
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 2/2 [00:08<00:00,  4.37s/it, loss=1.96, v_num=12, train_acc=0.2
# Epoch 6:  50%|▌| 1/2 [00:07<00:07,  7.84s/it, loss=1.97, v_num=12, train_acc=0.3
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 2/2 [00:08<00:00,  4.34s/it, loss=1.97, v_num=12, train_acc=0.3
# Epoch 7:  50%|▌| 1/2 [00:07<00:07,  7.94s/it, loss=1.98, v_num=12, train_acc=0.3
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 2/2 [00:08<00:00,  4.38s/it, loss=1.98, v_num=12, train_acc=0.3
# Epoch 8:  50%|▌| 1/2 [00:07<00:07,  7.95s/it, loss=2, v_num=12, train_acc=0.333,
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 2/2 [00:08<00:00,  4.41s/it, loss=2, v_num=12, train_acc=0.333,
# Epoch 9:  50%|▌| 1/2 [00:07<00:07,  7.92s/it, loss=2.01, v_num=12, train_acc=0.3
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 2/2 [00:08<00:00,  4.39s/it, loss=2.01, v_num=12, train_acc=0.3
# Epoch 9: 100%|█| 2/2 [00:08<00:00,  4.39s/it, loss=2.01, v_num=12, train_acc=0.3
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Testing: 100%|████████████████████████████████████| 1/1 [00:01<00:00,  1.49s/it]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.4447000026702881, 'test_loss': 2.1517751216888428}
# --------------------------------------------------------------------------------
# Testing: 100%|████████████████████████████████████| 1/1 [00:01<00:00,  1.49s/it]

# %% [markdown]
# ## 四，训练涨分技巧

# %% [markdown]
# pytorch_lightning 可以非常容易地支持以下训练涨分技巧:
#
# * SWA(随机参数平均): 调用pl.callbacks.stochastic_weight_avg.StochasticWeightAveraging实现。
#
# * CyclicLR(学习率周期性调度策略): 设置 lr_scheduler 为 torch.optim.lr_scheduler.CyclicLR实现。
#
# * auto_lr_find最优学习率发现: 设置 pl.Trainer(auto_lr_find = True)实现。
#
#
# 参考论文:
#
# * Cyclical Learning Rates for Training Neural Networks 【https://arxiv.org/pdf/1506.01186.pdf】
#
# * Averaging Weights Leads to Wider Optima and Better Generalization【https://arxiv.org/abs/1803.05407】

# %% [markdown]
# 我们将代码整理成如下形式，以便后续测试使用。

# %%
# %%writefile mnist_cnn.py
import torch 
from torch import nn 
from argparse import ArgumentParser
import numpy as np 

import torchvision 
from torchvision import transforms as T
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader,random_split
import pytorch_lightning as pl
from torchmetrics import Accuracy

#================================================================================
# 一，准备数据
#================================================================================

class MNISTDataModule(pl.LightningDataModule):
    def __init__(self, data_dir: str = "./minist/", 
                 batch_size: int = 32,
                 num_workers: int =4,
                 pin_memory:bool =True):
        super().__init__()
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.pin_memory = pin_memory

    def setup(self, stage = None):
        transform = T.Compose([T.ToTensor()])
        self.ds_test = MNIST(self.data_dir, download=True,train=False,transform=transform)
        self.ds_predict = MNIST(self.data_dir, download=True, train=False,transform=transform)
        ds_full = MNIST(self.data_dir, download=True, train=True,transform=transform)
        ds_train, self.ds_val = random_split(ds_full, [59000, 1000])
        #为加速训练，随机取10000个
        indices = np.arange(59000)
        np.random.shuffle(indices)
        self.ds_train = torch.utils.data.dataset.Subset(
            ds_train,indices = indices[:3000]) 

    def train_dataloader(self):
        return DataLoader(self.ds_train, batch_size=self.batch_size,
                          shuffle=True, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)

    def val_dataloader(self):
        return DataLoader(self.ds_val, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)

    def test_dataloader(self):
        return DataLoader(self.ds_test, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)

    def predict_dataloader(self):
        return DataLoader(self.ds_predict, batch_size=self.batch_size,
                          shuffle=False, num_workers=self.num_workers,
                          pin_memory=self.pin_memory)
    
    @staticmethod
    def add_dataset_args(parent_parser):
        parser = ArgumentParser(parents=[parent_parser], add_help=False)
        parser.add_argument('--batch_size', type=int, default=32)
        parser.add_argument('--num_workers', type=int, default=8)
        parser.add_argument('--pin_memory', type=bool, default=True)
        return parser

#================================================================================
# 二，定义模型
#================================================================================

net = nn.Sequential(
    nn.Conv2d(in_channels=1,out_channels=32,kernel_size = 3),
    nn.MaxPool2d(kernel_size = 2,stride = 2),
    nn.Conv2d(in_channels=32,out_channels=64,kernel_size = 5),
    nn.MaxPool2d(kernel_size = 2,stride = 2),
    nn.Dropout2d(p = 0.1),
    nn.AdaptiveMaxPool2d((1,1)),
    nn.Flatten(),
    nn.Linear(64,32),
    nn.ReLU(),
    nn.Linear(32,10)
)

class Model(pl.LightningModule):
    
    def __init__(self,net,
                 learning_rate=1e-3,
                 use_CyclicLR = False,
                 epoch_size=500):
        super().__init__()
        self.save_hyperparameters() #自动创建self.hparams
        self.net = net
        self.train_acc = Accuracy()
        self.val_acc = Accuracy()
        self.test_acc = Accuracy() 
        
        
    def forward(self,x):
        x = self.net(x)
        return x
    
    
    #定义loss
    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}
    
    #定义各种metrics
    def training_step_end(self,outputs):
        train_acc = self.train_acc(outputs['preds'], outputs['y']).item()    
        self.log("train_acc",train_acc,prog_bar=True)
        return {"loss":outputs["loss"].mean()}
    
    #定义optimizer,以及可选的lr_scheduler
    def configure_optimizers(self):
        optimizer = torch.optim.RMSprop(self.parameters(), lr=self.hparams.learning_rate)
        if not self.hparams.use_CyclicLR:
            return optimizer 

        max_lr = self.hparams.learning_rate
        base_lr = max_lr/4.0
        scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer,
            base_lr=base_lr,max_lr=max_lr,
            step_size_up=5*self.hparams.epoch_size,cycle_momentum=False)
        self.print("set lr = "+str(max_lr))
        
        return ([optimizer],[scheduler])
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}

    def validation_step_end(self,outputs):
        val_acc = self.val_acc(outputs['preds'], outputs['y']).item()    
        self.log("val_loss",outputs["loss"].mean(),on_epoch=True,on_step=False)
        self.log("val_acc",val_acc,prog_bar=True,on_epoch=True,on_step=False)
    
    def test_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = nn.CrossEntropyLoss()(preds,y)
        return {"loss":loss,"preds":preds.detach(),"y":y.detach()}
    
    def test_step_end(self,outputs):
        test_acc = self.test_acc(outputs['preds'], outputs['y']).item()    
        self.log("test_acc",test_acc,on_epoch=True,on_step=False)
        self.log("test_loss",outputs["loss"].mean(),on_epoch=True,on_step=False)
    
    @staticmethod
    def add_model_args(parent_parser):
        parser = ArgumentParser(parents=[parent_parser], add_help=False)
        parser.add_argument('--learning_rate', type=float, default=7e-3)
        parser.add_argument('--use_CyclicLR', type=bool, default=False)
        return parser
    

#================================================================================
# 三，训练模型
#================================================================================
    
def main(hparams):
    pl.seed_everything(1234)
    
    data_mnist = MNISTDataModule(batch_size=hparams.batch_size,
                                 num_workers=hparams.num_workers)
    data_mnist.setup()
    epoch_size = len(data_mnist.ds_train)//data_mnist.batch_size
    
    model = Model(net,learning_rate=hparams.learning_rate,
                  use_CyclicLR = hparams.use_CyclicLR,
                  epoch_size=epoch_size)
    
    ckpt_callback = pl.callbacks.ModelCheckpoint(
        monitor='val_acc',
        save_top_k=3,
        mode='max'
    )
    
    early_stopping = pl.callbacks.EarlyStopping(monitor = 'val_acc',
                   patience=16,
                   mode = 'max')
    callbacks = [ckpt_callback,early_stopping]
    if hparams.use_swa:
        callbacks.append(pl.callbacks.StochasticWeightAveraging())
        
    trainer = pl.Trainer.from_argparse_args( 
        hparams,
        max_epochs=1000,
        callbacks = callbacks) 

    
    print("hparams.auto_lr_find=",hparams.auto_lr_find)
    if hparams.auto_lr_find:
        
        #搜索学习率范围
        lr_finder = trainer.tuner.lr_find(model,
          datamodule = data_mnist,
          min_lr=1e-08,
          max_lr=1,
          num_training=100,
          mode='exponential',
          early_stop_threshold=4.0
          )
        lr_finder.plot() 
        lr = lr_finder.suggestion()
        model.hparams.learning_rate = lr 
        print("suggest lr=",lr)
        
        del model 
        
        hparams.learning_rate = lr
        model = Model(net,learning_rate=hparams.learning_rate,
                  use_CyclicLR = hparams.use_CyclicLR,
                  epoch_size=epoch_size)
        
        #等价于
        #trainer.tune(model,data_mnist)
        

    trainer.fit(model,data_mnist)
    train_result = trainer.test(model,data_mnist.train_dataloader(),ckpt_path='best')
    val_result = trainer.test(model,data_mnist.val_dataloader(),ckpt_path='best')
    test_result = trainer.test(model,data_mnist.test_dataloader(),ckpt_path='best')
    
    print("train_result:\n")
    print(train_result)
    print("val_result:\n")
    print(val_result)
    print("test_result:\n")
    print(test_result)
    
    

if __name__ == "__main__":
    parser = ArgumentParser()
    parser.add_argument('--use_swa', default=False, type=bool)
    parser = MNISTDataModule.add_dataset_args(parser)
    parser = Model.add_model_args(parser)
    parser = pl.Trainer.add_argparse_args(parser)
    hparams = parser.parse_args()
    main(hparams)
# Out:
# Overwriting mnist_cnn.py

# %% [markdown]
# ### 1，SWA 随机权重平均 (pl.callbacks.stochastic_weight_avg.StochasticWeightAveraging)

# %% [markdown]
# * 平凡方式训练：test_acc = 0.9581000208854675
#
# * SWA随机权重： test_acc = 0.963100016117096

# %%
#平凡方式训练
# !python3 mnist_cnn.py --gpus=2 --strategy="ddp_find_unused_parameters_false"
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Global seed set to 1234
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (47) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# Epoch 0:  75%|▋| 47/63 [00:02<00:00, 18.14it/s, loss=2.17, v_num=3, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 0:  78%|▊| 49/63 [00:02<00:00, 16.42it/s, loss=2.17, v_num=3, train_acc=0.
# Epoch 0: 100%|█| 63/63 [00:03<00:00, 17.40it/s, loss=2.17, v_num=3, train_acc=0.
# Epoch 1:  76%|▊| 48/63 [00:02<00:00, 20.70it/s, loss=1.65, v_num=3, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 1:  81%|▊| 51/63 [00:02<00:00, 18.81it/s, loss=1.65, v_num=3, train_acc=0.
# Epoch 1: 100%|█| 63/63 [00:03<00:00, 18.96it/s, loss=1.65, v_num=3, train_acc=0.
# Epoch 2:  76%|▊| 48/63 [00:02<00:00, 20.64it/s, loss=0.913, v_num=3, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 2:  81%|▊| 51/63 [00:02<00:00, 18.71it/s, loss=0.913, v_num=3, train_acc=0
# Epoch 2: 100%|█| 63/63 [00:03<00:00, 18.81it/s, loss=0.913, v_num=3, train_acc=0
# Epoch 3:  76%|▊| 48/63 [00:02<00:00, 20.38it/s, loss=0.8, v_num=3, train_acc=0.8
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 3:  81%|▊| 51/63 [00:02<00:00, 18.47it/s, loss=0.8, v_num=3, train_acc=0.8
# Epoch 3: 100%|█| 63/63 [00:03<00:00, 18.70it/s, loss=0.8, v_num=3, train_acc=0.8
# Epoch 4:  76%|▊| 48/63 [00:02<00:00, 20.64it/s, loss=0.48, v_num=3, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 4:  81%|▊| 51/63 [00:02<00:00, 18.74it/s, loss=0.48, v_num=3, train_acc=0.
# Epoch 4: 100%|█| 63/63 [00:03<00:00, 18.81it/s, loss=0.48, v_num=3, train_acc=0.
# Epoch 5:  76%|▊| 48/63 [00:02<00:00, 20.49it/s, loss=0.34, v_num=3, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 5:  81%|▊| 51/63 [00:02<00:00, 18.44it/s, loss=0.34, v_num=3, train_acc=0.
# Epoch 5: 100%|█| 63/63 [00:03<00:00, 18.56it/s, loss=0.34, v_num=3, train_acc=0.
# Epoch 6:  76%|▊| 48/63 [00:02<00:00, 19.81it/s, loss=0.28, v_num=3, train_acc=1.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 6:  81%|▊| 51/63 [00:02<00:00, 17.95it/s, loss=0.28, v_num=3, train_acc=1.
# Epoch 6: 100%|█| 63/63 [00:03<00:00, 18.27it/s, loss=0.28, v_num=3, train_acc=1.
# Epoch 7:  76%|▊| 48/63 [00:02<00:00, 20.28it/s, loss=0.983, v_num=3, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 7:  81%|▊| 51/63 [00:02<00:00, 18.28it/s, loss=0.983, v_num=3, train_acc=0
# Epoch 7: 100%|█| 63/63 [00:03<00:00, 18.54it/s, loss=0.983, v_num=3, train_acc=0
# Epoch 8:  76%|▊| 48/63 [00:02<00:00, 19.85it/s, loss=0.203, v_num=3, train_acc=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 8:  81%|▊| 51/63 [00:02<00:00, 17.98it/s, loss=0.203, v_num=3, train_acc=1
# Epoch 8: 100%|█| 63/63 [00:03<00:00, 18.15it/s, loss=0.203, v_num=3, train_acc=1
# Epoch 9:  76%|▊| 48/63 [00:02<00:00, 19.96it/s, loss=0.225, v_num=3, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 9:  81%|▊| 51/63 [00:02<00:00, 18.00it/s, loss=0.225, v_num=3, train_acc=0
# Epoch 9: 100%|█| 63/63 [00:03<00:00, 18.34it/s, loss=0.225, v_num=3, train_acc=0
# Epoch 10:  76%|▊| 48/63 [00:02<00:00, 19.77it/s, loss=0.796, v_num=3, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 10:  81%|▊| 51/63 [00:02<00:00, 17.87it/s, loss=0.796, v_num=3, train_acc=
# Epoch 10: 100%|█| 63/63 [00:03<00:00, 18.29it/s, loss=0.796, v_num=3, train_acc=
# Epoch 11:  76%|▊| 48/63 [00:02<00:00, 20.05it/s, loss=0.15, v_num=3, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 11:  81%|▊| 51/63 [00:02<00:00, 18.12it/s, loss=0.15, v_num=3, train_acc=0
# Epoch 11: 100%|█| 63/63 [00:03<00:00, 18.37it/s, loss=0.15, v_num=3, train_acc=0
# Epoch 12:  76%|▊| 48/63 [00:02<00:00, 19.68it/s, loss=0.0767, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 12:  81%|▊| 51/63 [00:02<00:00, 17.79it/s, loss=0.0767, v_num=3, train_acc
# Epoch 12: 100%|█| 63/63 [00:03<00:00, 18.07it/s, loss=0.0767, v_num=3, train_acc
# Epoch 13:  76%|▊| 48/63 [00:02<00:00, 20.01it/s, loss=0.0841, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 13:  81%|▊| 51/63 [00:02<00:00, 18.14it/s, loss=0.0841, v_num=3, train_acc
# Epoch 13: 100%|█| 63/63 [00:03<00:00, 18.31it/s, loss=0.0841, v_num=3, train_acc
# Epoch 14:  76%|▊| 48/63 [00:02<00:00, 20.10it/s, loss=0.0821, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 14:  81%|▊| 51/63 [00:02<00:00, 18.12it/s, loss=0.0821, v_num=3, train_acc
# Epoch 14: 100%|█| 63/63 [00:03<00:00, 18.49it/s, loss=0.0821, v_num=3, train_acc
# Epoch 15:  76%|▊| 48/63 [00:02<00:00, 20.43it/s, loss=0.0548, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 15:  81%|▊| 51/63 [00:02<00:00, 18.50it/s, loss=0.0548, v_num=3, train_acc
# Epoch 15: 100%|█| 63/63 [00:03<00:00, 18.67it/s, loss=0.0548, v_num=3, train_acc
# Epoch 16:  76%|▊| 48/63 [00:02<00:00, 20.69it/s, loss=2.05, v_num=3, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 16:  81%|▊| 51/63 [00:02<00:00, 18.67it/s, loss=2.05, v_num=3, train_acc=0
# Epoch 16: 100%|█| 63/63 [00:03<00:00, 18.87it/s, loss=2.05, v_num=3, train_acc=0
# Epoch 17:  76%|▊| 48/63 [00:02<00:00, 20.86it/s, loss=0.116, v_num=3, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 17:  81%|▊| 51/63 [00:02<00:00, 18.83it/s, loss=0.116, v_num=3, train_acc=
# Epoch 17: 100%|█| 63/63 [00:03<00:00, 18.95it/s, loss=0.116, v_num=3, train_acc=
# Epoch 18:  76%|▊| 48/63 [00:02<00:00, 20.65it/s, loss=0.0519, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 18:  81%|▊| 51/63 [00:02<00:00, 18.73it/s, loss=0.0519, v_num=3, train_acc
# Epoch 18: 100%|█| 63/63 [00:03<00:00, 18.80it/s, loss=0.0519, v_num=3, train_acc
# Epoch 19:  76%|▊| 48/63 [00:02<00:00, 20.86it/s, loss=0.0401, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 19:  81%|▊| 51/63 [00:02<00:00, 18.79it/s, loss=0.0401, v_num=3, train_acc
# Epoch 19: 100%|█| 63/63 [00:03<00:00, 18.80it/s, loss=0.0401, v_num=3, train_acc
# Epoch 20:  76%|▊| 48/63 [00:02<00:00, 20.23it/s, loss=0.0385, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 20:  81%|▊| 51/63 [00:02<00:00, 18.19it/s, loss=0.0385, v_num=3, train_acc
# Epoch 20: 100%|█| 63/63 [00:03<00:00, 18.46it/s, loss=0.0385, v_num=3, train_acc
# Epoch 21:  76%|▊| 48/63 [00:02<00:00, 20.16it/s, loss=0.533, v_num=3, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 21:  81%|▊| 51/63 [00:02<00:00, 18.26it/s, loss=0.533, v_num=3, train_acc=
# Epoch 21: 100%|█| 63/63 [00:03<00:00, 18.45it/s, loss=0.533, v_num=3, train_acc=
# Epoch 22:  76%|▊| 48/63 [00:02<00:00, 19.86it/s, loss=0.0419, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 22:  81%|▊| 51/63 [00:02<00:00, 17.98it/s, loss=0.0419, v_num=3, train_acc
# Epoch 22: 100%|█| 63/63 [00:03<00:00, 18.15it/s, loss=0.0419, v_num=3, train_acc
# Epoch 23:  76%|▊| 48/63 [00:02<00:00, 20.05it/s, loss=0.0225, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 23:  81%|▊| 51/63 [00:02<00:00, 18.20it/s, loss=0.0225, v_num=3, train_acc
# Epoch 23: 100%|█| 63/63 [00:03<00:00, 18.32it/s, loss=0.0225, v_num=3, train_acc
# Epoch 24:  76%|▊| 48/63 [00:02<00:00, 20.55it/s, loss=0.217, v_num=3, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 24:  81%|▊| 51/63 [00:02<00:00, 18.55it/s, loss=0.217, v_num=3, train_acc=
# Epoch 24: 100%|█| 63/63 [00:03<00:00, 18.61it/s, loss=0.217, v_num=3, train_acc=
# Epoch 25:  76%|▊| 48/63 [00:02<00:00, 20.13it/s, loss=0.0376, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 25:  81%|▊| 51/63 [00:02<00:00, 18.24it/s, loss=0.0376, v_num=3, train_acc
# Epoch 25: 100%|█| 63/63 [00:03<00:00, 18.57it/s, loss=0.0376, v_num=3, train_acc
# Epoch 26:  76%|▊| 48/63 [00:02<00:00, 20.44it/s, loss=0.0398, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 26:  81%|▊| 51/63 [00:02<00:00, 18.37it/s, loss=0.0398, v_num=3, train_acc
# Epoch 26: 100%|█| 63/63 [00:03<00:00, 18.80it/s, loss=0.0398, v_num=3, train_acc
# Epoch 27:  76%|▊| 48/63 [00:02<00:00, 20.82it/s, loss=3.13, v_num=3, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 27:  81%|▊| 51/63 [00:02<00:00, 18.79it/s, loss=3.13, v_num=3, train_acc=0
# Epoch 27: 100%|█| 63/63 [00:03<00:00, 19.05it/s, loss=3.13, v_num=3, train_acc=0
# Epoch 28:  76%|▊| 48/63 [00:02<00:00, 20.78it/s, loss=0.0784, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 28:  81%|▊| 51/63 [00:02<00:00, 18.80it/s, loss=0.0784, v_num=3, train_acc
# Epoch 28: 100%|█| 63/63 [00:03<00:00, 18.93it/s, loss=0.0784, v_num=3, train_acc
# Epoch 29:  76%|▊| 48/63 [00:02<00:00, 21.07it/s, loss=0.0301, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 29:  81%|▊| 51/63 [00:02<00:00, 19.07it/s, loss=0.0301, v_num=3, train_acc
# Epoch 29: 100%|█| 63/63 [00:03<00:00, 19.13it/s, loss=0.0301, v_num=3, train_acc
# Epoch 30:  76%|▊| 48/63 [00:02<00:00, 20.59it/s, loss=0.0128, v_num=3, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 30:  81%|▊| 51/63 [00:02<00:00, 18.68it/s, loss=0.0128, v_num=3, train_acc
# Epoch 30: 100%|█| 63/63 [00:03<00:00, 18.84it/s, loss=0.0128, v_num=3, train_acc
# Epoch 30: 100%|█| 63/63 [00:03<00:00, 18.73it/s, loss=0.0128, v_num=3, train_acc
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_3/checkpoints/epoch=14-step=704.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_3/checkpoints/epoch=14-step=704.ckpt
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:662: UserWarning: Your `test_dataloader` has `shuffle=True`, it is strongly recommended that you turn this off for val/test/predict dataloaders.
#   category=UserWarning,
# Testing:  83%|████████████████████████████▏     | 39/47 [00:00<00:00, 84.54it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.996666669845581, 'test_loss': 0.02135266177356243}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 47/47 [00:02<00:00, 22.11it/s]
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_3/checkpoints/epoch=14-step=704.ckpt
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_3/checkpoints/epoch=14-step=704.ckpt
# Testing: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 36.09it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9620000123977661, 'test_loss': 0.14162316918373108}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 16/16 [00:01<00:00, 15.29it/s]
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.teardown has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.teardown.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_3/checkpoints/epoch=14-step=704.ckpt
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_3/checkpoints/epoch=14-step=704.ckpt
# Testing: 100%|███████████████████████████████| 157/157 [00:01<00:00, 136.93it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9581000208854675, 'test_loss': 0.14859822392463684}
# --------------------------------------------------------------------------------
# Testing: 100%|████████████████████████████████| 157/157 [00:05<00:00, 26.47it/s]
# train_result:
#
# [{'test_acc': 0.996666669845581, 'test_loss': 0.02135266177356243}]
# val_result:
#
# [{'test_acc': 0.9620000123977661, 'test_loss': 0.14162316918373108}]
# test_result:
#
# [{'test_acc': 0.9581000208854675, 'test_loss': 0.14859822392463684}]
# train_result:
#
# [{'test_acc': 0.996666669845581, 'test_loss': 0.02135266177356243}]
# val_result:
#
# [{'test_acc': 0.9620000123977661, 'test_loss': 0.14162316918373108}]
# test_result:
#
# [{'test_acc': 0.9581000208854675, 'test_loss': 0.14859822392463684}]

# %% [markdown]
# ```
# ------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9581000208854675, 'test_loss': 0.14859822392463684}
# --------------------------------------------------------------------------------
# ```

# %%
#使用SWA随机权重
# !python3 mnist_cnn.py --gpus=2 --strategy="ddp_find_unused_parameters_false" --use_swa=True
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Global seed set to 1234
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (47) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# Epoch 0:  75%|▋| 47/63 [00:02<00:00, 16.73it/s, loss=2.21, v_num=5, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 0:  78%|▊| 49/63 [00:03<00:00, 14.77it/s, loss=2.21, v_num=5, train_acc=0.
# Epoch 0: 100%|█| 63/63 [00:03<00:00, 15.85it/s, loss=2.21, v_num=5, train_acc=0.
# Epoch 1:  76%|▊| 48/63 [00:02<00:00, 18.82it/s, loss=1.93, v_num=5, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 1:  81%|▊| 51/63 [00:03<00:00, 16.69it/s, loss=1.93, v_num=5, train_acc=0.
# Epoch 1: 100%|█| 63/63 [00:03<00:00, 17.12it/s, loss=1.93, v_num=5, train_acc=0.
# Epoch 2:  76%|▊| 48/63 [00:02<00:00, 18.84it/s, loss=1.29, v_num=5, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 2:  81%|▊| 51/63 [00:03<00:00, 16.67it/s, loss=1.29, v_num=5, train_acc=0.
# Epoch 2: 100%|█| 63/63 [00:03<00:00, 16.98it/s, loss=1.29, v_num=5, train_acc=0.
# Epoch 3:  76%|▊| 48/63 [00:02<00:00, 18.84it/s, loss=0.801, v_num=5, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 3:  81%|▊| 51/63 [00:03<00:00, 16.53it/s, loss=0.801, v_num=5, train_acc=0
# Epoch 3: 100%|█| 63/63 [00:03<00:00, 16.88it/s, loss=0.801, v_num=5, train_acc=0
# Epoch 4:  76%|▊| 48/63 [00:02<00:00, 19.13it/s, loss=0.486, v_num=5, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 4:  81%|▊| 51/63 [00:03<00:00, 16.92it/s, loss=0.486, v_num=5, train_acc=0
# Epoch 4: 100%|█| 63/63 [00:03<00:00, 17.19it/s, loss=0.486, v_num=5, train_acc=0
# Epoch 5:  76%|▊| 48/63 [00:02<00:00, 18.84it/s, loss=0.247, v_num=5, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 5:  81%|▊| 51/63 [00:03<00:00, 16.74it/s, loss=0.247, v_num=5, train_acc=0
# Epoch 5: 100%|█| 63/63 [00:03<00:00, 17.09it/s, loss=0.247, v_num=5, train_acc=0
# Epoch 6:  76%|▊| 48/63 [00:02<00:00, 18.74it/s, loss=0.448, v_num=5, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 6:  81%|▊| 51/63 [00:03<00:00, 16.57it/s, loss=0.448, v_num=5, train_acc=0
# Epoch 6: 100%|█| 63/63 [00:03<00:00, 16.92it/s, loss=0.448, v_num=5, train_acc=0
# Epoch 7:  76%|▊| 48/63 [00:02<00:00, 18.69it/s, loss=0.192, v_num=5, train_acc=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 7:  81%|▊| 51/63 [00:03<00:00, 16.49it/s, loss=0.192, v_num=5, train_acc=1
# Epoch 7: 100%|█| 63/63 [00:03<00:00, 16.85it/s, loss=0.192, v_num=5, train_acc=1
# Epoch 8:  76%|▊| 48/63 [00:02<00:00, 18.52it/s, loss=0.181, v_num=5, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 8:  81%|▊| 51/63 [00:03<00:00, 16.41it/s, loss=0.181, v_num=5, train_acc=0
# Epoch 8: 100%|█| 63/63 [00:03<00:00, 16.88it/s, loss=0.181, v_num=5, train_acc=0
# Epoch 9:  76%|▊| 48/63 [00:02<00:00, 18.79it/s, loss=0.599, v_num=5, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 9:  81%|▊| 51/63 [00:03<00:00, 16.62it/s, loss=0.599, v_num=5, train_acc=0
# Epoch 9: 100%|█| 63/63 [00:03<00:00, 17.08it/s, loss=0.599, v_num=5, train_acc=0
# Epoch 10:  76%|▊| 48/63 [00:02<00:00, 18.67it/s, loss=0.0882, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 10:  81%|▊| 51/63 [00:03<00:00, 16.45it/s, loss=0.0882, v_num=5, train_acc
# Epoch 10: 100%|█| 63/63 [00:03<00:00, 16.88it/s, loss=0.0882, v_num=5, train_acc
# Epoch 11:  76%|▊| 48/63 [00:02<00:00, 18.73it/s, loss=0.0923, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 11:  81%|▊| 51/63 [00:03<00:00, 16.55it/s, loss=0.0923, v_num=5, train_acc
# Epoch 11: 100%|█| 63/63 [00:03<00:00, 16.79it/s, loss=0.0923, v_num=5, train_acc
# Epoch 12:  76%|▊| 48/63 [00:02<00:00, 18.52it/s, loss=0.124, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 12:  81%|▊| 51/63 [00:03<00:00, 16.39it/s, loss=0.124, v_num=5, train_acc=
# Epoch 12: 100%|█| 63/63 [00:03<00:00, 16.70it/s, loss=0.124, v_num=5, train_acc=
# Epoch 13:  76%|▊| 48/63 [00:02<00:00, 18.48it/s, loss=0.271, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 13:  81%|▊| 51/63 [00:03<00:00, 16.28it/s, loss=0.271, v_num=5, train_acc=
# Epoch 13: 100%|█| 63/63 [00:03<00:00, 16.78it/s, loss=0.271, v_num=5, train_acc=
# Epoch 14:  76%|▊| 48/63 [00:02<00:00, 18.56it/s, loss=0.2, v_num=5, train_acc=1.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 14:  81%|▊| 51/63 [00:03<00:00, 16.45it/s, loss=0.2, v_num=5, train_acc=1.
# Epoch 14: 100%|█| 63/63 [00:03<00:00, 16.83it/s, loss=0.2, v_num=5, train_acc=1.
# Epoch 15:  76%|▊| 48/63 [00:02<00:00, 19.29it/s, loss=0.076, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 15:  81%|▊| 51/63 [00:02<00:00, 17.05it/s, loss=0.076, v_num=5, train_acc=
# Epoch 15: 100%|█| 63/63 [00:03<00:00, 17.32it/s, loss=0.076, v_num=5, train_acc=
# Epoch 16:  76%|▊| 48/63 [00:02<00:00, 19.44it/s, loss=0.11, v_num=5, train_acc=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 16:  81%|▊| 51/63 [00:02<00:00, 17.10it/s, loss=0.11, v_num=5, train_acc=1
# Epoch 16: 100%|█| 63/63 [00:03<00:00, 17.49it/s, loss=0.11, v_num=5, train_acc=1
# Epoch 17:  76%|▊| 48/63 [00:02<00:00, 19.36it/s, loss=0.131, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 17:  81%|▊| 51/63 [00:02<00:00, 17.08it/s, loss=0.131, v_num=5, train_acc=
# Epoch 17: 100%|█| 63/63 [00:03<00:00, 17.31it/s, loss=0.131, v_num=5, train_acc=
# Epoch 18:  76%|▊| 48/63 [00:02<00:00, 19.35it/s, loss=0.0798, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 18:  81%|▊| 51/63 [00:02<00:00, 17.14it/s, loss=0.0798, v_num=5, train_acc
# Epoch 18: 100%|█| 63/63 [00:03<00:00, 17.44it/s, loss=0.0798, v_num=5, train_acc
# Epoch 19:  76%|▊| 48/63 [00:02<00:00, 19.30it/s, loss=0.0513, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 19:  81%|▊| 51/63 [00:03<00:00, 16.99it/s, loss=0.0513, v_num=5, train_acc
# Epoch 19: 100%|█| 63/63 [00:03<00:00, 17.28it/s, loss=0.0513, v_num=5, train_acc
# Epoch 20:  76%|▊| 48/63 [00:02<00:00, 18.89it/s, loss=0.158, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 20:  81%|▊| 51/63 [00:03<00:00, 16.61it/s, loss=0.158, v_num=5, train_acc=
# Epoch 20: 100%|█| 63/63 [00:03<00:00, 16.89it/s, loss=0.158, v_num=5, train_acc=
# Epoch 21:  76%|▊| 48/63 [00:02<00:00, 18.67it/s, loss=0.0401, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 21:  81%|▊| 51/63 [00:03<00:00, 16.57it/s, loss=0.0401, v_num=5, train_acc
# Epoch 21: 100%|█| 63/63 [00:03<00:00, 16.93it/s, loss=0.0401, v_num=5, train_acc
# Epoch 22:  76%|▊| 48/63 [00:02<00:00, 18.54it/s, loss=0.0472, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 22:  81%|▊| 51/63 [00:03<00:00, 16.38it/s, loss=0.0472, v_num=5, train_acc
# Epoch 22: 100%|█| 63/63 [00:03<00:00, 16.78it/s, loss=0.0472, v_num=5, train_acc
# Epoch 23:  76%|▊| 48/63 [00:02<00:00, 18.60it/s, loss=0.0338, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 23:  81%|▊| 51/63 [00:03<00:00, 16.31it/s, loss=0.0338, v_num=5, train_acc
# Epoch 23: 100%|█| 63/63 [00:03<00:00, 16.85it/s, loss=0.0338, v_num=5, train_acc
# Epoch 24:  76%|▊| 48/63 [00:02<00:00, 18.66it/s, loss=0.0156, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 24:  81%|▊| 51/63 [00:03<00:00, 16.51it/s, loss=0.0156, v_num=5, train_acc
# Epoch 24: 100%|█| 63/63 [00:03<00:00, 16.99it/s, loss=0.0156, v_num=5, train_acc
# Epoch 25:  76%|▊| 48/63 [00:02<00:00, 18.61it/s, loss=0.049, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 25:  81%|▊| 51/63 [00:03<00:00, 16.24it/s, loss=0.049, v_num=5, train_acc=
# Epoch 25: 100%|█| 63/63 [00:03<00:00, 16.58it/s, loss=0.049, v_num=5, train_acc=
# Epoch 26:  76%|▊| 48/63 [00:02<00:00, 18.59it/s, loss=0.0388, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 26:  81%|▊| 51/63 [00:03<00:00, 16.42it/s, loss=0.0388, v_num=5, train_acc
# Epoch 26: 100%|█| 63/63 [00:03<00:00, 16.78it/s, loss=0.0388, v_num=5, train_acc
# Epoch 27:  76%|▊| 48/63 [00:02<00:00, 18.68it/s, loss=0.0194, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 27:  81%|▊| 51/63 [00:03<00:00, 16.55it/s, loss=0.0194, v_num=5, train_acc
# Epoch 27: 100%|█| 63/63 [00:03<00:00, 17.03it/s, loss=0.0194, v_num=5, train_acc
# Epoch 28:  76%|▊| 48/63 [00:02<00:00, 18.86it/s, loss=0.0535, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 28:  81%|▊| 51/63 [00:03<00:00, 16.73it/s, loss=0.0535, v_num=5, train_acc
# Epoch 28: 100%|█| 63/63 [00:03<00:00, 16.91it/s, loss=0.0535, v_num=5, train_acc
# Epoch 29:  76%|▊| 48/63 [00:02<00:00, 19.45it/s, loss=1.83, v_num=5, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 29:  81%|▊| 51/63 [00:02<00:00, 17.18it/s, loss=1.83, v_num=5, train_acc=0
# Epoch 29: 100%|█| 63/63 [00:03<00:00, 17.40it/s, loss=1.83, v_num=5, train_acc=0
# Epoch 30:  76%|▊| 48/63 [00:02<00:00, 18.97it/s, loss=0.0553, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 30:  81%|▊| 51/63 [00:03<00:00, 16.79it/s, loss=0.0553, v_num=5, train_acc
# Epoch 30: 100%|█| 63/63 [00:03<00:00, 17.24it/s, loss=0.0553, v_num=5, train_acc
# Epoch 31:  76%|▊| 48/63 [00:02<00:00, 19.26it/s, loss=0.0287, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 31:  81%|▊| 51/63 [00:02<00:00, 17.04it/s, loss=0.0287, v_num=5, train_acc
# Epoch 31: 100%|█| 63/63 [00:03<00:00, 17.26it/s, loss=0.0287, v_num=5, train_acc
# Epoch 32:  76%|▊| 48/63 [00:02<00:00, 19.32it/s, loss=0.0206, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 32:  81%|▊| 51/63 [00:02<00:00, 17.11it/s, loss=0.0206, v_num=5, train_acc
# Epoch 32: 100%|█| 63/63 [00:03<00:00, 17.36it/s, loss=0.0206, v_num=5, train_acc
# Epoch 33:  76%|▊| 48/63 [00:02<00:00, 18.59it/s, loss=0.0221, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 33:  81%|▊| 51/63 [00:03<00:00, 16.36it/s, loss=0.0221, v_num=5, train_acc
# Epoch 33: 100%|█| 63/63 [00:03<00:00, 16.84it/s, loss=0.0221, v_num=5, train_acc
# Epoch 34:  76%|▊| 48/63 [00:02<00:00, 18.70it/s, loss=0.0704, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 34:  81%|▊| 51/63 [00:03<00:00, 16.29it/s, loss=0.0704, v_num=5, train_acc
# Epoch 34: 100%|█| 63/63 [00:03<00:00, 17.00it/s, loss=0.0704, v_num=5, train_acc
# Epoch 35:  76%|▊| 48/63 [00:02<00:00, 18.79it/s, loss=0.0251, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 35:  81%|▊| 51/63 [00:03<00:00, 16.67it/s, loss=0.0251, v_num=5, train_acc
# Epoch 35: 100%|█| 63/63 [00:03<00:00, 16.93it/s, loss=0.0251, v_num=5, train_acc
# Epoch 36:  76%|▊| 48/63 [00:02<00:00, 18.62it/s, loss=0.0133, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 36:  81%|▊| 51/63 [00:03<00:00, 16.27it/s, loss=0.0133, v_num=5, train_acc
# Epoch 36: 100%|█| 63/63 [00:03<00:00, 16.89it/s, loss=0.0133, v_num=5, train_acc
# Epoch 37:  76%|▊| 48/63 [00:02<00:00, 18.64it/s, loss=0.0389, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 37:  81%|▊| 51/63 [00:03<00:00, 16.43it/s, loss=0.0389, v_num=5, train_acc
# Epoch 37: 100%|█| 63/63 [00:03<00:00, 16.82it/s, loss=0.0389, v_num=5, train_acc
# Epoch 38:  76%|▊| 48/63 [00:02<00:00, 18.71it/s, loss=0.0219, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 38:  81%|▊| 51/63 [00:03<00:00, 16.52it/s, loss=0.0219, v_num=5, train_acc
# Epoch 38: 100%|█| 63/63 [00:03<00:00, 16.95it/s, loss=0.0219, v_num=5, train_acc
# Epoch 39:  76%|▊| 48/63 [00:02<00:00, 18.49it/s, loss=1.46, v_num=5, train_acc=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 39:  81%|▊| 51/63 [00:03<00:00, 16.40it/s, loss=1.46, v_num=5, train_acc=1
# Epoch 39: 100%|█| 63/63 [00:03<00:00, 16.67it/s, loss=1.46, v_num=5, train_acc=1
# Epoch 40:  76%|▊| 48/63 [00:02<00:00, 18.82it/s, loss=0.0498, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 40:  81%|▊| 51/63 [00:03<00:00, 16.63it/s, loss=0.0498, v_num=5, train_acc
# Epoch 40: 100%|█| 63/63 [00:03<00:00, 17.13it/s, loss=0.0498, v_num=5, train_acc
# Epoch 41:  76%|▊| 48/63 [00:02<00:00, 18.41it/s, loss=0.0128, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 41:  81%|▊| 51/63 [00:03<00:00, 16.24it/s, loss=0.0128, v_num=5, train_acc
# Epoch 41: 100%|█| 63/63 [00:03<00:00, 16.69it/s, loss=0.0128, v_num=5, train_acc
# Epoch 42:  76%|▊| 48/63 [00:02<00:00, 18.94it/s, loss=0.0136, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 42:  81%|▊| 51/63 [00:03<00:00, 16.71it/s, loss=0.0136, v_num=5, train_acc
# Epoch 42: 100%|█| 63/63 [00:03<00:00, 17.30it/s, loss=0.0136, v_num=5, train_acc
# Epoch 43:  76%|▊| 48/63 [00:02<00:00, 19.06it/s, loss=0.0176, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 43:  81%|▊| 51/63 [00:03<00:00, 16.90it/s, loss=0.0176, v_num=5, train_acc
# Epoch 43: 100%|█| 63/63 [00:03<00:00, 17.17it/s, loss=0.0176, v_num=5, train_acc
# Epoch 44:  76%|▊| 48/63 [00:02<00:00, 19.33it/s, loss=0.131, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 44:  81%|▊| 51/63 [00:03<00:00, 16.98it/s, loss=0.131, v_num=5, train_acc=
# Epoch 44: 100%|█| 63/63 [00:03<00:00, 17.36it/s, loss=0.131, v_num=5, train_acc=
# Epoch 45:  76%|▊| 48/63 [00:02<00:00, 19.59it/s, loss=0.0284, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 45:  81%|▊| 51/63 [00:02<00:00, 17.27it/s, loss=0.0284, v_num=5, train_acc
# Epoch 45: 100%|█| 63/63 [00:03<00:00, 17.51it/s, loss=0.0284, v_num=5, train_acc
# Epoch 46:  76%|▊| 48/63 [00:02<00:00, 19.21it/s, loss=0.684, v_num=5, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 46:  81%|▊| 51/63 [00:03<00:00, 16.99it/s, loss=0.684, v_num=5, train_acc=
# Epoch 46: 100%|█| 63/63 [00:03<00:00, 17.40it/s, loss=0.684, v_num=5, train_acc=
# Epoch 47:  76%|▊| 48/63 [00:02<00:00, 19.03it/s, loss=0.0317, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 47:  81%|▊| 51/63 [00:03<00:00, 16.77it/s, loss=0.0317, v_num=5, train_acc
# Epoch 47: 100%|█| 63/63 [00:03<00:00, 17.16it/s, loss=0.0317, v_num=5, train_acc
# Epoch 48:  76%|▊| 48/63 [00:02<00:00, 19.03it/s, loss=0.00829, v_num=5, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 48:  81%|▊| 51/63 [00:03<00:00, 16.89it/s, loss=0.00829, v_num=5, train_ac
# Epoch 48: 100%|█| 63/63 [00:03<00:00, 16.98it/s, loss=0.00829, v_num=5, train_ac
# Epoch 49:  76%|▊| 48/63 [00:02<00:00, 19.09it/s, loss=0.00588, v_num=5, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 49:  81%|▊| 51/63 [00:03<00:00, 16.77it/s, loss=0.00588, v_num=5, train_ac
# Epoch 49: 100%|█| 63/63 [00:03<00:00, 17.24it/s, loss=0.00588, v_num=5, train_ac
# Epoch 50:  76%|▊| 48/63 [00:02<00:00, 18.79it/s, loss=0.0282, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 50:  81%|▊| 51/63 [00:03<00:00, 16.64it/s, loss=0.0282, v_num=5, train_acc
# Epoch 50: 100%|█| 63/63 [00:03<00:00, 17.06it/s, loss=0.0282, v_num=5, train_acc
# Epoch 51:  76%|▊| 48/63 [00:02<00:00, 18.93it/s, loss=0.0103, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 51:  81%|▊| 51/63 [00:03<00:00, 16.79it/s, loss=0.0103, v_num=5, train_acc
# Epoch 51: 100%|█| 63/63 [00:03<00:00, 17.00it/s, loss=0.0103, v_num=5, train_acc
# Epoch 52:  76%|▊| 48/63 [00:02<00:00, 19.02it/s, loss=0.0122, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 52:  81%|▊| 51/63 [00:03<00:00, 16.23it/s, loss=0.0122, v_num=5, train_acc
# Epoch 52: 100%|█| 63/63 [00:03<00:00, 17.08it/s, loss=0.0122, v_num=5, train_acc
# Epoch 53:  76%|▊| 48/63 [00:02<00:00, 17.87it/s, loss=0.0657, v_num=5, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 53:  81%|▊| 51/63 [00:03<00:00, 16.00it/s, loss=0.0657, v_num=5, train_acc
# Epoch 53: 100%|█| 63/63 [00:03<00:00, 16.36it/s, loss=0.0657, v_num=5, train_acc
# Epoch 53: 100%|█| 63/63 [00:03<00:00, 16.27it/s, loss=0.0657, v_num=5, train_acc
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_5/checkpoints/epoch=37-step=1785.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_5/checkpoints/epoch=37-step=1785.ckpt
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:662: UserWarning: Your `test_dataloader` has `shuffle=True`, it is strongly recommended that you turn this off for val/test/predict dataloaders.
#   category=UserWarning,
# Testing:  85%|████████████████████████████▉     | 40/47 [00:00<00:00, 78.94it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9993333220481873, 'test_loss': 0.004299486521631479}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 47/47 [00:02<00:00, 20.94it/s]
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_5/checkpoints/epoch=37-step=1785.ckpt
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_5/checkpoints/epoch=37-step=1785.ckpt
# Testing: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 31.38it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9700000286102295, 'test_loss': 0.1477910727262497}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 16/16 [00:01<00:00, 14.15it/s]
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.teardown has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.teardown.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_5/checkpoints/epoch=37-step=1785.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_5/checkpoints/epoch=37-step=1785.ckpt
# Testing:  95%|█████████████████████████████▍ | 149/157 [00:01<00:00, 166.43it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.963100016117096, 'test_loss': 0.18146753311157227}
# --------------------------------------------------------------------------------
# Testing: 100%|████████████████████████████████| 157/157 [00:06<00:00, 25.87it/s]
# train_result:
#
# [{'test_acc': 0.9993333220481873, 'test_loss': 0.004299486521631479}]
# val_result:
#
# [{'test_acc': 0.9700000286102295, 'test_loss': 0.1477910727262497}]
# test_result:
#
# [{'test_acc': 0.963100016117096, 'test_loss': 0.18146753311157227}]
# train_result:
#
# [{'test_acc': 0.9993333220481873, 'test_loss': 0.004299486521631479}]
# val_result:
#
# [{'test_acc': 0.9700000286102295, 'test_loss': 0.1477910727262497}]
# test_result:
#
# [{'test_acc': 0.963100016117096, 'test_loss': 0.18146753311157227}]

# %% [markdown]
# ```
# -----------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.963100016117096, 'test_loss': 0.18146753311157227}
# --------------------------------------------------------------------------------
# ```

# %% [markdown]
# ### 2，CyclicLR学习率调度策略（torch.optim.lr_scheduler.CyclicLR）

# %% [markdown]
# * 平凡方式训练：test_acc = 0.9581000208854675
#
# * SWA随机权重： test_acc = 0.963100016117096
#
# * SWA随机权重 + CyClicLR学习率调度策略: test_acc = 0.9688000082969666

# %%
# !python3 mnist_cnn.py --gpus=2 --strategy="ddp_find_unused_parameters_false" --use_swa=True --use_CyclicLR=True
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Global seed set to 1234
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# Global seed set to 1234
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Global seed set to 1234
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:433: UserWarning: The number of training samples (47) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# Epoch 0:  75%|▋| 47/63 [00:02<00:00, 17.80it/s, loss=1.28, v_num=6, train_acc=0.
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 0:  78%|▊| 49/63 [00:03<00:00, 15.63it/s, loss=1.28, v_num=6, train_acc=0.
# Epoch 0: 100%|█| 63/63 [00:03<00:00, 16.65it/s, loss=1.28, v_num=6, train_acc=0.
# Epoch 1:  76%|▊| 48/63 [00:02<00:00, 19.68it/s, loss=0.544, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 1:  81%|▊| 51/63 [00:02<00:00, 17.35it/s, loss=0.544, v_num=6, train_acc=0
# Epoch 1: 100%|█| 63/63 [00:03<00:00, 17.61it/s, loss=0.544, v_num=6, train_acc=0
# Epoch 2:  76%|▊| 48/63 [00:02<00:00, 19.70it/s, loss=0.305, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 2:  81%|▊| 51/63 [00:02<00:00, 17.32it/s, loss=0.305, v_num=6, train_acc=0
# Epoch 2: 100%|█| 63/63 [00:03<00:00, 17.82it/s, loss=0.305, v_num=6, train_acc=0
# Epoch 3:  76%|▊| 48/63 [00:02<00:00, 19.04it/s, loss=0.233, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 3:  81%|▊| 51/63 [00:03<00:00, 16.81it/s, loss=0.233, v_num=6, train_acc=0
# Epoch 3: 100%|█| 63/63 [00:03<00:00, 17.25it/s, loss=0.233, v_num=6, train_acc=0
# Epoch 4:  76%|▊| 48/63 [00:02<00:00, 19.13it/s, loss=0.188, v_num=6, train_acc=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 4:  81%|▊| 51/63 [00:03<00:00, 16.91it/s, loss=0.188, v_num=6, train_acc=1
# Epoch 4: 100%|█| 63/63 [00:03<00:00, 17.36it/s, loss=0.188, v_num=6, train_acc=1
# Epoch 5:  76%|▊| 48/63 [00:02<00:00, 18.86it/s, loss=0.137, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 5:  81%|▊| 51/63 [00:03<00:00, 16.70it/s, loss=0.137, v_num=6, train_acc=0
# Epoch 5: 100%|█| 63/63 [00:03<00:00, 17.03it/s, loss=0.137, v_num=6, train_acc=0
# Epoch 6:  76%|▊| 48/63 [00:02<00:00, 19.12it/s, loss=0.205, v_num=6, train_acc=1
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 6:  81%|▊| 51/63 [00:03<00:00, 16.83it/s, loss=0.205, v_num=6, train_acc=1
# Epoch 6: 100%|█| 63/63 [00:03<00:00, 17.29it/s, loss=0.205, v_num=6, train_acc=1
# Epoch 7:  76%|▊| 48/63 [00:02<00:00, 18.86it/s, loss=0.111, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 7:  81%|▊| 51/63 [00:03<00:00, 16.71it/s, loss=0.111, v_num=6, train_acc=0
# Epoch 7: 100%|█| 63/63 [00:03<00:00, 17.16it/s, loss=0.111, v_num=6, train_acc=0
# Epoch 8:  76%|▊| 48/63 [00:02<00:00, 19.09it/s, loss=0.137, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 8:  81%|▊| 51/63 [00:03<00:00, 16.92it/s, loss=0.137, v_num=6, train_acc=0
# Epoch 8: 100%|█| 63/63 [00:03<00:00, 17.38it/s, loss=0.137, v_num=6, train_acc=0
# Epoch 9:  76%|▊| 48/63 [00:02<00:00, 19.07it/s, loss=0.067, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 9:  81%|▊| 51/63 [00:03<00:00, 16.99it/s, loss=0.067, v_num=6, train_acc=0
# Epoch 9: 100%|█| 63/63 [00:03<00:00, 16.96it/s, loss=0.067, v_num=6, train_acc=0
# Epoch 10:  76%|▊| 48/63 [00:02<00:00, 18.93it/s, loss=0.0757, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 10:  81%|▊| 51/63 [00:03<00:00, 16.80it/s, loss=0.0757, v_num=6, train_acc
# Epoch 10: 100%|█| 63/63 [00:03<00:00, 17.18it/s, loss=0.0757, v_num=6, train_acc
# Epoch 11:  76%|▊| 48/63 [00:02<00:00, 19.80it/s, loss=0.0624, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 11:  81%|▊| 51/63 [00:02<00:00, 17.48it/s, loss=0.0624, v_num=6, train_acc
# Epoch 11: 100%|█| 63/63 [00:03<00:00, 17.86it/s, loss=0.0624, v_num=6, train_acc
# Epoch 12:  76%|▊| 48/63 [00:02<00:00, 18.77it/s, loss=0.0417, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 12:  81%|▊| 51/63 [00:03<00:00, 16.60it/s, loss=0.0417, v_num=6, train_acc
# Epoch 12: 100%|█| 63/63 [00:03<00:00, 16.99it/s, loss=0.0417, v_num=6, train_acc
# Epoch 13:  76%|▊| 48/63 [00:02<00:00, 19.00it/s, loss=0.0757, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 13:  81%|▊| 51/63 [00:03<00:00, 16.78it/s, loss=0.0757, v_num=6, train_acc
# Epoch 13: 100%|█| 63/63 [00:03<00:00, 17.11it/s, loss=0.0757, v_num=6, train_acc
# Epoch 14:  76%|▊| 48/63 [00:02<00:00, 19.14it/s, loss=0.0935, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 14:  81%|▊| 51/63 [00:03<00:00, 16.93it/s, loss=0.0935, v_num=6, train_acc
# Epoch 14: 100%|█| 63/63 [00:03<00:00, 17.20it/s, loss=0.0935, v_num=6, train_acc
# Epoch 15:  76%|▊| 48/63 [00:02<00:00, 18.81it/s, loss=0.0433, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 15:  81%|▊| 51/63 [00:03<00:00, 16.67it/s, loss=0.0433, v_num=6, train_acc
# Epoch 15: 100%|█| 63/63 [00:03<00:00, 17.01it/s, loss=0.0433, v_num=6, train_acc
# Epoch 16:  76%|▊| 48/63 [00:02<00:00, 18.93it/s, loss=0.0359, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 16:  81%|▊| 51/63 [00:03<00:00, 16.68it/s, loss=0.0359, v_num=6, train_acc
# Epoch 16: 100%|█| 63/63 [00:03<00:00, 17.11it/s, loss=0.0359, v_num=6, train_acc
# Epoch 17:  76%|▊| 48/63 [00:02<00:00, 18.93it/s, loss=0.0191, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 17:  81%|▊| 51/63 [00:03<00:00, 16.72it/s, loss=0.0191, v_num=6, train_acc
# Epoch 17: 100%|█| 63/63 [00:03<00:00, 17.14it/s, loss=0.0191, v_num=6, train_acc
# Epoch 18:  76%|▊| 48/63 [00:02<00:00, 18.83it/s, loss=0.0576, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 18:  81%|▊| 51/63 [00:03<00:00, 16.55it/s, loss=0.0576, v_num=6, train_acc
# Epoch 18: 100%|█| 63/63 [00:03<00:00, 16.88it/s, loss=0.0576, v_num=6, train_acc
# Epoch 19:  76%|▊| 48/63 [00:02<00:00, 18.55it/s, loss=0.0218, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 19:  81%|▊| 51/63 [00:03<00:00, 16.38it/s, loss=0.0218, v_num=6, train_acc
# Epoch 19: 100%|█| 63/63 [00:03<00:00, 16.65it/s, loss=0.0218, v_num=6, train_acc
# Epoch 20:  76%|▊| 48/63 [00:02<00:00, 18.66it/s, loss=0.0469, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 20:  81%|▊| 51/63 [00:03<00:00, 16.51it/s, loss=0.0469, v_num=6, train_acc
# Epoch 20: 100%|█| 63/63 [00:03<00:00, 16.87it/s, loss=0.0469, v_num=6, train_acc
# Epoch 21:  76%|▊| 48/63 [00:02<00:00, 18.70it/s, loss=0.0203, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 21:  81%|▊| 51/63 [00:03<00:00, 16.61it/s, loss=0.0203, v_num=6, train_acc
# Epoch 21: 100%|█| 63/63 [00:03<00:00, 17.00it/s, loss=0.0203, v_num=6, train_acc
# Epoch 22:  76%|▊| 48/63 [00:02<00:00, 18.84it/s, loss=0.0164, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 22:  81%|▊| 51/63 [00:03<00:00, 16.58it/s, loss=0.0164, v_num=6, train_acc
# Epoch 22: 100%|█| 63/63 [00:03<00:00, 16.86it/s, loss=0.0164, v_num=6, train_acc
# Epoch 23:  76%|▊| 48/63 [00:02<00:00, 18.53it/s, loss=0.0107, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 23:  81%|▊| 51/63 [00:03<00:00, 16.33it/s, loss=0.0107, v_num=6, train_acc
# Epoch 23: 100%|█| 63/63 [00:03<00:00, 16.99it/s, loss=0.0107, v_num=6, train_acc
# Epoch 24:  76%|▊| 48/63 [00:02<00:00, 18.70it/s, loss=0.0298, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 24:  81%|▊| 51/63 [00:03<00:00, 16.57it/s, loss=0.0298, v_num=6, train_acc
# Epoch 24: 100%|█| 63/63 [00:03<00:00, 16.98it/s, loss=0.0298, v_num=6, train_acc
# Epoch 25:  76%|▊| 48/63 [00:02<00:00, 18.73it/s, loss=0.00768, v_num=6, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 25:  81%|▊| 51/63 [00:03<00:00, 16.61it/s, loss=0.00768, v_num=6, train_ac
# Epoch 25: 100%|█| 63/63 [00:03<00:00, 17.01it/s, loss=0.00768, v_num=6, train_ac
# Epoch 26:  76%|▊| 48/63 [00:02<00:00, 19.35it/s, loss=0.0103, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 26:  81%|▊| 51/63 [00:02<00:00, 17.14it/s, loss=0.0103, v_num=6, train_acc
# Epoch 26: 100%|█| 63/63 [00:03<00:00, 17.41it/s, loss=0.0103, v_num=6, train_acc
# Epoch 27:  76%|▊| 48/63 [00:02<00:00, 19.46it/s, loss=0.00524, v_num=6, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 27:  81%|▊| 51/63 [00:02<00:00, 17.18it/s, loss=0.00524, v_num=6, train_ac
# Epoch 27: 100%|█| 63/63 [00:03<00:00, 17.57it/s, loss=0.00524, v_num=6, train_ac
# Epoch 28:  76%|▊| 48/63 [00:02<00:00, 19.29it/s, loss=0.0278, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 28:  81%|▊| 51/63 [00:02<00:00, 17.06it/s, loss=0.0278, v_num=6, train_acc
# Epoch 28: 100%|█| 63/63 [00:03<00:00, 17.47it/s, loss=0.0278, v_num=6, train_acc
# Epoch 29:  76%|▊| 48/63 [00:02<00:00, 19.40it/s, loss=0.0438, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 29:  81%|▊| 51/63 [00:02<00:00, 17.17it/s, loss=0.0438, v_num=6, train_acc
# Epoch 29: 100%|█| 63/63 [00:03<00:00, 17.54it/s, loss=0.0438, v_num=6, train_acc
# Epoch 30:  76%|▊| 48/63 [00:02<00:00, 18.87it/s, loss=0.0217, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 30:  81%|▊| 51/63 [00:03<00:00, 16.72it/s, loss=0.0217, v_num=6, train_acc
# Epoch 30: 100%|█| 63/63 [00:03<00:00, 17.09it/s, loss=0.0217, v_num=6, train_acc
# Epoch 31:  76%|▊| 48/63 [00:02<00:00, 18.73it/s, loss=0.0139, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 31:  81%|▊| 51/63 [00:03<00:00, 16.55it/s, loss=0.0139, v_num=6, train_acc
# Epoch 31: 100%|█| 63/63 [00:03<00:00, 16.98it/s, loss=0.0139, v_num=6, train_acc
# Epoch 32:  76%|▊| 48/63 [00:02<00:00, 18.48it/s, loss=0.0471, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 32:  81%|▊| 51/63 [00:03<00:00, 16.29it/s, loss=0.0471, v_num=6, train_acc
# Epoch 32: 100%|█| 63/63 [00:03<00:00, 16.80it/s, loss=0.0471, v_num=6, train_acc
# Epoch 33:  76%|▊| 48/63 [00:02<00:00, 18.89it/s, loss=0.0247, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 33:  81%|▊| 51/63 [00:03<00:00, 16.59it/s, loss=0.0247, v_num=6, train_acc
# Epoch 33: 100%|█| 63/63 [00:03<00:00, 16.99it/s, loss=0.0247, v_num=6, train_acc
# Epoch 34:  76%|▊| 48/63 [00:02<00:00, 18.81it/s, loss=0.00486, v_num=6, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 34:  81%|▊| 51/63 [00:03<00:00, 16.63it/s, loss=0.00486, v_num=6, train_ac
# Epoch 34: 100%|█| 63/63 [00:03<00:00, 16.98it/s, loss=0.00486, v_num=6, train_ac
# Epoch 35:  76%|▊| 48/63 [00:02<00:00, 18.88it/s, loss=0.00731, v_num=6, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 35:  81%|▊| 51/63 [00:03<00:00, 16.66it/s, loss=0.00731, v_num=6, train_ac
# Epoch 35: 100%|█| 63/63 [00:03<00:00, 17.01it/s, loss=0.00731, v_num=6, train_ac
# Epoch 36:  76%|▊| 48/63 [00:02<00:00, 18.86it/s, loss=0.0105, v_num=6, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 36:  81%|▊| 51/63 [00:03<00:00, 16.68it/s, loss=0.0105, v_num=6, train_acc
# Epoch 36: 100%|█| 63/63 [00:03<00:00, 17.04it/s, loss=0.0105, v_num=6, train_acc
# Epoch 37:  76%|▊| 48/63 [00:02<00:00, 19.00it/s, loss=0.26, v_num=6, train_acc=0
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 37:  81%|▊| 51/63 [00:03<00:00, 16.74it/s, loss=0.26, v_num=6, train_acc=0
# Epoch 37: 100%|█| 63/63 [00:03<00:00, 16.94it/s, loss=0.26, v_num=6, train_acc=0
# Epoch 38:  76%|▊| 48/63 [00:02<00:00, 18.96it/s, loss=0.00954, v_num=6, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/16 [00:00<?, ?it/s]
# Epoch 38:  81%|▊| 51/63 [00:03<00:00, 16.81it/s, loss=0.00954, v_num=6, train_ac
# Epoch 38: 100%|█| 63/63 [00:03<00:00, 17.18it/s, loss=0.00954, v_num=6, train_ac
# Epoch 38: 100%|█| 63/63 [00:03<00:00, 17.09it/s, loss=0.00954, v_num=6, train_ac
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_6/checkpoints/epoch=22-step=1080.ckpt
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_6/checkpoints/epoch=22-step=1080.ckpt
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:662: UserWarning: Your `test_dataloader` has `shuffle=True`, it is strongly recommended that you turn this off for val/test/predict dataloaders.
#   category=UserWarning,
# Testing:  87%|█████████████████████████████▋    | 41/47 [00:00<00:00, 82.49it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.999666690826416, 'test_loss': 0.0029280984308570623}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 47/47 [00:02<00:00, 20.96it/s]
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_6/checkpoints/epoch=22-step=1080.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_6/checkpoints/epoch=22-step=1080.ckpt
# Testing: 100%|██████████████████████████████████| 16/16 [00:00<00:00, 30.07it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9660000205039978, 'test_loss': 0.11626611649990082}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 16/16 [00:01<00:00, 14.53it/s]
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.teardown has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.teardown.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# Global seed set to 1234
# Global seed set to 1234
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_6/checkpoints/epoch=22-step=1080.ckpt
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_6/checkpoints/epoch=22-step=1080.ckpt
# Testing: 100%|███████████████████████████████| 157/157 [00:01<00:00, 138.74it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9688000082969666, 'test_loss': 0.11470437049865723}
# --------------------------------------------------------------------------------
# Testing: 100%|████████████████████████████████| 157/157 [00:06<00:00, 25.85it/s]
# train_result:
#
# [{'test_acc': 0.999666690826416, 'test_loss': 0.0029280984308570623}]
# val_result:
#
# [{'test_acc': 0.9660000205039978, 'test_loss': 0.11626611649990082}]
# test_result:
#
# [{'test_acc': 0.9688000082969666, 'test_loss': 0.11470437049865723}]
# train_result:
#
# [{'test_acc': 0.999666690826416, 'test_loss': 0.0029280984308570623}]
# val_result:
#
# [{'test_acc': 0.9660000205039978, 'test_loss': 0.11626611649990082}]
# test_result:
#
# [{'test_acc': 0.9688000082969666, 'test_loss': 0.11470437049865723}]

# %% [markdown]
# ```
# ------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9688000082969666, 'test_loss': 0.11470437049865723}
# --------------------------------------------------------------------------------
# ```

# %% [markdown]
# ### 3, 最优学习率搜索(auto_lr_find=True)

# %% [markdown]
# * 平凡方式训练：test_acc = 0.9581000208854675
#
# * SWA随机权重： test_acc = 0.963100016117096
#
# * SWA随机权重 + CyClicLR学习率调度策略: test_acc = 0.9688000082969666
#
# * SWA随机权重 + CyClicLR学习率调度策略 + 最优学习率搜索： test_acc = 0.9693999886512756

# %%
# !python3 mnist_cnn.py --gpus=1  --auto_lr_find=True --use_swa=True --use_CyclicLR=True
# Out:
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# hparams.auto_lr_find= True
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# set lr = 0.007
# Global seed set to 1234
# Finding best initial lr:  80%|█████████████▌   | 80/100 [00:00<00:00, 94.27it/s]
# LR finder stopped early after 80 steps due to diverging loss.
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lr_find_temp_model_5344e797-48c6-4eb4-b090-a25e9aa6635c.ckpt
# suggest lr= 0.003311311214825908
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | net       | Sequential | 54.0 K
# 1 | train_acc | Accuracy   | 0
# 2 | val_acc   | Accuracy   | 0
# 3 | test_acc  | Accuracy   | 0
# -----------------------------------------
# 54.0 K    Trainable params
# 0         Non-trainable params
# 54.0 K    Total params
# 0.216     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  75%|▋| 94/126 [00:01<00:00, 63.08it/s, loss=1.04, v_num=19, train_acc=
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 0:  78%|▊| 98/126 [00:01<00:00, 50.41it/s, loss=1.04, v_num=19, train_acc=
# Epoch 0:  94%|▉| 118/126 [00:02<00:00, 57.72it/s, loss=1.04, v_num=19, train_acc
# Epoch 0: 100%|█| 126/126 [00:02<00:00, 57.73it/s, loss=1.04, v_num=19, train_acc
# Epoch 1:  75%|▋| 94/126 [00:01<00:00, 64.47it/s, loss=0.598, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 1:  79%|▊| 100/126 [00:01<00:00, 51.37it/s, loss=0.598, v_num=19, train_ac
# Epoch 1:  95%|▉| 120/126 [00:02<00:00, 58.61it/s, loss=0.598, v_num=19, train_ac
# Epoch 1: 100%|█| 126/126 [00:02<00:00, 58.17it/s, loss=0.598, v_num=19, train_ac
# Epoch 2:  75%|▋| 94/126 [00:01<00:00, 62.16it/s, loss=0.437, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 2:  79%|▊| 100/126 [00:02<00:00, 49.87it/s, loss=0.437, v_num=19, train_ac
# Epoch 2:  95%|▉| 120/126 [00:02<00:00, 56.89it/s, loss=0.437, v_num=19, train_ac
# Epoch 2: 100%|█| 126/126 [00:02<00:00, 56.49it/s, loss=0.437, v_num=19, train_ac
# Epoch 3:  75%|▋| 94/126 [00:01<00:00, 61.26it/s, loss=0.307, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 3:  79%|▊| 100/126 [00:02<00:00, 49.41it/s, loss=0.307, v_num=19, train_ac
# Epoch 3: 100%|█| 126/126 [00:02<00:00, 56.76it/s, loss=0.307, v_num=19, train_ac
# Epoch 4:  75%|▋| 94/126 [00:01<00:00, 62.91it/s, loss=0.225, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 4:  83%|▊| 105/126 [00:01<00:00, 52.78it/s, loss=0.225, v_num=19, train_ac
# Epoch 4: 100%|█| 126/126 [00:02<00:00, 60.14it/s, loss=0.225, v_num=19, train_ac
# Epoch 4: 100%|█| 126/126 [00:02<00:00, 58.13it/s, loss=0.225, v_num=19, train_ac
# Epoch 5:  75%|▋| 94/126 [00:01<00:00, 63.91it/s, loss=0.178, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 5:  83%|▊| 105/126 [00:01<00:00, 53.01it/s, loss=0.178, v_num=19, train_ac
# Epoch 5: 100%|█| 126/126 [00:02<00:00, 60.51it/s, loss=0.178, v_num=19, train_ac
# Epoch 5: 100%|█| 126/126 [00:02<00:00, 58.48it/s, loss=0.178, v_num=19, train_ac
# Epoch 6:  75%|▋| 94/126 [00:01<00:00, 62.28it/s, loss=0.178, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 6:  83%|▊| 105/126 [00:02<00:00, 52.21it/s, loss=0.178, v_num=19, train_ac
# Epoch 6: 100%|█| 126/126 [00:02<00:00, 59.54it/s, loss=0.178, v_num=19, train_ac
# Epoch 6: 100%|█| 126/126 [00:02<00:00, 57.34it/s, loss=0.178, v_num=19, train_ac
# Epoch 7:  75%|▋| 94/126 [00:01<00:00, 64.29it/s, loss=0.128, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 7:  83%|▊| 105/126 [00:01<00:00, 52.78it/s, loss=0.128, v_num=19, train_ac
# Epoch 7: 100%|█| 126/126 [00:02<00:00, 60.16it/s, loss=0.128, v_num=19, train_ac
# Epoch 7: 100%|█| 126/126 [00:02<00:00, 57.52it/s, loss=0.128, v_num=19, train_ac
# Epoch 8:  75%|▋| 94/126 [00:01<00:00, 63.20it/s, loss=0.127, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 8:  83%|▊| 105/126 [00:01<00:00, 52.55it/s, loss=0.127, v_num=19, train_ac
# Validating:  59%|██████████████████▍            | 19/32 [00:00<00:00, 44.64it/s]
# Epoch 8: 100%|█| 126/126 [00:02<00:00, 57.51it/s, loss=0.127, v_num=19, train_ac
# Epoch 9:  75%|▋| 94/126 [00:01<00:00, 63.51it/s, loss=0.105, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 9:  83%|▊| 105/126 [00:01<00:00, 52.83it/s, loss=0.105, v_num=19, train_ac
# Epoch 9: 100%|█| 126/126 [00:02<00:00, 60.19it/s, loss=0.105, v_num=19, train_ac
# Epoch 9: 100%|█| 126/126 [00:02<00:00, 57.10it/s, loss=0.105, v_num=19, train_ac
# Epoch 10:  75%|▋| 94/126 [00:01<00:00, 65.49it/s, loss=0.0979, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 10:  83%|▊| 105/126 [00:01<00:00, 54.23it/s, loss=0.0979, v_num=19, train_
# Validating:  59%|██████████████████▍            | 19/32 [00:00<00:00, 45.49it/s]
# Epoch 10: 100%|█| 126/126 [00:02<00:00, 59.81it/s, loss=0.0979, v_num=19, train_
# Epoch 11:  75%|▋| 94/126 [00:01<00:00, 65.20it/s, loss=0.0908, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 11:  83%|▊| 105/126 [00:01<00:00, 54.31it/s, loss=0.0908, v_num=19, train_
# Epoch 11: 100%|█| 126/126 [00:02<00:00, 61.92it/s, loss=0.0908, v_num=19, train_
# Epoch 11: 100%|█| 126/126 [00:02<00:00, 59.01it/s, loss=0.0908, v_num=19, train_
# Epoch 12:  75%|▋| 94/126 [00:01<00:00, 67.03it/s, loss=0.0511, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 12:  83%|▊| 105/126 [00:01<00:00, 55.86it/s, loss=0.0511, v_num=19, train_
# Epoch 12: 100%|█| 126/126 [00:02<00:00, 61.20it/s, loss=0.0511, v_num=19, train_
# Epoch 13:  75%|▋| 94/126 [00:01<00:00, 67.98it/s, loss=0.0388, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 13:  83%|▊| 105/126 [00:01<00:00, 55.69it/s, loss=0.0388, v_num=19, train_
# Validating:  62%|███████████████████▍           | 20/32 [00:00<00:00, 47.61it/s]
# Epoch 13: 100%|█| 126/126 [00:02<00:00, 61.39it/s, loss=0.0388, v_num=19, train_
# Epoch 14:  75%|▋| 94/126 [00:01<00:00, 67.66it/s, loss=0.0438, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 14:  83%|▊| 105/126 [00:01<00:00, 55.96it/s, loss=0.0438, v_num=19, train_
# Epoch 14: 100%|█| 126/126 [00:01<00:00, 63.63it/s, loss=0.0438, v_num=19, train_
# Epoch 14: 100%|█| 126/126 [00:02<00:00, 61.33it/s, loss=0.0438, v_num=19, train_
# Epoch 15:  75%|▋| 94/126 [00:01<00:00, 68.00it/s, loss=0.0427, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 15:  83%|▊| 105/126 [00:01<00:00, 55.75it/s, loss=0.0427, v_num=19, train_
# Epoch 15: 100%|█| 126/126 [00:02<00:00, 60.84it/s, loss=0.0427, v_num=19, train_
# Epoch 16:  75%|▋| 94/126 [00:01<00:00, 67.85it/s, loss=0.0482, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 16:  83%|▊| 105/126 [00:01<00:00, 55.95it/s, loss=0.0482, v_num=19, train_
# Epoch 16: 100%|█| 126/126 [00:02<00:00, 61.39it/s, loss=0.0482, v_num=19, train_
# Epoch 17:  75%|▋| 94/126 [00:01<00:00, 67.91it/s, loss=0.0531, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 17:  83%|▊| 105/126 [00:01<00:00, 55.76it/s, loss=0.0531, v_num=19, train_
# Epoch 17: 100%|█| 126/126 [00:02<00:00, 61.47it/s, loss=0.0531, v_num=19, train_
# Epoch 18:  75%|▋| 94/126 [00:01<00:00, 66.77it/s, loss=0.0296, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 18:  83%|▊| 105/126 [00:01<00:00, 55.03it/s, loss=0.0296, v_num=19, train_
# Epoch 18: 100%|█| 126/126 [00:02<00:00, 62.71it/s, loss=0.0296, v_num=19, train_
# Epoch 18: 100%|█| 126/126 [00:02<00:00, 59.48it/s, loss=0.0296, v_num=19, train_
# Epoch 19:  75%|▋| 94/126 [00:01<00:00, 63.95it/s, loss=0.0511, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 19:  83%|▊| 105/126 [00:01<00:00, 53.19it/s, loss=0.0511, v_num=19, train_
# Epoch 19: 100%|█| 126/126 [00:02<00:00, 60.61it/s, loss=0.0511, v_num=19, train_
# Epoch 19: 100%|█| 126/126 [00:02<00:00, 57.81it/s, loss=0.0511, v_num=19, train_
# Epoch 20:  75%|▋| 94/126 [00:01<00:00, 62.81it/s, loss=0.0224, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 20:  83%|▊| 105/126 [00:02<00:00, 52.48it/s, loss=0.0224, v_num=19, train_
# Epoch 20: 100%|█| 126/126 [00:02<00:00, 59.95it/s, loss=0.0224, v_num=19, train_
# Epoch 20: 100%|█| 126/126 [00:02<00:00, 57.91it/s, loss=0.0224, v_num=19, train_
# Epoch 21:  75%|▋| 94/126 [00:01<00:00, 61.95it/s, loss=0.0223, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 21:  83%|▊| 105/126 [00:02<00:00, 51.65it/s, loss=0.0223, v_num=19, train_
# Epoch 21: 100%|█| 126/126 [00:02<00:00, 59.04it/s, loss=0.0223, v_num=19, train_
# Epoch 21: 100%|█| 126/126 [00:02<00:00, 56.54it/s, loss=0.0223, v_num=19, train_
# Epoch 22:  75%|▋| 94/126 [00:01<00:00, 64.44it/s, loss=0.0434, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 22:  83%|▊| 105/126 [00:01<00:00, 53.17it/s, loss=0.0434, v_num=19, train_
# Epoch 22: 100%|█| 126/126 [00:02<00:00, 60.58it/s, loss=0.0434, v_num=19, train_
# Epoch 22: 100%|█| 126/126 [00:02<00:00, 57.61it/s, loss=0.0434, v_num=19, train_
# Epoch 23:  75%|▋| 94/126 [00:01<00:00, 63.32it/s, loss=0.03, v_num=19, train_acc
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 23:  83%|▊| 105/126 [00:01<00:00, 52.78it/s, loss=0.03, v_num=19, train_ac
# Epoch 23: 100%|█| 126/126 [00:02<00:00, 60.26it/s, loss=0.03, v_num=19, train_ac
# Epoch 23: 100%|█| 126/126 [00:02<00:00, 57.25it/s, loss=0.03, v_num=19, train_ac
# Epoch 24:  75%|▋| 94/126 [00:01<00:00, 63.32it/s, loss=0.0143, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 24:  83%|▊| 105/126 [00:01<00:00, 52.74it/s, loss=0.0143, v_num=19, train_
# Epoch 24: 100%|█| 126/126 [00:02<00:00, 60.23it/s, loss=0.0143, v_num=19, train_
# Epoch 24: 100%|█| 126/126 [00:02<00:00, 57.35it/s, loss=0.0143, v_num=19, train_
# Epoch 25:  75%|▋| 94/126 [00:01<00:00, 63.10it/s, loss=0.0344, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 25:  83%|▊| 105/126 [00:02<00:00, 52.44it/s, loss=0.0344, v_num=19, train_
# Epoch 25: 100%|█| 126/126 [00:02<00:00, 59.84it/s, loss=0.0344, v_num=19, train_
# Epoch 25: 100%|█| 126/126 [00:02<00:00, 57.07it/s, loss=0.0344, v_num=19, train_
# Epoch 26:  75%|▋| 94/126 [00:01<00:00, 64.24it/s, loss=0.0579, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 26:  83%|▊| 105/126 [00:01<00:00, 52.58it/s, loss=0.0579, v_num=19, train_
# Epoch 26: 100%|█| 126/126 [00:02<00:00, 60.07it/s, loss=0.0579, v_num=19, train_
# Epoch 26: 100%|█| 126/126 [00:02<00:00, 57.95it/s, loss=0.0579, v_num=19, train_
# Epoch 27:  75%|▋| 94/126 [00:01<00:00, 63.36it/s, loss=0.0185, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 27:  83%|▊| 105/126 [00:01<00:00, 52.68it/s, loss=0.0185, v_num=19, train_
# Epoch 27: 100%|█| 126/126 [00:02<00:00, 60.14it/s, loss=0.0185, v_num=19, train_
# Epoch 27: 100%|█| 126/126 [00:02<00:00, 57.52it/s, loss=0.0185, v_num=19, train_
# Epoch 28:  75%|▋| 94/126 [00:01<00:00, 63.29it/s, loss=0.0183, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 28:  83%|▊| 105/126 [00:01<00:00, 53.09it/s, loss=0.0183, v_num=19, train_
# Epoch 28: 100%|█| 126/126 [00:02<00:00, 60.50it/s, loss=0.0183, v_num=19, train_
# Epoch 28: 100%|█| 126/126 [00:02<00:00, 57.71it/s, loss=0.0183, v_num=19, train_
# Epoch 29:  75%|▋| 94/126 [00:01<00:00, 62.71it/s, loss=0.0451, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 29:  83%|▊| 105/126 [00:02<00:00, 52.30it/s, loss=0.0451, v_num=19, train_
# Epoch 29: 100%|█| 126/126 [00:02<00:00, 59.72it/s, loss=0.0451, v_num=19, train_
# Epoch 29: 100%|█| 126/126 [00:02<00:00, 57.35it/s, loss=0.0451, v_num=19, train_
# Epoch 30:  75%|▋| 94/126 [00:01<00:00, 63.14it/s, loss=0.017, v_num=19, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 30:  83%|▊| 105/126 [00:02<00:00, 51.86it/s, loss=0.017, v_num=19, train_a
# Epoch 30: 100%|█| 126/126 [00:02<00:00, 59.23it/s, loss=0.017, v_num=19, train_a
# Epoch 30: 100%|█| 126/126 [00:02<00:00, 57.18it/s, loss=0.017, v_num=19, train_a
# Epoch 31:  75%|▋| 94/126 [00:01<00:00, 60.85it/s, loss=0.0127, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 31:  83%|▊| 105/126 [00:02<00:00, 50.97it/s, loss=0.0127, v_num=19, train_
# Validating:  62%|███████████████████▍           | 20/32 [00:00<00:00, 46.59it/s]
# Epoch 31: 100%|█| 126/126 [00:02<00:00, 56.00it/s, loss=0.0127, v_num=19, train_
# Epoch 32:  75%|▋| 94/126 [00:01<00:00, 61.13it/s, loss=0.0195, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 32:  83%|▊| 105/126 [00:02<00:00, 51.01it/s, loss=0.0195, v_num=19, train_
# Epoch 32: 100%|█| 126/126 [00:02<00:00, 58.22it/s, loss=0.0195, v_num=19, train_
# Epoch 32: 100%|█| 126/126 [00:02<00:00, 56.28it/s, loss=0.0195, v_num=19, train_
# Epoch 33:  75%|▋| 94/126 [00:01<00:00, 63.95it/s, loss=0.00425, v_num=19, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 33:  83%|▊| 105/126 [00:01<00:00, 53.21it/s, loss=0.00425, v_num=19, train
# Validating:  62%|███████████████████▍           | 20/32 [00:00<00:00, 47.47it/s]
# Epoch 33: 100%|█| 126/126 [00:02<00:00, 58.09it/s, loss=0.00425, v_num=19, train
# Epoch 34:  75%|▋| 94/126 [00:01<00:00, 65.46it/s, loss=0.0357, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 34:  83%|▊| 105/126 [00:01<00:00, 54.39it/s, loss=0.0357, v_num=19, train_
# Validating:  59%|██████████████████▍            | 19/32 [00:00<00:00, 46.15it/s]
# Epoch 34: 100%|█| 126/126 [00:02<00:00, 59.95it/s, loss=0.0357, v_num=19, train_
# Epoch 35:  75%|▋| 94/126 [00:01<00:00, 67.32it/s, loss=0.0234, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 35:  83%|▊| 105/126 [00:01<00:00, 55.70it/s, loss=0.0234, v_num=19, train_
# Epoch 35: 100%|█| 126/126 [00:02<00:00, 60.55it/s, loss=0.0234, v_num=19, train_
# Epoch 36:  75%|▋| 94/126 [00:01<00:00, 69.17it/s, loss=0.0287, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 36:  83%|▊| 105/126 [00:01<00:00, 56.81it/s, loss=0.0287, v_num=19, train_
# Validating:  59%|██████████████████▍            | 19/32 [00:00<00:00, 46.65it/s]
# Epoch 36: 100%|█| 126/126 [00:02<00:00, 62.47it/s, loss=0.0287, v_num=19, train_
# Epoch 37:  75%|▋| 94/126 [00:01<00:00, 68.60it/s, loss=0.00399, v_num=19, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 37:  83%|▊| 105/126 [00:01<00:00, 56.76it/s, loss=0.00399, v_num=19, train
# Epoch 37: 100%|█| 126/126 [00:02<00:00, 62.68it/s, loss=0.00399, v_num=19, train
# Epoch 38:  75%|▋| 94/126 [00:01<00:00, 69.03it/s, loss=0.0454, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 38:  83%|▊| 105/126 [00:01<00:00, 56.97it/s, loss=0.0454, v_num=19, train_
# Validating:  62%|███████████████████▍           | 20/32 [00:00<00:00, 49.34it/s]
# Epoch 38: 100%|█| 126/126 [00:02<00:00, 62.55it/s, loss=0.0454, v_num=19, train_
# Epoch 39:  75%|▋| 94/126 [00:01<00:00, 67.26it/s, loss=0.034, v_num=19, train_ac
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 39:  83%|▊| 105/126 [00:01<00:00, 55.60it/s, loss=0.034, v_num=19, train_a
# Validating:  62%|███████████████████▍           | 20/32 [00:00<00:00, 48.56it/s]
# Epoch 39: 100%|█| 126/126 [00:02<00:00, 60.97it/s, loss=0.034, v_num=19, train_a
# Epoch 40:  75%|▋| 94/126 [00:01<00:00, 67.34it/s, loss=0.0262, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 40:  83%|▊| 105/126 [00:01<00:00, 55.31it/s, loss=0.0262, v_num=19, train_
# Validating:  59%|██████████████████▍            | 19/32 [00:00<00:00, 45.36it/s]
# Epoch 40: 100%|█| 126/126 [00:02<00:00, 60.83it/s, loss=0.0262, v_num=19, train_
# Epoch 41:  75%|▋| 94/126 [00:01<00:00, 67.71it/s, loss=0.00348, v_num=19, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 41:  83%|▊| 105/126 [00:01<00:00, 56.08it/s, loss=0.00348, v_num=19, train
# Epoch 41: 100%|█| 126/126 [00:02<00:00, 61.10it/s, loss=0.00348, v_num=19, train
# Epoch 42:  75%|▋| 94/126 [00:01<00:00, 64.99it/s, loss=0.0051, v_num=19, train_a
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 42:  83%|▊| 105/126 [00:01<00:00, 53.78it/s, loss=0.0051, v_num=19, train_
# Epoch 42: 100%|█| 126/126 [00:02<00:00, 61.36it/s, loss=0.0051, v_num=19, train_
# Epoch 42: 100%|█| 126/126 [00:02<00:00, 58.60it/s, loss=0.0051, v_num=19, train_
# Epoch 43:  75%|▋| 94/126 [00:01<00:00, 63.08it/s, loss=0.00219, v_num=19, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 43:  83%|▊| 105/126 [00:01<00:00, 52.56it/s, loss=0.00219, v_num=19, train
# Epoch 43: 100%|█| 126/126 [00:02<00:00, 60.01it/s, loss=0.00219, v_num=19, train
# Epoch 43: 100%|█| 126/126 [00:02<00:00, 57.97it/s, loss=0.00219, v_num=19, train
# Epoch 44:  75%|▋| 94/126 [00:01<00:00, 64.57it/s, loss=0.00869, v_num=19, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 44:  83%|▊| 105/126 [00:01<00:00, 53.33it/s, loss=0.00869, v_num=19, train
# Epoch 44: 100%|█| 126/126 [00:02<00:00, 60.71it/s, loss=0.00869, v_num=19, train
# Epoch 44: 100%|█| 126/126 [00:02<00:00, 57.78it/s, loss=0.00869, v_num=19, train
# Epoch 45:  75%|▋| 94/126 [00:01<00:00, 61.46it/s, loss=0.00969, v_num=19, train_
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                        | 0/32 [00:00<?, ?it/s]
# Epoch 45:  83%|▊| 105/126 [00:02<00:00, 51.96it/s, loss=0.00969, v_num=19, train
# Epoch 45: 100%|█| 126/126 [00:02<00:00, 59.38it/s, loss=0.00969, v_num=19, train
# Epoch 45: 100%|█| 126/126 [00:02<00:00, 56.84it/s, loss=0.00969, v_num=19, train
# Epoch 45: 100%|█| 126/126 [00:02<00:00, 56.77it/s, loss=0.00969, v_num=19, train
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/core/datamodule.py:470: LightningDeprecationWarning: DataModule.teardown has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.teardown.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=29-step=2819.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=29-step=2819.ckpt
# /usr/local/lib/python3.6/site-packages/pytorch_lightning/trainer/data_loading.py:662: UserWarning: Your `test_dataloader` has `shuffle=True`, it is strongly recommended that you turn this off for val/test/predict dataloaders.
#   category=UserWarning,
# Testing:  99%|████████████████████████████████▋| 93/94 [00:00<00:00, 143.64it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 1.0, 'test_loss': 0.0020417957566678524}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 94/94 [00:01<00:00, 89.38it/s]
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=29-step=2819.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=29-step=2819.ckpt
# Testing: 100%|██████████████████████████████████| 32/32 [00:00<00:00, 61.36it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.972000002861023, 'test_loss': 0.10358494520187378}
# --------------------------------------------------------------------------------
# Testing: 100%|██████████████████████████████████| 32/32 [00:00<00:00, 46.36it/s]
# Restoring states from the checkpoint path at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=29-step=2819.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loaded model weights from checkpoint at /home/hadoop-map/machine_learning_AK47/②基础模型/lightning_logs/version_19/checkpoints/epoch=29-step=2819.ckpt
# Testing: 100%|███████████████████████████████| 313/313 [00:02<00:00, 155.28it/s]--------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9693999886512756, 'test_loss': 0.11024412512779236}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:02<00:00, 137.85it/s]
# train_result:
#
# [{'test_acc': 1.0, 'test_loss': 0.0020417957566678524}]
# val_result:
#
# [{'test_acc': 0.972000002861023, 'test_loss': 0.10358494520187378}]
# test_result:
#
# [{'test_acc': 0.9693999886512756, 'test_loss': 0.11024412512779236}]

# %% [markdown]
# ```
# ---------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc': 0.9693999886512756, 'test_loss': 0.11024412512779236}
# --------------------------------------------------------------------------------
# Testing: 100%|███████████████████████████████| 313/313 [00:02<00:00, 137.85it/s]
# ```
